# %%
#import pybel
#from pybel import *
import numpy as np
import pandas as pd
#import matplotlib.pyplot as plt
from openbabel import *
from openbabel.pybel import *
import openbabel.pybel as pybel
import openbabel
import os
import ntpath
import re


for filename in os.listdir('./'):
    if filename.endswith(".csv"):
        samples = ntpath.basename(filename)
        print (samples)

samples_smiles = pd.read_csv(samples)
print (samples_smiles.head())
# Out:
# linjian_gen_outlier.csv
#    Unnamed: 0                             SMILES  pred_gap
# 0           0              O=C1[C]2[C]C(=S)C=C21  1.804824
# 1           1        NC1=CC=CC=C=CSSC=CSC=CSC1=O  1.864085
# 2           2          CSC1=CC=CC=CN=NC=CC(S)=C1  1.971824
# 3           3           C=CC(OC)=[PH]=C1C=[SH]C1  1.983468
# 4           4  C1=CC=CN2SN=CC=CC2=C[SH]=[SH]C=C1  1.886328

# %%
for ii, smiles in enumerate(samples_smiles['SMILES']):
    mol = pybel.readstring("smi", smiles)
    print (mol)
    mol.make3D()
    p_counter = 0
    for kk, char in enumerate (smiles):
        s = smiles.replace("=","d")
        s = s.replace("#","t")
        s = s.replace("(","q")
        s = s.replace(")","r")
    f = open("{}.com".format(s), "w")    
    f.write("%chk={}.chk\n".format(s))
    f.write("%NProcShared=20\n")
    f.write("# opt freq b3lyp/6-31g(2df,p)\n")
    f.write("\n")
    f.write("Title Card Required")
    #f.write("\n")
    with open('file.test', 'w') as atoms:
        atoms.write(mol.write("gjf"))
    with open('file.test', 'r') as atoms2:
        atomss = atoms2.read().splitlines(True)
    f.writelines(atomss[3:])
    ff = open("{}.sh".format(ii+1),'w')
    ff.write("#!/bin/bash -\n")
    ff.write("#-------------------------------------------------------------------------------\n")
    ff.write("#  SBATCH CONFIG\n")
    ff.write("#-------------------------------------------------------------------------------\n")
    ff.write("## resources\n")
    ff.write("#SBATCH -N1  # nodes\n")
    ff.write("#SBATCH -n4  # tasks (cores)\n")
    ff.write("#SBATCH --ntasks-per-node=4  # how many tasks per node\n")
    ff.write("#SBATCH --mem-per-cpu=4G  # memory required per core\n")
    ff.write("#SBATCH -t 00-08:00  # time (days-hours:minutes)\n")
    ff.write("#\n")
    ff.write("#SBATCH -p Lewis  # partition (which set of nodes to run on)\n")
    ff.write("#SBATCH -o {}.out\n".format(s))
    ff.write("#SBATCH -J gauss_rcgan\n")
    ff.write("#\n")
    ff.write("module load gaussian/gaussian-16-A.03\n")
    ff.write('echo "### Starting Gaussian ###"\n')
    ff.write("g16 < ./{}.com\n".format(s))
    ff.write('echo "### All Done ###"\n')
    ff.write("\n")
# Out:
# O=C1[C]2[C]C(=S)C=C12
#
# NC1=CC=CC=C=CSSC=CSC=CSC1=O
#
# CSC1=CC=CC=CN=NC=CC(=C1)S
#
# C=CC(=P=C1C=SC1)OC
#
# C1=CC=CN2SN=CC=CC2=CS=SC=C1
#
# N=C1C=CC=NN=CN=CC=CC=CSC=N1
#
# Cc1ccccc2=CN=CC=CC=CCC=c2sc1
#
# CCC1=CC=CC=CC=CC=C=NSSS1
#
# O=C=CC1=CC=CC=CC=CC2=CS2=C1
#
# Nc1cccc2cc(c3=C=CC=CC=c3c1)S2
#
# N#CC1=CC=CC=NC=NN=C2C=NC12S
#
# CC1=[C][C]=[C]N=C2N=C3N=C2[C]=C3C2=CC2=[C]1
#
# O=C1N=CC2=C=CC2=CC=CC2=C3C=CC=CC123
#
# C=c1cc2c3-c(ccc3)nc1=CC(=O)N=CC=CC=C2
#
# C=Nc1cc2ccc1N=CC=C2SC
#
# Nc1cc2-c3cccc(cnn2)c3cc2ccccc2no1
#
# O=C1C=C2C=CC3=CC=CC=NC3=CC2=N1
#
# N=C1C=CC=CC=CC=CN=CN=NC=CS1
#
# O=C1C=CC=CC=CC=NN=NN=N1
#
# C1=Cc2ccccccc3c(=CN3)c2=C1
#
# O=CC=CC1=CC(=CNN=C1)C=O
#
# C1=CC=CS=Sc2ccccc2C=CC=C1
#
# COC1=CC2=C(C2CS=O)S2C=NN=C2N=CC=C1
#
# SC1=C(S)C(=CC=CC=CC=NC=C1)C#S
#
# O=C1[C]=C2C=CC=CC3=NC3=C12
#
# N=c1cccc2c(c1)N=CC=CSC=CC=C2
#
# NC1=CC=c2cccnc2=CN[CH]C1=O
#
# C=CC1=C(OC)C(=S)C(=NC=CNS=C=N1)O
#
# O=C1C=CC=CC=CC2=CC=CC2=CSS1
#
# N=c1cc(N)c(=O)cccccccc1N=CSS
#
# S[C]1C=CC=CC=CC=C[N]C=C1
#
# SCC1=CC=C2C=C2SC=CS1
#
# O=C1C=CC=CC=CC2=NC=CC12S
#
# O=c1c2=CC=CC=Cc2ccccccc2c1=S2
#
# O=C1N=CC2=CC3=CC=CC=CN=C3C2=N1
#
# NC12C=S1C1=CC1=CC=C2SCC=S
#
# NN=CC1=CC=CSC=C1N=CS
#
# O=NCC=CCOC1=CC(=S)C=C1
#
# CN1C=CC=NN=CN=c2ncccc2=NNS1
#
# COC1=NC2=CC=CC1=C1SC=CSS2S1
#
# NC1=CC=CC=C2C=CN=CC=C2SCSS1
#
# O=C1[C]=CC=CC=CC=CN=CC=C1
#
# NC1=c2ncccc2=C2C=CC=CC=C(C=C2)CC=N1
#
# NC1=C(C=S)C=CN=CC=CC1=S
#
# NC1=CC=CC=CC=CC(=NS1)[C]=O
#
# O=C1[C]=CC=CC2=CC=CC=CC=CC=NN=CN=CC=C12
#
# NC=NC1=CN=CC=CC=CC(=O)C=NN1
#
# N=C1C=CC=CC=C2C=CC3=NC=CC=CC=CC3=CC=C2N1
#
# CC1=CC=CC=CC=CC=NNC=C=NC=C1
#
# OOc1nc2=CC=c2ncc1=S
#
# ONN=C1C=CC=CN=CSN=NS1
#
# N=c1scc2cc2cc2cc1cnncs2
#
# O=C1C=C(C=S)C=CSC=SC=CCC1
#
# ONN1CSC=C=C(C=S)N=N1
#
# O=c1cc[nH]c2-c(c2)c2c(n1)N=CC=NC=CC=CC=C2
#
# O=NN=SNn1c2-c(ccc2)cccc1=O
#
# O=c1nc2c(=C[C]2)cc2c1=CC=N2
#
# C=c1cc2c(=N)ccc1=CC=CC=CC=C1C=CC=CN1C2
#
# OCC=C1C=CC(=S)SSS=CS=C1
#
# O=Cc1ccc2=CC=CC=CC=CC=CC=c2c1
#
# O=C1C=CC=CC=CC2=NC=CS12S
#
# O=CC1=c2ccc(=CC=C1)nn[nH]cn2
#
# NC1=CC(=S)C=CC=CC=CC=CC=C1
#
# S=C1N=CC=C2C=C2C=CSSSS1
#
# O=CC1=NSC=NC=CS=CSNC=CC=CC=C1
#
# O=C[C]1C=CC(=S)SC=CN=C1
#
# SSC1=CC=CC=CC=CC=NC=CC=CC=C1
#
# N=CS=C1C(=S)CCC1=SS
#
# O=C=NC1=C2C=CC=CC=[C]C=CC2=C1
#
# N=C1C=CC=CC=CC2=NC=CC12S
#
# O=c1ccc2=C=C3c(cc2=CCC3)nncn1
#
# O=C1C=c2sccc2=CC=CC=C2SC=C12
#
# Cc1ccc2c(N)cc[nH]c1C=CC=NC=CN=CC=CC=C2
#
# C1=COC=c2ccccc3cccn3ncc2=N1
#
# O=C1C=CC=CC=CC=NN=NSS1=S
#
# C=C1C=c2ccc3c4c2=CC2(S=C2SC)C1=C34
#
# NS1=CSC=CC=CC=c2ccsc2=CC1=O
#
# C1=CC=CC=Cc2nn[nH]oc3cc2ccc=13
#
# C=c1nc2C=CC=CC=Cc3c(c[nH]ssc13)cc2
#
# N=C1C=CC=CC=C(N)C1=CC=SS
#
# O=CC1=C(c2cc3=c(o3)c2=O)C=C=CSC=C1
#
# CSC1=CC=CC=CC=C(CSSS)S1C
#
# C=CC1=C2[C]C=C=C1N=C2SS
#
# CC1=CC=C=C(N=O)N=NN=NC1
#
# NCCN1NS1CC(=O)C=SS=O
#
# NC1=CC=c2ccccc2=NC=CC1=S
#
# O=CC1=C2C(=[C]C=CC=CC=C2)C=CC=C1
#
# O=C1C=CC=CC=CC2=CC3=C2C=CC3=C1
#
# [CH]C=C1C=CC=CSC1=NC
#
# O=SC1=NC=S2C=CSC2=CC=CC=C1
#
# OCC1=C=CC=CC=CC=C1C1=S=S1
#
# O=C(O)CCC1=CC=CC=CC=CC=CS1
#
# Nc1ccc2-c1c1=CC=c1ccc2
#
# S=C1C=CSC2=C=CC(=S12)S
#
# CSC1=CC=CC=CC=CC=C2C=C1N(S)S2
#
# C=C=SC1=CC=CC=CC2=C1C2=S
#
# O=CC1=CC=CC=CC=CN[C]SS1
#
# O=c1c2-c(ccc2)ccccnc1=S
#
# NCc1cnccccc2-c3nccccc1c2cn3
#
# O=C1C=CC=c2ccccc2=CN=CC=CN1
#
# S=C1C=C2C=CC=CC=CN=CC=CC=C12
#
# Nn1cccc2c(cccccnc1)C=CC=CC=C2
#
# C=CC1=Cc2cc3=Cc3cc2=C=C=CC=C1
#
# O=C1C=CN=c2ccccc2=CC=CC=NC1
#
# Sn1ccccc2c(s1)N=NC=CN=CC=CN2
#
# NCC1=CC=CSON=C(SS)SSS1
#
# N=C1C=CC(=S)SNSSNC=CS1
#
# O=CC1=C=C2C=C2N=C2SNSSC=C12
#
# NC1=CC=CC2=C(N=S)C=CSC1=C2
#
# O=C1C=CSC2=C[N]SSC=C2S1
#
# OSC1=CC=c2cccnccccc2=CC=N1
#
# [C]=CC=C1CC1CCCSN=O
#
# O=CN[N][C]C1=C=c2ccccc2=N1
#
# O=c1ccc2-n1cnccsccc2
#
# S=C=SC1=CC=C(CS=S)CSSS1
#
# O=CCSSc1ccc2-c1ccccc2
#
# [N][N]c1cc2=CC=NC=CC=CN=CN=c2[nH]1
#
# S=C1[C]=CSC2=C1C=NC=CC=CC=CS2
#
# CN=CC1=CC=CC=[C]SCNS1=N
#
# SC1=CN=c2ccscc[nH]c2=CS1
#
# CC1=c2occc2=CSN=CS=C=CC=NN=C1
#
# NNC=CC1=C(C=O)C=CC=CSSNNS1
#
# CC1=Nc2cc3=CC=NC=c2c1ccccc3N
#
# CCc1cccc2=CC=CC=CC=c2c1=O
#
# O=C1C=Nc2ccc3c(=CC=C3)c2=C1
#
# C=C1C=CC=C2C=CC=C=SS2=N1
#
# O=C1[C]=C=C2C1=CSC2S
#
# [N][C]C1=CC=NC=CC1
#
# S=C1C=CC=C=Sc2ccccc2SS1
#
# C=C=CSC=C(CS=SO)SSSC
#
# O=CC1=NC=CC=C=C=CC=CC=CC=C2SN2C=C1
#
# CN1C=CC=CC=CS=SC(=O)C1
#
# SNC1=CC=CN=CC=CSSSC=CC=C=C1
#
# CNC1C=C=C2C=C2C=CC=C1S=N
#
# NN=C1[C]=C2C=CN=CC=CC=C12
#
# C1=CC=C2S=CSN=CC=CC=C2C=C1
#
# CC1=C=c2cnc(=CN=C1)cc1-c(c1)nc2CC=O
#
# O=C1C=CN=CC=CC=CS2=CC=CC2=CS1
#
# CC1=CC=CSC(=CC=CC=CSN=N1)N
#
# NNC[N]c1ccc2-c1ccccc2
#
# O=C1[C]=C2C(=C2)C=C2N3C=C2C1=NC3
#
# NC1=NN2C(=CC=C1)C=CN=CC=CC=CC=C2
#
# N=c1c2ccccc3ccc(c1c2)ccccc3N
#
# NN1C2=CC=CC=CN=NC=[C]N12
#
# OSC1=CC=CC=CC=CC=C2C=CSC=C12
#
# CN=c1cccccc2-c(ccccc2)s1
#
# N=C1C=CN=CC=NN=NC=C2C=CC12N
#
# C1=CC=CN=c2ccc(=CC=C1)cnncnc2
#
# NC=NC1=C(C=S)C=CC=CNSC=C1
#
# NC=CC=C=NC1=C2C3=C=C1C=NN23
#
# CC1=CC2=CC=C(S)C=CC2=C=S1
#
# C=C1C=CC=CC1=SSC=SSC=S
#
# N=c1nc2-c1cccc1=CN=CC=NN=CC=c2cc1
#
# NC1=C(C2=CC=CC=CSC=CSC=CS2)S1
#
# O=C1C=c2ccncc2=CC2=C(SN=NC1)S2
#
# COC1=CC=CC=CC=C(N=O)NCSSC=C1
#
# C=C1C=C2C=CC=CC=C2C=CC=CSS1
#
# CC1=CC2=CC=CC=C=NC=CC=S2SC1
#
# COc1ccc2=CC=CC=CC=c2snnn1
#
# N=c1cc2cc[nH]nccc1C=C=C=CC=C2
#
# CC1=CC=CC=CC=C2N=CCN3C=CSC23N=C1
#
# O=CC1=C2NC=NN=c3ncnnc3=S12
#
# N#CC1=C2C=CC2=C=NC2=SSN=C12
#
# N=C1CC2=C(C=N2)N=CC=CC=CSSSSN1
#
# Nc1cc2=CC=c2cccc2-c(c2)c1=O
#
# SCCC1=C2C=C(C=c3ccccc3=C2)SN=C1
#
# CCC(=SC1=CC=CC1=S)CS=S
#
# C=CC1=CS=SC=CC=CC=C1OC
#
# N=C1C=CSC2=C3C=CSC=C3S2=C1
#
# S#SC1=C2C=CC=C2C=CC=CS1
#
# O=C1C=CC2=CC=C2C=CSS=S1
#
# NOCc1cc2-c1c1-c(c(cc2)N=O)n1
#
# C=c1c(=O)n2cccncc3c1cc2=NC=NC=CC=C3
#
# [C]1C=CC=CS=C=CC=C[CH]C1
#
# O=C1C=CC=CC=CC=CC2=CC=NC2=C1
#
# CNC1=COCC2=CC=CC=CC3=C(C3)SC=CC2=C1
#
# O=CC1=S2CSC=CC=C2C=CC=CC=C1
#
# O=C1C=CC=C2C=CC=C2C1=S
#
# O=C1C=CC=CC=CN2SSN=C2S1
#
# O=C1C=[C]C2=NC=CC=CC2=CC=C2N=C12
#
# [N]=C=C(CCC=CO)N[O]
#
# C1=CC=C2C=CC=CSC2=CC=CS=1
#
# N=C1C=C=NC=CN=CC2=CC(=N)C(=CC=C1)CCNN2
#
# S=C1C=CC=CC=CC=CNSSS1
#
# NC1=C=C=C(CS=S)CC=CC=C1
#
# C1=c2cccccc3-c(c[nH]s3)c2=C1
#
# O=C1C=CC=CC=CC2=CN=CC12S
#
# S=C1C=CC=CN=CC2=CC=CC=CC2=C1
#
# N=c1cccc2c(c3-c1ccc3)SSC=C2
#
# C=NC1=CC=CC=CC=C=C(S)SSS1
#
# C1=CC=CSC=CC2=C(C=CCSC=NC=C1)S2
#
# O=c1ccccc2=C=C=C(C=c2cnnc1)O
#
# O=C1C=C=C2CCNN=C=C=C2C=CC2=COC1C2
#
# ON1C=CC=CC=CC=CN=CC=[C-]S1
#
# SN=c1c2-c(c3=CC=CSc23)c2c1=C2
#
# SC1=CC=Cc2n[nH]cc2C=CSSC1
#
# N=NC1=C2C(=C=C=C2S1)C=S
#
# C=CC1=CC=CSSCCC=CNCSS1
#
# CSC1=CC=CC=CC=C1[C]SCC=O
#
# S=c1ccccc2=CSSS=NC=c12
