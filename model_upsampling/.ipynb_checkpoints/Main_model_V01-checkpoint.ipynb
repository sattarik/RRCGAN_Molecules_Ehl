# %%
# Strategy 1:
# Generate data after each epoch of training, if less than
# 10% error rate, and is a legit SMILES
# append to the real data
# Otherwise, append to fake data

# ADDING REINFORCEMENT MECHANISM
# Regenerate Normal sampling (define ranges), default: uniform

# IMPORTANT!!!!!!!!!!!!! DO NOT DROP DUPLICATE FOR RESULT .CSV

import warnings
warnings.filterwarnings('ignore')

import time
import os
import re
import pandas as pd
import random

import matplotlib as mpl
from matplotlib import rc, rcParams

import numpy as np
from numpy import ndarray

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score
from scipy.stats import truncnorm

import multiprocessing
import pickle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import (Input, Dropout, LSTM, Reshape, LeakyReLU,
                          Concatenate, ReLU, Flatten, Dense, Embedding,
                          BatchNormalization, Activation, SpatialDropout1D,
                          Conv2D, MaxPooling2D, UpSampling2D, Lambda)
from tensorflow.keras.models     import Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses     import mse, binary_crossentropy
import tensorflow.keras.backend as K
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.metrics import  mean_squared_error as mse_keras
from tensorflow.keras.backend import argmax as argmax
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow import one_hot
from tensorflow.keras.models import Sequential 

from tensorflow.keras.utils import  to_categorical
from tensorflow import random as randomtf

from IPython.display import clear_output
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.lines as mlines
from   matplotlib.lines import Line2D
from   matplotlib.colors import ListedColormap
import matplotlib.ticker as tk

from progressbar import ProgressBar
import seaborn as sns

from chainer_chemistry.dataset.preprocessors import GGNNPreprocessor, construct_atomic_number_array
preprocessor = GGNNPreprocessor()
from rdkit import rdBase
rdBase.DisableLog('rdApp.error')
from rdkit import Chem

import ntpath
from scipy.stats import truncnorm

""" fix all the seeds,results are still slighthly different """
randomtf.set_seed(10)
os.environ['PYTHONHASHSEED'] = '10'
np.random.seed(420)
random.seed(123450)
from progressbar import ProgressBar
#gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.3667)
#session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1, gpu_options=gpu_options)
#tf.set_random_seed(1234)
#sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
#K.set_session(sess)
# Out:
# 2023-04-18 13:24:39.379015: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-18 13:24:39.438301: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-18 13:24:39.772207: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2023-04-18 13:24:39.772247: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2023-04-18 13:24:39.772250: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8)
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1, gpu_options=gpu_options)
tf.compat.v1.set_random_seed(1234)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)
# Out:
# 2023-04-18 13:24:40.396249: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-18 13:24:40.435086: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-18 13:24:40.439725: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-18 13:24:40.439837: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# WARNING:tensorflow:From /tmp/ipykernel_385871/3769586680.py:5: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# 2023-04-18 13:24:40.745705: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-18 13:24:40.745839: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-18 13:24:40.745901: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-18 13:24:40.745954: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 19394 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
tf.compat.v1.keras.backend.clear_session()

# %%
# check the font !!!!!!!!!!!!!!!!!!!!!
# switch to Arial
# if not working: delet ~/.catch/matplotlib
plt.rcParams["font.family"] = "Arial"
plt.rcParams['ps.useafm'] = True
plt.rcParams['pdf.fonttype'] = 42
mpl.font_manager.FontManager()

rc('font', weight='bold')
fig, ax = plt.subplots(figsize=(5, 4))
plt.scatter([10, 55], [10, 55])
ax.tick_params(axis='both', length=0, width=1.5, colors='black', grid_alpha=0, labelsize=20)
plt.xlabel('!!!Ariaaaal', fontname='Arial', fontsize=50)
# Out:
# Text(0.5, 0, '!!!Ariaaaal')

# %%
""" reading and preprocessing data"""
with open('./../data/trainingsets/60000_train_regular_pubqc/image_train.pickle', 'rb') as f:
    X_smiles_train0, SMILES_train0, y_train00 = pickle.load(f)
    
with open('./../data/trainingsets/60000_train_regular_pubqc/image_test.pickle', 'rb') as f:
    X_smiles_val0, SMILES_val0, y_val00 = pickle.load(f)

with open('./../data/trainingsets/60000_train_regular_pubqc/tokenizer.pickle', 'rb') as f:
    tokenizer = pickle.load(f)
tokenizer[0] = ' '

print (X_smiles_train0.shape)
print (X_smiles_val0.shape)
# Out:
# (98190, 40, 26, 1)
# (24547, 40, 26, 1)

# %%
# reduce the number of samples
# subsampling
idx = np.random.choice(len(y_train00), int(len(y_train00) * 1), replace = False)

X_smiles_train, SMILES_train, y_train0 = (X_smiles_train0[idx], SMILES_train0[idx], y_train00[idx])


idx = np.random.choice(len(y_val00), int(len(y_val00) * 1), replace = False)

X_smiles_val, SMILES_val, y_val0 = (X_smiles_val0[idx], SMILES_val0[idx], y_val00[idx])

print (X_smiles_train.shape)
print (X_smiles_val.shape)
# Out:
# (98190, 40, 26, 1)
# (24547, 40, 26, 1)

# %%
fig, ax = plt.subplots(figsize=(5, 4))

ax.tick_params(axis='both', length=4, width=2, colors='black', grid_alpha=0, labelsize=15)
[i.set_linewidth(2) for i in ax.spines.values()]
plt.xlabel('HOMO-LUMO gap (eV)', fontname='Arial', fontweight = 'bold', fontsize=15)
plt.ylabel('% of samples', fontname='Arial', fontweight = 'bold', fontsize=15)

sns.histplot (y_train0, color='red', label='train', stat='percent', kde=True, bins=50)
sns.histplot (y_val0, color='blue', label='test', stat='percent', kde=True, bins=50, alpha=0.5)
plt.legend()
plt.tight_layout()
plt.savefig('gap_test_train.jpeg', dpi=500)

# %%
""" models definition and extracting pretrained encoder and decoder """
encoder = load_model('./../data/nns/keep/encoder.h5')
decoder = load_model('./../data/nns/keep/decoder.h5')

class Config:
    
    def __init__(self):
        self.Filters = [256, 128, 64]
        self.genFilters = [128, 128, 128]
        self.upFilters = [(2, 2), (2, 2), (2, 2)]
        
config = Config()

## Generator 
z = Input(shape = (128, ))
y = Input(shape = (1, ))

h = Concatenate(axis = 1)([z, y])
h = Dense(1 * 1 * 128)(h)
R1 = Reshape([1, 1, 128])(h)
R2 = Reshape([1, 1, 128])(h)

for i in range(3):
    R1 = UpSampling2D(size = config.upFilters[i])(R1)
    C1 = Conv2D(filters = config.genFilters[i], 
               kernel_size = 2, 
               strides = 1, 
               padding = 'same')(R1)
    B1 = BatchNormalization()(C1)
    R1 = LeakyReLU(alpha=0.2)(B1)

for i in range(3):
    R2 = UpSampling2D(size = config.upFilters[i])(R2)
    C2 = Conv2D(filters = config.genFilters[i], 
               kernel_size = 2, 
               strides = 1, 
               padding = 'same')(R2)
    B2 = BatchNormalization()(C2)
    R2 = LeakyReLU(alpha=0.2)(B2)
    
R1 = Conv2D(1,
            kernel_size = 3,
            strides = 1,
            padding = 'valid',
            activation = 'tanh')(R1)
R2 = Conv2D(1,
            kernel_size = 3,
            strides = 1,
            padding = 'valid',
            activation = 'tanh')(R2)

generator = Model([z, y], [R1, R2])
print (generator.summary())

## Discriminator 
inp1 = Input(shape = [6, 6, 1])
inp2 = Input(shape = [6, 6, 1])

X1 = Concatenate()([inp1, inp2])
X = Flatten()(X1)
y2 = Concatenate(axis = 1)([X, y])
for i in range(3):
		y2 = Dense(64, activation = 'relu')(y2)
		y2 = LeakyReLU(alpha = 0.2)(y2)
		y2 = Dropout(0.2)(y2)

O_dis = Dense(1, activation = 'sigmoid')(y2)


discriminator = Model([inp1, inp2, y], O_dis)
discriminator.compile(loss = 'binary_crossentropy', optimizer = Adam(lr = 5e-5, beta_1 = 0.5))
print (discriminator.summary()) 

## Regressor
inp1 = Input(shape = [6, 6, 1])
inp2 = Input(shape = [6, 6, 1])

yr = Concatenate()([inp1, inp2])

tower0 = Conv2D(32, 1, padding = 'same')(yr)
tower1 = Conv2D(64, 1, padding = 'same')(yr)
tower1 = Conv2D(64, 3, padding = 'same')(tower1)
tower2 = Conv2D(32, 1, padding = 'same')(yr)
tower2 = Conv2D(32, 5, padding = 'same')(tower2)
tower3 = MaxPooling2D(3, 1, padding = 'same')(yr)
tower3 = Conv2D(32, 1, padding = 'same')(tower3)
h = Concatenate()([tower0, tower1, tower2, tower3])
h = ReLU()(h)
h = MaxPooling2D(2, 1, padding = 'same')(h)

for i in range(6):
    tower0 = Conv2D(32, 1, padding = 'same')(h)
    tower1 = Conv2D(64, 1, padding = 'same')(h)
    tower1 = Conv2D(64, 3, padding = 'same')(tower1)
    tower2 = Conv2D(32, 1, padding = 'same')(h)
    tower2 = Conv2D(32, 5, padding = 'same')(tower2)
    tower3 = MaxPooling2D(3, 1, padding = 'same')(h)
    tower3 = Conv2D(32, 1, padding = 'same')(tower3)
    h = Concatenate()([tower0, tower1, tower2, tower3])
    h = ReLU()(h)
    if i % 2 == 0 and i != 0:
        h = MaxPooling2D(2, 1, padding = 'same')(h)
h = BatchNormalization()(h)

yr = Flatten()(h)
o = Dropout(0.2)(yr)
o = Dense(128)(o)

o_reg = Dropout(0.2)(o)
o_reg = Dense(1, activation = 'linear')(o_reg)

regressor = Model([inp1, inp2], o_reg)
regressor_top = Model([inp1, inp2], o)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2023-04-18 13:24:42.089979: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-18 13:24:42.090159: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-18 13:24:42.090218: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-18 13:24:42.090413: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-18 13:24:42.090477: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-18 13:24:42.090526: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-18 13:24:42.090613: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-18 13:24:42.090664: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-18 13:24:42.090702: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 19394 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128)]        0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  concatenate (Concatenate)      (None, 129)          0           ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  dense (Dense)                  (None, 128)          16640       ['concatenate[0][0]']
#
#  reshape (Reshape)              (None, 1, 1, 128)    0           ['dense[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 1, 128)    0           ['dense[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 2, 2, 128)    0           ['reshape[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 2, 2, 128)   0           ['reshape_1[0][0]']
#
#  conv2d (Conv2D)                (None, 2, 2, 128)    65664       ['up_sampling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 2, 2, 128)    65664       ['up_sampling2d_3[0][0]']
#
#  batch_normalization (BatchNorm  (None, 2, 2, 128)   512         ['conv2d[0][0]']
#  alization)
#
#  batch_normalization_3 (BatchNo  (None, 2, 2, 128)   512         ['conv2d_3[0][0]']
#  rmalization)
#
#  leaky_re_lu (LeakyReLU)        (None, 2, 2, 128)    0           ['batch_normalization[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 2, 2, 128)    0           ['batch_normalization_3[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 4, 4, 128)   0           ['leaky_re_lu[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 4, 4, 128)   0           ['leaky_re_lu_3[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 4, 4, 128)    65664       ['up_sampling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 4, 4, 128)    65664       ['up_sampling2d_4[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 4, 4, 128)   512         ['conv2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 4, 4, 128)   512         ['conv2d_4[0][0]']
#  rmalization)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 4, 4, 128)    0           ['batch_normalization_1[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 4, 4, 128)    0           ['batch_normalization_4[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 8, 8, 128)   0           ['leaky_re_lu_1[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 8, 8, 128)   0           ['leaky_re_lu_4[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 8, 8, 128)    65664       ['up_sampling2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 8, 8, 128)    65664       ['up_sampling2d_5[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 8, 128)   512         ['conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 8, 8, 128)   512         ['conv2d_5[0][0]']
#  rmalization)
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 8, 8, 128)    0           ['batch_normalization_2[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 8, 8, 128)    0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 6, 6, 1)      1153        ['leaky_re_lu_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 6, 6, 1)      1153        ['leaky_re_lu_5[0][0]']
#
# ==================================================================================================
# Total params: 416,002
# Trainable params: 414,466
# Non-trainable params: 1,536
# __________________________________________________________________________________________________
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# None
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 6, 6, 1)]    0           []
#
#  input_4 (InputLayer)           [(None, 6, 6, 1)]    0           []
#
#  concatenate_1 (Concatenate)    (None, 6, 6, 2)      0           ['input_3[0][0]',
#                                                                   'input_4[0][0]']
#
#  flatten (Flatten)              (None, 72)           0           ['concatenate_1[0][0]']
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  concatenate_2 (Concatenate)    (None, 73)           0           ['flatten[0][0]',
#                                                                   'input_2[0][0]']
#
#  dense_1 (Dense)                (None, 64)           4736        ['concatenate_2[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 64)           0           ['dense_1[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['leaky_re_lu_6[0][0]']
#
#  dense_2 (Dense)                (None, 64)           4160        ['dropout[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 64)           0           ['dense_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['leaky_re_lu_7[0][0]']
#
#  dense_3 (Dense)                (None, 64)           4160        ['dropout_1[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 64)           0           ['dense_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 64)           0           ['leaky_re_lu_8[0][0]']
#
#  dense_4 (Dense)                (None, 1)            65          ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 13,121
# Trainable params: 13,121
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# Training the Regressor 
# latent vectors from trained Encoder, 
# last output of Encoder is concat. (O1, O2)
train_atoms_embedding, train_bonds_embedding, _ = encoder.predict([X_smiles_train], verbose=0)
atoms_embedding, bonds_embedding, _ = encoder.predict([X_smiles_train], verbose=0)
atoms_val, bonds_val, _ = encoder.predict([X_smiles_val], verbose=0)

# No training if the trained model is saved. 
try:
    regressor =     load_model('./../data/nns/keep/regressor.h5')
    regressor_top = load_model('./../data/nns/keep/regressor_top.h5')
    print (".h5 was read")
except:
    print ("no .h5 available")
    regressor.compile(loss = 'mse', optimizer = Adam(1e-6))
    pass

tf.compat.v1.keras.backend.clear_session()

regressor.compile(loss = 'mse', optimizer = Adam(1e-7))
history = regressor.fit([atoms_embedding, bonds_embedding], 
              y_train0,
              validation_data = ([atoms_val,
                                  bonds_val],
                                 y_val0),
              batch_size = 128,
              epochs = 50,
              verbose = 1)
tf.compat.v1.keras.backend.clear_session()

# Validating the regressor
# Train
pred_train = regressor.predict([atoms_embedding, bonds_embedding], verbose=0)
print('Current R2 on Regressor for train data: {}'.format(r2_score(y_train0, pred_train.reshape([-1]))))
mse_train = mean_squared_error(y_train0, pred_train.reshape([-1]))
mae_train = mean_absolute_error(y_train0, pred_train.reshape([-1]))

#print ('prediction on train: ', pred_train)
#print ('True train: ', y_train0)

# Test
pred = regressor.predict([atoms_val, bonds_val], verbose=0)
print('Current R2 on Regressor for test data: {}'.format(r2_score(y_val0, pred.reshape([-1]))))
mse_test = mean_squared_error (y_val0, pred.reshape([-1]))
mae_test = mean_absolute_error (y_val0, pred.reshape([-1]))

#print ("prediction on test: ", pred )
#print ("True test values: ", y_val0)

print ('Train MSE: {}, RMSE: {}, MAE: {}'.format (round(mse_train, 5), 
                                                  round(mse_train**0.5, 5), 
                                                  round(mae_train, 5)))
print ('Test MSE: {}, RMSE: {}, MAE: {}'.format (round(mse_test, 5), 
                                                  round(mse_test**0.5, 5), 
                                                  round(mae_test, 5)))
# Saving the currently trained models
regressor.save('./../data/nns/keep/regressor.h5')
regressor_top.save('./../data/nns/keep/regressor_top.h5')

"""
# save the losses 
with open ('regressor_loss_0_150.csv', 'w') as f:
    for key in history.history.keys():
        f.write("%s,%s\n"%(key,history.history[key]))
"""
# Out:
# 2023-04-18 13:24:43.574876: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2023-04-18 13:24:44.046148: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# .h5 was read
# Epoch 1/50
# 2023-04-18 13:24:55.363692: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-04-18 13:24:55.364980: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x1ebe0040 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-04-18 13:24:55.364994: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-04-18 13:24:55.368252: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-04-18 13:24:55.406187: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-18 13:24:55.429212: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 768/768 [==============================] - 12s 9ms/step - loss: 0.4085 - val_loss: 0.5242
# Epoch 2/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4312 - val_loss: 0.5239
# Epoch 3/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4302 - val_loss: 0.5239
# Epoch 4/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4317 - val_loss: 0.5240
# Epoch 5/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4293 - val_loss: 0.5240
# Epoch 6/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4305 - val_loss: 0.5244
# Epoch 7/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4279 - val_loss: 0.5243
# Epoch 8/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4294 - val_loss: 0.5239
# Epoch 9/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4298 - val_loss: 0.5242
# Epoch 10/50
# 768/768 [==============================] - 7s 9ms/step - loss: 0.4258 - val_loss: 0.5243
# Epoch 11/50
# 768/768 [==============================] - 7s 9ms/step - loss: 0.4361 - val_loss: 0.5239
# Epoch 12/50
# 768/768 [==============================] - 7s 9ms/step - loss: 0.4370 - val_loss: 0.5239
# Epoch 13/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4359 - val_loss: 0.5239
# Epoch 14/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4359 - val_loss: 0.5239
# Epoch 15/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4348 - val_loss: 0.5240
# Epoch 16/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4357 - val_loss: 0.5239
# Epoch 17/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4347 - val_loss: 0.5239
# Epoch 18/50
# 768/768 [==============================] - 7s 9ms/step - loss: 0.4368 - val_loss: 0.5240
# Epoch 19/50
# 768/768 [==============================] - 7s 9ms/step - loss: 0.4348 - val_loss: 0.5239
# Epoch 20/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4346 - val_loss: 0.5240
# Epoch 21/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4350 - val_loss: 0.5239
# Epoch 22/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4357 - val_loss: 0.5238
# Epoch 23/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4329 - val_loss: 0.5240
# Epoch 24/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4345 - val_loss: 0.5239
# Epoch 25/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4345 - val_loss: 0.5239
# Epoch 26/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4358 - val_loss: 0.5239
# Epoch 27/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4345 - val_loss: 0.5241
# Epoch 28/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4341 - val_loss: 0.5239
# Epoch 29/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4352 - val_loss: 0.5240
# Epoch 30/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4328 - val_loss: 0.5237
# Epoch 31/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4328 - val_loss: 0.5239
# Epoch 32/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4317 - val_loss: 0.5243
# Epoch 33/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4332 - val_loss: 0.5240
# Epoch 34/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4327 - val_loss: 0.5240
# Epoch 35/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4337 - val_loss: 0.5238
# Epoch 36/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4328 - val_loss: 0.5236
# Epoch 37/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4324 - val_loss: 0.5237
# Epoch 38/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4332 - val_loss: 0.5240
# Epoch 39/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4335 - val_loss: 0.5238
# Epoch 40/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4350 - val_loss: 0.5237
# Epoch 41/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4318 - val_loss: 0.5239
# Epoch 42/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4313 - val_loss: 0.5239
# Epoch 43/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4303 - val_loss: 0.5239
# Epoch 44/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4334 - val_loss: 0.5240
# Epoch 45/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4332 - val_loss: 0.5242
# Epoch 46/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4309 - val_loss: 0.5243
# Epoch 47/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4327 - val_loss: 0.5237
# Epoch 48/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4323 - val_loss: 0.5238
# Epoch 49/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4338 - val_loss: 0.5239
# Epoch 50/50
# 768/768 [==============================] - 6s 8ms/step - loss: 0.4350 - val_loss: 0.5241
# Current R2 on Regressor for train data: 0.9236536104818133
# Current R2 on Regressor for test data: 0.8722575385399014
# Train MSE: 0.31263, RMSE: 0.55914, MAE: 0.42951
# Test MSE: 0.52414, RMSE: 0.72397, MAE: 0.54531
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# '\n# save the losses \nwith open (\'regressor_loss_0_150.csv\', \'w\') as f:\n    for key in history.history.keys():\n        f.write("%s,%s\n"%(key,history.history[key]))\n'

# %% [raw]
# fig, ax = plt.subplots(figsize=(5, 4))
# plt.plot(list(range(len(history.history['loss']))),
#          history.history['loss'], label='Training loss', linewidth=3,)
# plt.plot(list(range(len(history.history['val_loss']))),
#          history.history['val_loss'], label='Validation loss', linewidth=3,)
#
# ax.set_xlabel('Epochs', fontsize='20', fontname='Arial', fontweight='bold', labelpad=5)
# ax.set_ylabel('Loss', fontsize='20', fontname='Arial', fontweight='bold', labelpad=5)
#
# ax.tick_params(direction='out', length=5, width=3, colors='black', grid_alpha=1, labelsize='18')
#
# [i.set_linewidth(2) for i in ax.spines.values()]
#
#
# #plt.title ('per {}, rand {}'.format(per, rand))
#
# #plt.ylim(0, 12)
# #plt.xticks((1, 3, 5, 7, 9,  11));
# #plt.yticks((1, 3, 5, 7, 9,  11));
# plt.title('Regressor loss', fontsize=15, fontname='Arial', fontweight='bold', pad=10)
# plt.legend(fontsize=15)
# plt.tight_layout()
# plt.savefig("R_loss_0_100.png", dpi=300)

# %%
fig, ax = plt.subplots(figsize=(5, 4))
plt.rcParams["legend.markerscale"] = 10
plt.scatter (y_train0, pred_train, color='red', label='Train', alpha=0.6, s=0.1)
plt.scatter ( y_val0, pred, color='blue', label='Test', alpha=0.6, s=0.1)

plt.legend()

ax.set_xlabel('DFT gap (eV)', fontsize='20', fontname='Arial', fontweight='bold', labelpad=5)
ax.set_ylabel('Pred. gap (eV)', fontsize='20', fontname='Arial', fontweight='bold', labelpad=5)

ax.tick_params(direction='out', length=5, width=3, colors='black', 
               grid_alpha=1, labelsize='18')

[i.set_linewidth(3) for i in ax.spines.values()]
leg = plt.legend(title='Train: R$^2$={}, MAE={} \nTest: R$^2$={}, MAE={}'.\
           format(round(r2_score(y_train0, pred_train.reshape([-1])), 2), 
                  round (mae_train, 2),
                  round (r2_score(y_val0, pred.reshape([-1])), 2), 
                  round (mae_test, 2), ), framealpha=0, title_fontsize=15)
leg._legend_box.align = "left"

#plt.title ('per {}, rand {}'.format(per, rand))
plt.xlim(0, 12)
plt.ylim(0, 12)
plt.xticks((1, 3, 5, 7, 9,  11));
plt.yticks((1, 3, 5, 7, 9,  11));
plt.plot([0, 12], [0, 12], '--k', )#color='black')
plt.tight_layout()
plt.savefig('regressor_train_test.jpeg', dpi=300)
plt.rcParams["legend.markerscale"] = 1

# %%
K.clear_session()

# %%
## Combined model 
def build_combined(z, y,
                   regressor,
                   regressor_top,
                   discriminator,
                   encoder,
                   decoder):
    discriminator.trainable = False
    regressor_top.trainable = False
    regressor.trainable = False
    encoder.trainable = False
    decoder.trainable = False
    
    atoms_emb, bonds_emb = generator([z, y])
    dec_embedding = Concatenate()([atoms_emb, bonds_emb])
    
    softmax_smiles, _ = decoder([dec_embedding])
    argmax_smiles = argmax (softmax_smiles, axis=2)
    argmax_smiles = Reshape([40])(argmax_smiles)
    smiles = one_hot(argmax_smiles, depth=26)
    smiles = Reshape([40, 26, 1])(smiles)
    latent_encoder_atom, latent_encoder_bond, _ = encoder ([smiles])
    
    y_pred = regressor([latent_encoder_atom, latent_encoder_bond])
    valid = discriminator([atoms_emb, bonds_emb, y])

    combined = Model([z, y], [valid, y_pred])

    combined.compile(loss = ['binary_crossentropy',
                             'mse'], 
                     loss_weights = [1.0, 10.0], 
                     optimizer = Adam(1e-6, beta_1 = 0.5))
    return combined

combined = build_combined(z, y,
                          regressor,
                          regressor_top,
                          discriminator,
                          encoder,
                          decoder)

# %%
p = multiprocessing.Process()
""" Training RCGAN """
# loading pretrained models
#regressor = load_model    ('./../data/nns/regressor.h5')
#regressor_top = load_model('./../data/nns/regressor_top.h5')
#generator = load_model    ('./../data/nns/generator.h5')
#discriminator= load_model ('./../data/nns/discriminator.h5')


regressor_top.trainable = False
regressor.trainable = False

# SMILES related information
max_gen_atoms = 9
bond_max = 9
MAX_NB_WORDS = 26
MAX_SEQUENCE_LENGTH = 40


epochs = 10
batch_size = 256
batches = y_train0.shape[0] // batch_size
threshold = 0.2 # defining accurate samples
reinforce_n = 50 # 5*reinforce_n = fake sampling
reinforce_sample = 1000 # how many samples generated for Reinforcement

# variable for storing generated data
G_Losses = []
D_Losses = []
R_Losses = []
D_Losses_real = []
D_Losses_fake = []

for e in range(epochs):
    start = time.time()
    D_loss = []
    G_loss = []
    R_loss = []
    D_loss_real = []
    D_loss_fake = []
    
    for b in range(batches):
        
        regressor_top.trainable = False
        regressor.trainable = False

        idx = np.arange(b * batch_size, (b + 1) * batch_size)
        # rearrange the samples 
        idx = np.random.choice(idx, batch_size, replace = False)
        
        x_smiles_train = X_smiles_train[idx] 
        batch_y = y_train0[idx]
        
        batch_z = np.random.normal(0, 1, size = (batch_size, 128))
        
        atoms_embedding, bonds_embedding, _ = encoder.predict([x_smiles_train], verbose=0)
        dec_embedding = np.concatenate([atoms_embedding, bonds_embedding], axis = -1)
        
        gen_atoms_embedding, gen_bonds_embedding = generator.predict([batch_z, batch_y], verbose=0)
        
        gen_dec_embedding = np.concatenate([gen_atoms_embedding, gen_bonds_embedding], axis = -1)
        softmax_smiles = decoder.predict(gen_dec_embedding, verbose=0)[0]
        
        argmax_smiles = np.argmax(softmax_smiles, axis = 2)
        smiles = to_categorical(argmax_smiles, num_classes=26)
        SHAPE = list(smiles.shape) + [1]
        smiles = smiles.reshape(SHAPE)
        latent_encoder_atom, latent_encoder_bond, _ = encoder.predict([smiles], verbose=0)
        gen_pred = regressor.predict([latent_encoder_atom, latent_encoder_bond], verbose=0).reshape([-1])
        
        regressor.trainable = True
        r_loss = regressor.train_on_batch([atoms_embedding, bonds_embedding], batch_y)
        R_loss.append(r_loss)
        regressor.trainable = False

        discriminator.trainable = True
        # original was 3!
        d = 3
        #if b<100:
        #    d=1
        for _ in range(d):
            d_loss_real = discriminator.train_on_batch([atoms_embedding, bonds_embedding, batch_y],
                                                       [1 * np.ones((batch_size, 1))])
            d_loss_fake = discriminator.train_on_batch([gen_atoms_embedding, gen_bonds_embedding, batch_y],
                                                       [np.zeros((batch_size, 1))])

        d_loss = 0.5*np.add(d_loss_real, d_loss_fake)
        D_loss.append(d_loss)
        D_loss_real.append (d_loss_real)
        D_loss_fake.append (d_loss_fake)
        discriminator.trainable = False
        
        regressor_top.trainable = False
        regressor.trainable = False

        #for _ in range(d):
        g_loss = combined.train_on_batch([batch_z, batch_y], [1 * np.ones((batch_size, 1)), batch_y])
        G_loss.append(g_loss)
    
    D_Losses.append(np.mean(D_loss))
    D_Losses_real.append(np.mean(D_loss_real))
    D_Losses_fake.append(np.mean(D_loss_fake))
    G_Losses.append(np.mean(G_loss))
    R_Losses.append(np.mean(R_loss))
    
    print('====')
    print('Current epoch: {}/{}'.format((e + 1), epochs))
    print ('D Loss Real: {}'.format(np.mean(D_loss_real)))
    print ('D Loss Fake: {}'.format(np.mean(D_loss_fake)))
    print('D Loss: {}'.format(np.mean(D_loss)))
    print('G Loss: {}'.format(np.mean(G_loss)))
    print('R Loss: {}'.format(np.mean(R_loss)))
    print('====')
    print()

    
    # Reinforcement
    gen_error = []
    gen_smiles = []
    gen_valid_smiles = []
    gen_X_atoms = []
    gen_X_bonds = []
    predcv_AE_latent = []
    embeddings = []
    sample_ys = []
    valid_smiles_index = []
    for _ in range(reinforce_sample):
        sample_y = np.random.uniform(0, 11, size = [1, ])
        sample_y = np.round(sample_y, 4)
        #sample_y = (sample_y - s_min_norm) / (s_max_norm - s_min_norm)
        sample_ys.append(sample_y)

        sample_z = np.random.normal(0, 1, size = (1, 128))

        sample_atoms_embedding, sample_bonds_embedding = generator.predict([sample_z, sample_y], verbose=0)
        embeddings.append((sample_atoms_embedding, sample_bonds_embedding))
        
        dec_embedding = np.concatenate([sample_atoms_embedding, sample_bonds_embedding], axis = -1)
        softmax_smiles = decoder.predict(dec_embedding, verbose=0)[0]
        argmax_smiles = np.argmax(softmax_smiles, axis = 2).reshape([-1])
        smiles = to_categorical(argmax_smiles, num_classes=26)
        SHAPE = [1] + list(smiles.shape) + [1]
        smiles = smiles.reshape(SHAPE)
        c_smiles = ''
        for s in argmax_smiles:
            c_smiles += tokenizer[s]
        c_smiles = c_smiles.rstrip()
        
        if _== 0:
            #print ("Gen. sample Reinforce center from Decoder", smiles)
            print ('"   "   converted to SMILES"',c_smiles)
        gen_smiles.append(c_smiles)
        latent_encoder_atom, latent_encoder_bond, _ = encoder.predict([smiles], verbose=0)
        reg_pred = regressor.predict([latent_encoder_atom, latent_encoder_bond], verbose=0)
        
        pred, desire = reg_pred[0][0], sample_y[0]
        gen_error.append(round (np.abs((pred - desire) / desire), 5))

        
    gen_error = np.asarray(gen_error)
    # two validity defined: 

    # without sanitizing: valid 0    
    valid = 0
    valid0 = 0
    idx_ = []
    idx0_ = []
    for iter_, smiles in enumerate(gen_smiles):
        if ' ' in smiles[:-1]:
            continue
        m  = Chem.MolFromSmiles(smiles[:-1], sanitize=True)
        m0 = Chem.MolFromSmiles(smiles[:-1], sanitize=False)
        if m0 is not None:
            valid0 += 1
            idx0_.append(iter_)
        if m is not None:
            #if len(construct_atomic_number_array(m)) <= 60:
            valid += 1
            idx_.append(iter_)
            try:
                gen_smiles [iter_] = Chem.MolToSmiles(m)
                print (Chem.MolToSmiles(m))
                print ("gap_des", sample_ys[iter_])
                print ("error", gen_error[iter_])
            except:
                pass
    idx_ = np.asarray(idx_)
    idx0_ = np.asarray(idx0_)

    validity = [gen_smiles[jj] for jj in idx0_ ]
    validity = pd.DataFrame(validity)
    validity = validity.drop_duplicates()

    validity_sanitize = [gen_smiles[jj] for jj in idx_ ]
    validity_sanitize = pd.DataFrame(validity_sanitize)
    validity_sanitize = validity_sanitize.drop_duplicates()

    if (e + 1) % 100 == 0:
        reinforce_n += 10

    # invalid smiles:
    fake_indices1 = np.setdiff1d(np.arange(reinforce_sample), np.asarray(idx_))
    fake_indices2 = np.intersect1d(np.where(gen_error > threshold)[0], idx_)
    fake_indices = np.concatenate ((fake_indices1, fake_indices2))
    fake_indices = np.random.choice(fake_indices, reinforce_n * 5, replace = False)

    real_indices_ = np.intersect1d(np.where(gen_error < threshold)[0], idx_)
    sample_size =  len(real_indices_)
    real_indices = np.random.choice(real_indices_, sample_size, replace = False)
    
    # Activating Reinforcement 
    if e >= 5:
        discriminator.trainable = True
        regressor_top.trainable = False
        regressor.trainable = False
        for real_index in real_indices:
            #real_latent = regressor_top.predict([embeddings[real_index][0], embeddings[real_index][1]])
            _ = discriminator.train_on_batch([embeddings[real_index][0], 
                                              embeddings[real_index][1], 
                                              sample_ys[real_index]],
                                             [1 * np.ones((1, 1))])

        for fake_index in fake_indices:
            #fake_latent = regressor_top.predict([embeddings[fake_index][0], embeddings[fake_index][1]])
            _ = discriminator.train_on_batch([embeddings[fake_index][0], 
                                              embeddings[fake_index][1] , 
                                              sample_ys[fake_index]],
                                             [np.zeros((1, 1))])
        discriminator.trainable = False

    # ==== #
    try:
        print('Currently valid SMILES (No chemical_beauty and sanitize off): {}'.format(valid0))
        print('Currently valid SMILES Unique (No chemical_beauty and sanitize off): {}'.format(len(validity)))
        print('Currently valid SMILES Sanitized: {}'.format(valid))
        print('Currently valid Unique SMILES Sanitized: {}'.format(len(validity_sanitize)))
        print('Currently satisfying SMILES: {}'.format(len(real_indices_)))
        print('Currently unique satisfying generation: {}'.format(len(np.unique(np.array(gen_smiles)[real_indices_]))))
        #print('Gen Sample is: {}, for {}'.format(c_smiles, sample_y))
        #print('Predicted val: {}'.format(reg_pred))
        print('====')
        print()
    except:
        pass
    
    if (e + 1) % 5 == 0:
        plt.close()
        fig, ax = plt.subplots(figsize = (12, 10))
        ax.tick_params(axis='both', which='major', labelsize=30)
        plt.plot(G_Losses, color='blue')
        plt.plot(D_Losses, color='red')
        plt.xlabel('epochs', fontsize=35)
        plt.ylabel('loss', fontsize=35)
        mpl.rcParams['axes.linewidth'] = 2.5
        #plt.plot(R_Losses)
        plt.legend(['G Loss', 'D Loss'], fontsize=30)
        plt.savefig("G_D_losses{}.png".format (e+1))
    

    n_unique = len(np.unique(np.array(gen_smiles)[real_indices_]))
    n_valid = valid
    if valid > 450 and n_unique > 350:
        print('Criteria has satisified, training has ended')
        break

    end = time.time()
    print ("time for current epoch: ", (end - start))

    tf.compat.v1.keras.backend.clear_session()
with open('GAN_loss.pickle', 'wb') as f:
    pickle.dump((G_Losses, D_Losses, R_Losses), f)

# Saving the currently trained models
#regressor.save('regressor.h5')
#regressor_top.save('regressor_top.h5')
generator.save('./../data/nns/keep/generator.h5')
discriminator.save('./../data/nns/keep/discriminator.h5')

p.start()

p.join()
print ('Done')
# Out:
# ====
# Current epoch: 1/10
# D Loss Real: 0.01975930156550971
# D Loss Fake: 0.024112757610268987
# D Loss: 0.021936029587889348
# G Loss: 34.402911650709115
# R Loss: 0.4337258876615031
# ====
#
# "   "   converted to SMILES" CN1cccC(CSC=C.
# COC1CCOO1
# gap_des [7.6953]
# error 0.19791
# NC1COC1O
# gap_des [3.1522]
# error 1.60427
# C1CCCCOCCC1
# gap_des [7.6603]
# error 0.16676
# C=CCCOC
# gap_des [10.033]
# error 0.15929
# CCOCCCCCOCC
# gap_des [1.0642]
# error 7.55589
# CCCOCCNN
# gap_des [1.0745]
# error 6.4263
# C1COCCOC1
# gap_des [10.427]
# error 0.21233
# C1CCOCC1
# gap_des [7.2156]
# error 0.19924
# C1CCOCC1
# gap_des [3.1511]
# error 1.76308
# CCOOCCOC
# gap_des [9.0228]
# error 0.29312
# CN1COCN1
# gap_des [8.5943]
# error 0.03259
# CC1CCCO1
# gap_des [8.7224]
# error 0.03923
# COCCCSSSC
# gap_des [2.4253]
# error 1.1773
# CCCCOCC
# gap_des [8.9994]
# error 0.03266
# CC(O)OCCCO
# gap_des [0.6198]
# error 11.97218
# COC1CNC1N
# gap_des [5.0893]
# error 0.65733
# OC1CCO1
# gap_des [0.1916]
# error 44.6112
# N=CCCC1CCC1NN
# gap_des [5.145]
# error 0.01801
# CCCCOCC
# gap_des [8.6518]
# error 0.01731
# CCCOCCOCC
# gap_des [3.6001]
# error 1.36896
# N=CC=C1CCCCS1
# gap_des [0.7859]
# error 5.5528
# OC1=C=CC1
# gap_des [7.8292]
# error 0.29078
# [C]=CC=CC(N)CCc1ccc(C)cc1
# gap_des [8.8111]
# error 0.61308
# COCOCCO
# gap_des [0.921]
# error 9.20462
# CCOCCCCOC
# gap_des [6.2947]
# error 0.36166
# CC1CCCC1
# gap_des [9.8787]
# error 0.07391
# CC1=C=CC=C(CCCO)C(C)CCCC1N
# gap_des [8.0691]
# error 0.36936
# S=C1SSC1S
# gap_des [2.3193]
# error 0.78871
# C=NCCC=NC
# gap_des [10.0616]
# error 0.44913
# OC1CCCO1
# gap_des [10.2913]
# error 0.21884
# CCCCC1OCC2CCCCC1CC2O
# gap_des [8.7933]
# error 0.01884
# COC1CCCC1
# gap_des [9.0736]
# error 0.02841
# CON1CCCCC1
# gap_des [0.6038]
# error 13.0538
# CCCCCCOCC
# gap_des [4.6195]
# error 1.1444
# COCCOCCCCC(C)NO
# gap_des [3.4179]
# error 0.3455
# COCOCC=N
# gap_des [5.5474]
# error 0.43696
# CCOC1CCOOC1
# gap_des [10.8814]
# error 0.12979
# Currently valid SMILES (No chemical_beauty and sanitize off): 68
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 66
# Currently valid SMILES Sanitized: 37
# Currently valid Unique SMILES Sanitized: 35
# Currently satisfying SMILES: 13
# Currently unique satisfying generation: 12
# ====
#
# time for current epoch:  197.6041157245636
# ====
# Current epoch: 2/10
# D Loss Real: 0.0054591088139712834
# D Loss Fake: 0.004886102730397065
# D Loss: 0.005172605772184174
# G Loss: 38.59452904235601
# R Loss: 0.4302843079243254
# ====
#
# "   "   converted to SMILES" Cc1ncc((Cccc(cO)nC1C
# C=NNNNSN
# gap_des [8.5305]
# error 0.48132
# CCC(N)OC(=N)O
# gap_des [5.3236]
# error 0.58778
# CCC1CCN1C=O
# gap_des [5.8941]
# error 0.14437
# CCC1CCCOCC1
# gap_des [3.3546]
# error 1.64015
# CC1CCN1C(C)Cc1ccccc2cccc1-2
# gap_des [4.0893]
# error 0.17979
# OC12CCC(CCO1)OC2
# gap_des [7.2792]
# error 0.26975
# COCC1OCCS1
# gap_des [10.3762]
# error 0.31495
# C=CCCCONCOC
# gap_des [3.1768]
# error 0.42134
# N=C1C=NC=CC(N)C(O)=CC=CO1
# gap_des [0.7512]
# error 3.93654
# NC1=CC(=O)CC(C2CCC2O)CCC1
# gap_des [7.5616]
# error 0.21043
# C=C1SCN1SCO
# gap_des [9.052]
# error 0.44346
# OC1COCON1
# gap_des [6.7586]
# error 0.2163
# OC1=NOC=NC=NC1
# gap_des [0.2779]
# error 19.4195
# COC1CCO1
# gap_des [8.2858]
# error 0.05596
# OC1CCCO1
# gap_des [10.7023]
# error 0.1697
# COCCCCCC=C=CO
# gap_des [10.7476]
# error 0.37153
# C.CN1C=NC=CC=N1
# gap_des [0.5497]
# error 9.2464
# CCCC(C)CC(C)CC(O)(CC)CC
# gap_des [3.3568]
# error 1.37121
# OOC1OCC1O
# gap_des [8.0644]
# error 0.03747
# CCC(=N)C1COC1
# gap_des [8.1084]
# error 0.14111
# CCSOCCCOC
# gap_des [10.7245]
# error 0.3173
# CCOCOSCC1CC(O)C1
# gap_des [10.623]
# error 0.3007
# c1c[nH][nH]ocn1
# gap_des [8.1409]
# error 0.3025
# C=C=C(C)CCCC=C
# gap_des [5.2869]
# error 0.03188
# N#CSC1N=CN=CN=N1
# gap_des [9.433]
# error 0.45944
# COC1CC1N
# gap_des [8.9737]
# error 0.07379
# CCCOOCOC
# gap_des [5.6478]
# error 0.37496
# CC1CS[SH]1O
# gap_des [6.4043]
# error 0.08286
# C1CCCC(CC2CC2)CC1
# gap_des [4.4124]
# error 1.11272
# CC1CSC1C
# gap_des [5.12]
# error 0.12569
# COCSON=[SH]C
# gap_des [9.3305]
# error 0.41522
# N=C(O)OC1CCC1
# gap_des [10.308]
# error 0.28702
# COCC1CC1OC
# gap_des [3.675]
# error 1.14683
# COC(C)N(C)CCCC=O
# gap_des [2.7592]
# error 1.71217
# CNC(C)COC
# gap_des [10.4791]
# error 0.20551
# NC1CC2C(O)CCC12
# gap_des [3.1562]
# error 1.36347
# OCC1=CCCCCCC1
# gap_des [7.0019]
# error 0.07033
# C=C1C=CCCCCC1
# gap_des [5.1885]
# error 0.13599
# CCOCOCOC
# gap_des [8.3589]
# error 0.16477
# CNC1CCC1
# gap_des [8.9949]
# error 0.14159
# CC1C=CCC=C1
# gap_des [4.449]
# error 0.26996
# COC1OCC1C
# gap_des [7.143]
# error 0.23027
# COC1CNC1=O
# gap_des [0.1804]
# error 35.08636
# Currently valid SMILES (No chemical_beauty and sanitize off): 76
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 76
# Currently valid SMILES Sanitized: 43
# Currently valid Unique SMILES Sanitized: 43
# Currently satisfying SMILES: 14
# Currently unique satisfying generation: 14
# ====
#
# time for current epoch:  197.65063428878784
# ====
# Current epoch: 3/10
# D Loss Real: 0.0035306145937260124
# D Loss Fake: 0.003530394781157332
# D Loss: 0.003530504687441672
# G Loss: 41.24406325702983
# R Loss: 0.43163843293414106
# ====
#
# "   "   converted to SMILES" CCOCc)OCc(cCNC)C(N).
# COC(C)OC
# gap_des [5.4645]
# error 0.52516
# NSCSCSO
# gap_des [2.0341]
# error 1.85825
# CC1CCCC2CC=NC2CCC1
# gap_des [4.6344]
# error 0.30861
# CP(C)COCO
# gap_des [9.7713]
# error 0.19451
# CN=C(C)OSC(C)S
# gap_des [9.296]
# error 0.3897
# CCCCCCC(C)CCC
# gap_des [0.6238]
# error 14.66568
# OCCCSC1NOC1=S
# gap_des [8.0087]
# error 0.29096
# C1CNSSC1
# gap_des [8.3636]
# error 0.43261
# CCC#COCSC
# gap_des [10.1586]
# error 0.32368
# C1OSSCSS1
# gap_des [6.8371]
# error 0.27862
# CC1=CC1O
# gap_des [0.4527]
# error 13.13194
# OC1SC1S[SH]1SCC1O
# gap_des [7.7758]
# error 0.18809
# COc1ccsc1
# gap_des [0.4876]
# error 8.94523
# OCSOC1=CS1
# gap_des [3.2674]
# error 0.70924
# C#CN(C#N)C1C2=CC=C1C=CC=C2
# gap_des [9.4573]
# error 0.42642
# COc1[nH]sc1CO
# gap_des [1.2451]
# error 3.1068
# CN=CSC1=CC1
# gap_des [4.5098]
# error 0.04025
# CCCCCC=CCC(C#N)=NOC
# gap_des [10.4403]
# error 0.44277
# C#CSCC1CC1
# gap_des [8.7306]
# error 0.26094
# C=C1CC1=O
# gap_des [9.6551]
# error 0.35894
# C#CCC1OCC=C2OC21
# gap_des [9.5655]
# error 0.48309
# CC1CCC1=O
# gap_des [9.6785]
# error 0.24969
# OC1=CN=C1CCC1C=CC=CC=C1
# gap_des [0.4272]
# error 9.76556
# COCCC1[SH]=CC=C1CNCCCC(C)C
# gap_des [5.3002]
# error 0.14181
# CC1CSCC1N
# gap_des [7.2035]
# error 0.1318
# Currently valid SMILES (No chemical_beauty and sanitize off): 54
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 54
# Currently valid SMILES Sanitized: 25
# Currently valid Unique SMILES Sanitized: 25
# Currently satisfying SMILES: 5
# Currently unique satisfying generation: 5
# ====
#
# time for current epoch:  197.4683666229248
# ====
# Current epoch: 4/10
# D Loss Real: 0.0027831554538489795
# D Loss Fake: 0.0024696242966475335
# D Loss: 0.0026263898752482565
# G Loss: 44.19483603551348
# R Loss: 0.4358934123584558
# ====
#
# "   "   converted to SMILES" CC1CCOC2C[C](O)[)]]]3[[[2]12c121.
# COCC1=CC(O)CC(O)C=C(O)C=C(O)C=C1
# gap_des [8.0221]
# error 0.5291
# CC=COC1CCS1
# gap_des [4.9329]
# error 0.18694
# COc1ccnc(N)c1O
# gap_des [10.3051]
# error 0.55649
# CC[N]C(O)C=NS
# gap_des [6.5159]
# error 0.36963
# C1CN=[SH]SC1
# gap_des [3.2309]
# error 0.4422
# NC1C=C1C=CC=CC=O
# gap_des [9.0076]
# error 0.6122
# CCC(CC=S)CCC(C)C
# gap_des [10.9232]
# error 0.44455
# NCCCC=O
# gap_des [6.8316]
# error 0.00179
# C1=C2C[SH]=NC12
# gap_des [10.8971]
# error 0.62048
# COCC(C)CO
# gap_des [8.5002]
# error 0.02501
# CCOCCCSCC
# gap_des [6.9175]
# error 0.03251
# CC1SSC1O
# gap_des [7.9491]
# error 0.37787
# CC=CCCNNC
# gap_des [10.1479]
# error 0.33501
# CCSOC1NC[C]NN=CC=C1O
# gap_des [2.2103]
# error 0.86216
# CC1CC1CCCCCC1[N]C(O)C=C1O
# gap_des [2.2807]
# error 0.29778
# CC1CCCOO1
# gap_des [9.9029]
# error 0.12022
# O=C1CCC(NCO)NC1
# gap_des [1.8056]
# error 2.57478
# Currently valid SMILES (No chemical_beauty and sanitize off): 36
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 36
# Currently valid SMILES Sanitized: 17
# Currently valid Unique SMILES Sanitized: 17
# Currently satisfying SMILES: 5
# Currently unique satisfying generation: 5
# ====
#
# time for current epoch:  199.9924337863922
# ====
# Current epoch: 5/10
# D Loss Real: 0.002337421126710684
# D Loss Fake: 0.002843040225067969
# D Loss: 0.0025902306758893265
# G Loss: 45.45742540716399
# R Loss: 0.4350976940079084
# ====
#
# "   "   converted to SMILES" N11[n]]=c2nccc1
# C=C1ONNNC1O
# gap_des [10.0474]
# error 0.529
# CCOOCOC
# gap_des [5.9838]
# error 0.52247
# NOCN=[SH]SS
# gap_des [5.7508]
# error 0.23985
# C=[SH]SCCC#N
# gap_des [6.2538]
# error 0.24621
# COSCSCON
# gap_des [9.8691]
# error 0.41837
# C#CCSSSCC
# gap_des [1.9511]
# error 1.19961
# OC1=NCC2C=CC=CC(O)C1O2
# gap_des [8.4113]
# error 0.35549
# C1=C=NC=CSNCCSCC=1
# gap_des [3.5752]
# error 0.27277
# C=CCC1CNC(OC)C(CCCC2CCC2=CCCC)=CO1
# gap_des [1.801]
# error 1.41736
# CCCCC1CC1CCCCOC
# gap_des [5.8952]
# error 0.55076
# CC=C1CCC1ON
# gap_des [10.2107]
# error 0.24781
# COCCC=C1CNCC=CC=CC(C)C(C)NN1
# gap_des [0.2139]
# error 19.11675
# Cc1nccnc1S
# gap_des [8.876]
# error 0.44265
# CC(CNOO)SC(CO)CC#[S]
# gap_des [7.6495]
# error 0.38564
# CCNCOCCC(CC)OC
# gap_des [1.2156]
# error 4.16556
# CNCCOCCCCNC1CC1O
# gap_des [0.1553]
# error 47.18562
# Currently valid SMILES (No chemical_beauty and sanitize off): 36
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 36
# Currently valid SMILES Sanitized: 16
# Currently valid Unique SMILES Sanitized: 16
# Currently satisfying SMILES: 0
# Currently unique satisfying generation: 0
# ====
#
# time for current epoch:  201.46458959579468
# ====
# Current epoch: 6/10
# D Loss Real: 0.0024024488282820113
# D Loss Fake: 0.0021277157495452723
# D Loss: 0.0022650822889136416
# G Loss: 46.67098245795028
# R Loss: 0.43336880323781046
# ====
#
# "   "   converted to SMILES" COC1CNC1CNOO
# COC1CNC1CNO
# gap_des [1.0102]
# error 5.6093
# NC1=CC=CSC=C1
# gap_des [4.3388]
# error 0.17254
# C=C1C=COC(N)C=CC=C1OO
# gap_des [9.0929]
# error 0.45787
# CC(CO)OCCOCC#N
# gap_des [1.9683]
# error 3.03156
# COCCSCSNO
# gap_des [8.9712]
# error 0.39585
# NOC1=CC=NC=NC=CC=C(N)C#C1
# gap_des [5.2915]
# error 0.17884
# CCCNCC1CCCC1(CN)C1CC1N
# gap_des [5.5705]
# error 0.10673
# CCNC=CC=N
# gap_des [6.2271]
# error 0.34887
# CCOCCC=CCNC
# gap_des [0.5168]
# error 11.58244
# OC1=C=CC=[SH]1
# gap_des [8.8124]
# error 0.51148
# Currently valid SMILES (No chemical_beauty and sanitize off): 38
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 38
# Currently valid SMILES Sanitized: 10
# Currently valid Unique SMILES Sanitized: 10
# Currently satisfying SMILES: 3
# Currently unique satisfying generation: 3
# ====
#
# time for current epoch:  201.80117297172546
# ====
# Current epoch: 7/10
# D Loss Real: 0.005526743543398288
# D Loss Fake: 0.0063891433866016135
# D Loss: 0.005957943464999951
# G Loss: 39.89116206638081
# R Loss: 0.4337222218980366
# ====
#
# "   "   converted to SMILES" Cn1ccc(c1NNNCOC)ccc1.
# CC(O)ONC1NC2=C1C2CN
# gap_des [10.9985]
# error 0.47159
# COCCCN
# gap_des [5.1156]
# error 0.63518
# COC1OC1(CN)OC
# gap_des [10.1168]
# error 0.21085
# C=C(CO)CC(N)=NC
# gap_des [9.7395]
# error 0.39498
# Cc1cc1=O
# gap_des [1.126]
# error 3.8803
# CCC1CCC1
# gap_des [4.8751]
# error 0.93087
# CNN=C1CC1CCC#N
# gap_des [7.0924]
# error 0.20435
# CCCOCCCC=COCC
# gap_des [10.9676]
# error 0.41551
# CCCC(O)OCCCNOC
# gap_des [1.9251]
# error 2.63675
# CCC1=NN=CC=NN1C
# gap_des [6.2173]
# error 0.08923
# COC(O)OCO
# gap_des [9.715]
# error 0.01253
# COCC=C(CCOC)COO
# gap_des [8.6344]
# error 0.13856
# C#CCSCCC
# gap_des [10.4237]
# error 0.46744
# C=C1CCN1N
# gap_des [4.7722]
# error 0.23184
# COC1=CC1(OC)OCCC(C)CCCCO
# gap_des [10.2077]
# error 0.4207
# NOCNONO
# gap_des [1.4589]
# error 3.76234
# COCCNCN(C)C
# gap_des [9.4071]
# error 0.09626
# C=C(O)NNCOC
# gap_des [8.5794]
# error 0.23669
# CCC(C)OCCC1CCO1
# gap_des [7.5326]
# error 0.23048
# Currently valid SMILES (No chemical_beauty and sanitize off): 44
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 44
# Currently valid SMILES Sanitized: 19
# Currently valid Unique SMILES Sanitized: 19
# Currently satisfying SMILES: 4
# Currently unique satisfying generation: 4
# ====
#
# time for current epoch:  201.6907606124878
# ====
# Current epoch: 8/10
# D Loss Real: 0.008033382171333276
# D Loss Fake: 0.006206865573987941
# D Loss: 0.007120123872660609
# G Loss: 35.80435799846865
# R Loss: 0.4319542706323977
# ====
#
# "   "   converted to SMILES" Cc1c2c(COCc2O)Cc.
# SC1C2=CC1CC2
# gap_des [10.4843]
# error 0.67194
# CCCNNCO
# gap_des [1.7682]
# error 3.25851
# OC1=CSCC1S
# gap_des [2.4296]
# error 1.07525
# CCN=COC
# gap_des [4.178]
# error 0.32596
# CCOCCCOC
# gap_des [9.7787]
# error 0.05955
# CCCSCCCC#CC=C=CCCOC
# gap_des [4.1579]
# error 0.01806
# [CH]CC=C1CCC=C2C=CC=C21
# gap_des [4.6636]
# error 0.35069
# OC1=NN=C2N=CN=C2OCC1
# gap_des [3.6144]
# error 0.45609
# CSOCN
# gap_des [0.0163]
# error 407.01367
# O=CC=NSCO
# gap_des [7.148]
# error 0.19972
# CC1=CCCCC1C1CCCC1
# gap_des [5.2601]
# error 0.31146
# CCCC=NC
# gap_des [2.8097]
# error 1.41502
# CC(O)CC(=S)CCNN
# gap_des [7.2477]
# error 0.19386
# CC1=NC=C(C#N)C1
# gap_des [6.0526]
# error 0.16579
# C1CCOCC1
# gap_des [5.4287]
# error 0.60296
# CCC1OC(CCOC)N1C
# gap_des [1.1511]
# error 4.41976
# N#CCCSNC[S]
# gap_des [0.0584]
# error 80.87154
# C.C1COC1
# gap_des [3.5157]
# error 1.24602
# CC(CSC#[SH])OCP(C)S
# gap_des [3.2084]
# error 1.00777
# COCCNO
# gap_des [0.7595]
# error 10.04144
# C=C=C=CCN
# gap_des [9.9346]
# error 0.53217
# CC1=NCN=C=CC=N1
# gap_des [3.8042]
# error 0.13642
# OOC1CC1O
# gap_des [0.5857]
# error 11.9269
# NOCCOC1COS1
# gap_des [9.2489]
# error 0.29963
# CCCC1CC1CCCCOC
# gap_des [4.1093]
# error 1.02797
# CCC1(CCCC=C(C)C)CO1
# gap_des [9.1128]
# error 0.1377
# OC1CCS1
# gap_des [3.1671]
# error 0.85642
# OC1CCS1
# gap_des [1.1047]
# error 5.50963
# CN1C=C=C=C1
# gap_des [9.0383]
# error 0.44058
# CC1CCCNCCO1
# gap_des [10.0309]
# error 0.19973
# CC1=CC=CC(C)C1
# gap_des [7.3741]
# error 0.33341
# Nc1cnccn1
# gap_des [5.8221]
# error 0.09199
# C=CC(C)=C=CCC
# gap_des [2.3745]
# error 0.749
# CC(O)COC(C)COCCO
# gap_des [2.8711]
# error 2.23523
# CN=[SH]C1C=CSO1
# gap_des [1.217]
# error 3.84307
# C=C=CCCCSCC
# gap_des [2.5933]
# error 0.78138
# C=NCCC[NH]
# gap_des [1.7285]
# error 0.39546
# SC1C[SH]=N1
# gap_des [0.3151]
# error 14.41063
# CNCCC1C=CC(OC#N)O1
# gap_des [10.8178]
# error 0.39374
# COCC=CC(=N)OC
# gap_des [1.8267]
# error 1.21031
# C=Cc1cncc(N)c1C
# gap_des [4.1309]
# error 0.00489
# Currently valid SMILES (No chemical_beauty and sanitize off): 79
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 78
# Currently valid SMILES Sanitized: 41
# Currently valid Unique SMILES Sanitized: 40
# Currently satisfying SMILES: 10
# Currently unique satisfying generation: 10
# ====
#
# time for current epoch:  202.73444437980652
# ====
# Current epoch: 9/10
# D Loss Real: 0.009422428918464107
# D Loss Fake: 0.009850038409442215
# D Loss: 0.00963623366395316
# G Loss: 32.69868327930142
# R Loss: 0.4314298728583065
# ====
#
# "   "   converted to SMILES" Cc1nc=nc([N]C(=OC((nO)[cH]ccc)cc1.
# C=C=C=CC=N
# gap_des [2.2859]
# error 0.92227
# CC1CC1NCC#CCCC#N
# gap_des [10.8023]
# error 0.3944
# COCCCC1=CC1N
# gap_des [5.1409]
# error 0.26604
# CC=C1CCS1
# gap_des [4.3894]
# error 0.20428
# Cc1ccccc1N
# gap_des [8.8551]
# error 0.46252
# CC(=S)C(C)S
# gap_des [3.0753]
# error 0.90911
# CCC1CCC2NN2OC(O)ON(C)C1
# gap_des [4.0332]
# error 0.98383
# N#CCSC1CCC1
# gap_des [9.2157]
# error 0.47272
# c1cnccn1
# gap_des [6.0766]
# error 0.19771
# C=CCN1CCCC1CC
# gap_des [0.6079]
# error 10.93423
# COC12CCON1OCCC2O
# gap_des [9.4147]
# error 0.29035
# CC1CCC1
# gap_des [6.8077]
# error 0.27006
# CC1=CCCCCC=C1
# gap_des [6.2056]
# error 0.05953
# CC1CC1C1C=CC=C1O
# gap_des [8.2441]
# error 0.25065
# CC1=CC(=NO)C1
# gap_des [0.6012]
# error 7.83224
# COCO
# gap_des [1.8637]
# error 3.41192
# CN1C=CC=CN=CC=CC=N1
# gap_des [5.2907]
# error 0.046
# COC1C=CC=CC(C)=C2ONO[N]C21
# gap_des [7.0359]
# error 0.15862
# COCOOCO
# gap_des [10.159]
# error 0.43609
# CC(S)CSCO
# gap_des [8.0123]
# error 0.38363
# OCC1CS1
# gap_des [0.5109]
# error 11.47675
# N#CCSS[SH]1CC1
# gap_des [3.9477]
# error 0.08201
# COC1CNC1=S
# gap_des [3.2251]
# error 0.69672
# CCCC1=C(C)C=COC=C1
# gap_des [9.9855]
# error 0.48581
# C=C1C=CC=NC1O
# gap_des [0.1203]
# error 40.60271
# C1CNCOC1.O
# gap_des [7.5725]
# error 0.04925
# Currently valid SMILES (No chemical_beauty and sanitize off): 62
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 62
# Currently valid SMILES Sanitized: 26
# Currently valid Unique SMILES Sanitized: 26
# Currently satisfying SMILES: 6
# Currently unique satisfying generation: 6
# ====
#
# time for current epoch:  202.9264693260193
# ====
# Current epoch: 10/10
# D Loss Real: 0.008739978565603684
# D Loss Fake: 0.00817258694414633
# D Loss: 0.008456282754875007
# G Loss: 33.03376983703998
# R Loss: 0.4334612334677196
# ====
#
# "   "   converted to SMILES" c1cc22c2CCC3CccC2O)cc32)c2.
# COCC=C(N)C#CO
# gap_des [10.4434]
# error 0.51975
# CCN=C[SH](C)O
# gap_des [0.1239]
# error 36.80611
# CCCCC1OC(CC)C1CC
# gap_des [2.0605]
# error 3.36038
# CC(C)C1CC1C
# gap_des [3.3667]
# error 1.6781
# C#CC[C]CCN
# gap_des [8.3314]
# error 0.44764
# C1CC2COC2C1
# gap_des [6.3416]
# error 0.18722
# C=CC1OC1O
# gap_des [2.3028]
# error 2.19389
# CC=COSC(C)S
# gap_des [0.0412]
# error 104.52841
# C#CCC=CCCOC
# gap_des [3.8235]
# error 0.65119
# CCC1C(NCNCN)CN1C
# gap_des [9.491]
# error 0.24586
# CCC1OCCCCC1OC
# gap_des [1.5936]
# error 4.38044
# CCC1CCCC1
# gap_des [7.3094]
# error 0.08255
# C#CCCCC(C)C
# gap_des [4.1077]
# error 0.91585
# CN(CCO)CNCCSN
# gap_des [6.5039]
# error 0.01402
# C1CCSSOC1
# gap_des [0.8061]
# error 5.9542
# CCCCCCCNCOC
# gap_des [9.1408]
# error 0.18459
# COC(O)NC1CC1
# gap_des [6.3867]
# error 0.12485
# CCCSC1CCC[SH]1C
# gap_des [8.5217]
# error 0.29335
# CNCCCC1CCC1
# gap_des [4.8169]
# error 0.52692
# CCN=PC
# gap_des [8.4675]
# error 0.17641
# CCOC1CCO1
# gap_des [6.6744]
# error 0.37146
# C=C=C=CCCCC
# gap_des [1.5]
# error 2.60334
# C1=CC=C2CC(ONC=C1)S2
# gap_des [2.2436]
# error 1.04456
# CC1=CCCC1
# gap_des [3.4097]
# error 1.04969
# COCOOC1=C(C)C1
# gap_des [8.4828]
# error 0.00681
# N=CCO[SH](=O)=[SH]C=O
# gap_des [5.2152]
# error 0.056
# CC1SSC1OCN
# gap_des [7.8428]
# error 0.23152
# C1=NCSCCCC1
# gap_des [10.7271]
# error 0.43485
# NN=C1C2=CONCCC21
# gap_des [3.883]
# error 0.43966
# CC1=C=CCCCC2CC(CNC2(C)C)C1C
# gap_des [4.072]
# error 0.21149
# C=CSCCC#N
# gap_des [0.4144]
# error 12.83854
# CCC1=CC=C1OC
# gap_des [9.78]
# error 0.42228
# NC1=CC=C2SCCN2CO1
# gap_des [4.2685]
# error 0.01829
# CC1C=CC=CC=C1
# gap_des [3.2804]
# error 0.72305
# CC=NCOCC(C)CSC
# gap_des [4.8857]
# error 0.29535
# Currently valid SMILES (No chemical_beauty and sanitize off): 91
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 91
# Currently valid SMILES Sanitized: 35
# Currently valid Unique SMILES Sanitized: 35
# Currently satisfying SMILES: 9
# Currently unique satisfying generation: 9
# ====
#
# time for current epoch:  203.47733426094055
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done

# %%
tf.compat.v1.keras.backend.clear_session()

# %%
generator = load_model    ('./../data/nns/keep/generator.h5')
discriminator= load_model ('./../data/nns/keep/discriminator.h5')
pbar = ProgressBar()
max = 0.3

randS = []
rsquaredS = []
MAE_S = []
less20RE_perS = []
output_lenS = []

for rand in pbar(range (190, 191)):  
    N = 75
    n_sample = 100
    gen_error = []
    gen_smiles = []
    sample_ys = []
    preds = []
    gen_atoms_embedding = []
    gen_bonds_embedding = []

    regressor_top.trainable = False
    regressor.trainable = False
    generator.trainable = False
    discriminator.trainable = False

    np.random.seed(rand)

    pbar = ProgressBar()
    for hc in (range(n_sample)):
        try:
            # get it back to original of s_min to s_max
            sample_y = np.random.uniform(np.min ((np.min(y_train0), np.min(y_val0))), 
                                         np.max ((np.max(y_train0), np.max(y_val0))), size=[1,])
            #print (sample_y)
            sample_y = np.round(sample_y, 4)
            sample_y = sample_y * np.ones([N, ])
            #sample_y_ = (sample_y - s_min_norm) / (s_max_norm - s_min_norm)
            sample_z = np.random.normal(0, 1, size = (N, 128))

            regressor_top.trainable = False
            regressor.trainable = False

            sample_atoms_embedding, sample_bonds_embedding = generator.predict([sample_z, sample_y], verbose=0)
            dec_embedding = np.concatenate([sample_atoms_embedding, sample_bonds_embedding], axis = -1)

            softmax_smiles = decoder.predict(dec_embedding, verbose=0)[0]
            argmax_smiles = np.argmax(softmax_smiles, axis = 2)
            #print ('shape argmax_smiles', argmax_smiles.shape)
            smiles = to_categorical(argmax_smiles, num_classes=26)
            SHAPE = list(smiles.shape) + [1] 
            #print ('shape line 767', SHAPE) 
            smiles = smiles.reshape(SHAPE)

            latent_encoder_atom, latent_encoder_bond, _ = encoder.predict([smiles], verbose=0)
            pred = regressor.predict([latent_encoder_atom, latent_encoder_bond], verbose=0).reshape([-1])
            #pred = pred * (s_max_norm - s_min_norm) + s_min_norm

            gen_errors = np.abs((pred - sample_y) / sample_y).reshape([-1])


            smiles = decoder.predict(dec_embedding, verbose=0)[0]
            smiles = np.argmax(smiles, axis = 2).reshape(smiles.shape[0], 40)

            generated_smiles = []
            for S in smiles:
                c_smiles = ''
                for s in S:
                    c_smiles += tokenizer[s]
                c_smiles = c_smiles.rstrip()
                generated_smiles.append(c_smiles)
            generated_smiles = np.array(generated_smiles)
            #generated_smiles = generated_smiles [accurate]
            all_gen_smiles = []
            idx = []
            for i, smiles in enumerate(generated_smiles):
                all_gen_smiles.append(smiles[:-1])

                if ' ' in smiles[:-1]:
                    continue
                #m = Chem.MolFromSmiles(smiles[:-1], sanitize=False)
                m = Chem.MolFromSmiles(smiles[:-1], sanitize=True)
                if m is not None:
                    if len(construct_atomic_number_array(m)) <= 60:
                        idx.append(i)

            idx = np.array(idx)
            all_gen_smiles = np.array(all_gen_smiles)
            #print ('all gen smiels shape', all_gen_smiles.shape)
            #print ('gen_errors shape', gen_errors.shape)
            #print (idx)
            gen_smiles.extend(list(all_gen_smiles[idx]))
            gen_error.extend(list(gen_errors[idx]))
            sample_ys.extend(list(sample_y[idx]))
            gen_atoms_embedding.extend(sample_atoms_embedding[idx])
            gen_bonds_embedding.extend(sample_bonds_embedding[idx])

            preds.extend(list(pred[idx]))
        except:
            #print('Did not discover SMILES for HC: {}'.format(sample_y))
            pass    


    output = {}

    for i, s in enumerate (gen_smiles):
        ss = Chem.MolToSmiles(Chem.MolFromSmiles(s, sanitize=True))
        gen_smiles[i] = ss

    output['SMILES'] = gen_smiles
    output['des_gap'] = sample_ys
    output['pred_gap'] = preds
    output['Err_pred_des'] = gen_error

    plt.close()
    plt.hist(gen_error)
    #plt.savefig("gen_error_hist.png")

    output = pd.DataFrame(output)
    output.reset_index(drop = True, inplace = True)
    #output.to_csv ('./../experiments/regular/Initial_training.csv', index=False)
    ## Statistics  (# pred=True value, Des=prediction)
    # total # of samples
    N = len(gen_error)
    print ('random seed', rand)
    # Explained Variance R2 from sklearn.metrics.explained_variance_score
    explained_variance_R2_pred_des = explained_variance_score(output['des_gap'], output['pred_gap'])
    print ("explained_varice_R2_pred_des", explained_variance_R2_pred_des)
    rsquared = np.round (r2_score (output['des_gap'], output['pred_gap']), 4)
    print ("r squared r**2", rsquared)

    # mean absolute error 
    MAE_pred_des = np.round (mean_absolute_error(output['pred_gap'], output['des_gap']), 4)
    print ("MAE_pred_des", MAE_pred_des)
    # Fractioned MAE, more normalized
    Fractioned_MAE_pred_des = 0
    for pred, des in zip(output['pred_gap'], output['des_gap']):
        Fractioned_MAE_pred_des = Fractioned_MAE_pred_des +  abs(des-pred)/des
    Fractioned_MAE_pred_des = Fractioned_MAE_pred_des/N
    #print ("Fractioned MAE_pred_des", Fractioned_MAE_pred_des)

    # root mean squared error (RMSE), sqrt(sklearn ouputs MSE)
    RMSE_pred_des = mean_squared_error(output['pred_gap'], output['des_gap'])**0.5
    #print ("RMSE_pred_des", RMSE_pred_des)

    Fractioned_RMSE_pred_des = 0
    for pred, des in zip(output['pred_gap'], output['des_gap']):
        Fractioned_RMSE_pred_des = Fractioned_RMSE_pred_des + ((des-pred)/des)**2
    Fractioned_RMSE_pred_des = (Fractioned_RMSE_pred_des/N)**0.5
    #print ("Fractioned_RMSE_pred_des", Fractioned_RMSE_pred_des)

    #output = pd.DataFrame(output)
    # do not drop duplicate
    #output2 = output.drop_duplicates(['SMILES'])
    #gen_atoms_embedding = np.array(gen_atoms_embedding)
    #gen_bonds_embedding = np.array(train_atoms_embedding)

    #output.reset_index(drop = True, inplace = True)
    #output2.reset_index(drop = True, inplace = True)
    #output2.to_csv('./../experiments/regular/Initial_training_nodub.csv', index = False)
    """with open('gen_pickles.pickle', 'wb') as f:
        pickle.dump(gen_unique_pickles, f)
    """
    #print ('% < 20 RE NODUP', sum (output2['Err_pred_des'] < 0.2) / output2['Err_pred_des'].shape[0])
    less20RE_per = np.round ((sum(output['Err_pred_des'] < 0.2) / output['Err_pred_des'].shape[0]), 4)
    print ('% < 20 RE', less20RE_per)
    output_len = len(output)
    explained_variance_R2_pred_des = explained_variance_score(output['des_gap'], output['pred_gap'])
    #print ("explained_varice_R2_pred_des", explained_variance_R2_pred_des)

    randS.append(rand)
    rsquaredS.append(rsquared)
    MAE_S.append(MAE_pred_des)
    less20RE_perS.append(less20RE_per)
    output_lenS.append(output_len)

    if rsquared>max:
        good_rand = rand
        max = rsquared
        best_r2 = rsquared
        print ('best r2', best_r2)
        print ('best random seed', good_rand)
    
    tf.compat.v1.keras.backend.clear_session()

params = {}
params ['rand'] = randS
params ['r2'] = rsquaredS
params ['MAE'] = MAE_S
params ['less20RE_per'] = less20RE_perS
params ['total_valid'] = output_lenS
params = pd.DataFrame(params)
params.reset_index(drop = True, inplace = True)
params.to_csv ('./gen_params.csv', index=False)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 100% |###################################################################################################################################################################|
# random seed 190
# explained_varice_R2_pred_des -0.1420651240949231
# r squared r**2 -0.1708
# MAE_pred_des 2.8467
# % < 20 RE 0.2063

# %%
try:
    print ('best r2', best_r2)
    print ('best random seed', good_rand)
except:
    pass

# %%
plt.scatter (output['des_gap'], output['pred_gap'])
plt.plot([1, 11], [1, 11], '--k', )
