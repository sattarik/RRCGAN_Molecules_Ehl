# %%
# Strategy 1:
# Generate data after each epoch of training, if less than
# 10% error rate, and is a legit SMILES
# append to the real data
# Otherwise, append to fake data

# ADDING REINFORCEMENT MECHANISM
# Regenerate Normal sampling (define ranges), default: uniform

# IMPORTANT!!!!!!!!!!!!! DO NOT DROP DUPLICATE FOR RESULT .CSV

import warnings
warnings.filterwarnings('ignore')

import time
import os
import re
import pandas as pd
import random

import matplotlib as mpl
from matplotlib import rc, rcParams

import numpy as np
from numpy import ndarray

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score
from scipy.stats import truncnorm

import multiprocessing
import pickle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import (Input, Dropout, LSTM, Reshape, LeakyReLU,
                          Concatenate, ReLU, Flatten, Dense, Embedding,
                          BatchNormalization, Activation, SpatialDropout1D,
                          Conv2D, MaxPooling2D, UpSampling2D, Lambda)
from tensorflow.keras.models     import Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses     import mse, binary_crossentropy
import tensorflow.keras.backend as K
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.metrics import  mean_squared_error as mse_keras
from tensorflow.keras.backend import argmax as argmax
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow import one_hot
from tensorflow.keras.models import Sequential 

from tensorflow.keras.utils import  to_categorical
from tensorflow import random as randomtf

from IPython.display import clear_output
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.lines as mlines
from   matplotlib.lines import Line2D
from   matplotlib.colors import ListedColormap
import matplotlib.ticker as tk
from scipy.stats import pearsonr

from progressbar import ProgressBar
import seaborn as sns

from chainer_chemistry.dataset.preprocessors import GGNNPreprocessor, construct_atomic_number_array
preprocessor = GGNNPreprocessor()
from rdkit import rdBase
rdBase.DisableLog('rdApp.error')
from rdkit import Chem

import ntpath
from scipy.stats import truncnorm

""" fix all the seeds,results are still slighthly different """
randomtf.set_seed(1)
os.environ['PYTHONHASHSEED'] = '1'
np.random.seed(42)
random.seed(12345)
from progressbar import ProgressBar
#gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.3667)
#session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1, gpu_options=gpu_options)
#tf.set_random_seed(1234)
#sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
#K.set_session(sess)
# Out:
# 2023-05-31 08:09:29.253434: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-31 08:09:29.373468: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-31 08:09:29.793498: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2023-05-31 08:09:29.793547: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2023-05-31 08:09:29.793550: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.9)
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1, gpu_options=gpu_options)
tf.compat.v1.set_random_seed(1234)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)
# Out:
# 2023-05-31 08:09:30.612904: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-31 08:09:30.623539: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 08:09:30.640379: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 08:09:30.640490: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# WARNING:tensorflow:From /tmp/ipykernel_7124/1543233923.py:5: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# 2023-05-31 08:09:31.039099: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 08:09:31.039419: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 08:09:31.039486: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 08:09:31.039539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21818 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
tf.compat.v1.keras.backend.clear_session()

# %%
# check the font !!!!!!!!!!!!!!!!!!!!!
# switch to Arial
# if not working: delet ~/.catch/matplotlib
plt.rcParams["font.family"] = "Arial"
plt.rcParams['ps.useafm'] = True
plt.rcParams['pdf.fonttype'] = 42
mpl.font_manager.FontManager()

rc('font', weight='bold')
fig, ax = plt.subplots(figsize=(5, 4))
plt.scatter([10, 55], [10, 55])
ax.tick_params(axis='both', length=0, width=1.5, colors='black', grid_alpha=0, labelsize=20)
plt.xlabel('!!!Ariaaaal', fontname='Arial', fontsize=50)
# Out:
# Text(0.5, 0, '!!!Ariaaaal')

# %%
tf.compat.v1.keras.backend.clear_session()
with open('./../data/trainingsets/60000_train_regular_pubqc/tokenizer.pickle', 'rb') as f:
    tokenizer = pickle.load(f)
tokenizer[0] = ' '
with open('./../data/trainingsets/60000_train_regular_pubqc/tokenizer_object.pickle', 'rb') as f:
    tokenizer_ = pickle.load(f)

# %%
with open('./../data/trainingsets/highgap_outliergen_trans1/image.pickle', 'rb') as f:
    X_smiles_gen, SMILES_gen, y_gen = pickle.load(f) 
    
with open('./../data/trainingsets/highgap_outliergen_trans1/image_train.pickle', 'rb') as f:
    X_smiles_train_gen, SMILES_train_gen, y_train_gen = pickle.load(f)
    
with open('./../data/trainingsets/highgap_outliergen_trans1/image_test.pickle', 'rb') as f:
    X_smiles_val_gen, SMILES_val_gen, y_val_gen = pickle.load(f)

# %%
SMILES_gen = np.array (SMILES_gen)
y_gen = np.array (y_gen)

# %%
with open('./../data/trainingsets/highgap_pubqc/image.pickle', 'rb') as f:
    X_smiles_pubqc, SMILES_pubqc, y_pubqc = pickle.load(f) 
    
with open('./../data/trainingsets/highgap_pubqc/image_train.pickle', 'rb') as f:
    X_smiles_train_pubqc, SMILES_train_pubqc, y_train_pubqc = pickle.load(f) 
    
with open('./../data/trainingsets/highgap_pubqc/image_test.pickle', 'rb') as f:
    X_smiles_val_pubqc, SMILES_val_pubqc, y_val_pubqc = pickle.load(f)

# %%
y_pubqc.shape
# Out:
# (861,)

# %%
X_smiles00 = np.concatenate ((X_smiles_pubqc, X_smiles_gen), axis=0)
SMILES00 = np.concatenate ((SMILES_pubqc, SMILES_gen), axis=0)
y_gantrain000 = np.concatenate ((y_pubqc, y_gen), axis=0)
print (y_gantrain000.shape)
print (X_smiles00.shape)
# Out:
# (3732,)
# (3732, 40, 27, 1)

# %%
X_smiles0 = np.concatenate((X_smiles00, 
                            X_smiles00[y_gantrain000>10.2], 
                            X_smiles00[y_gantrain000>10.2], 
                            X_smiles00[y_gantrain000>10.2], 
                            X_smiles00[y_gantrain000>10.5], ), axis=0)
SMILES0 = np.concatenate((SMILES00, 
                          SMILES00[y_gantrain000>10.2], 
                          SMILES00[y_gantrain000>10.2],
                          SMILES00[y_gantrain000>10.2], 
                          SMILES00[y_gantrain000>10.5]), axis=0)
y_gantrain00 = np.concatenate((y_gantrain000, 
                               y_gantrain000[y_gantrain000>10.2], 
                               y_gantrain000[y_gantrain000>10.2],
                               y_gantrain000[y_gantrain000>10.2], 
                               y_gantrain000[y_gantrain000>10.5]), axis=0)

# %%
print (SMILES0.shape)
y_gantrain0 = y_gantrain00[y_gantrain00<=13]
X_smiles = X_smiles0[y_gantrain00<=13]
SMILES = SMILES0[y_gantrain00<=13]
print (SMILES.shape)
# Out:
# (4569,)
# (4554,)

# %%
X_smiles_train00 = np.concatenate ((X_smiles_train_pubqc, X_smiles_train_gen), axis=0)
SMILES_train00 = np.concatenate ((SMILES_train_pubqc, SMILES_train_gen), axis=0)
y_train000 = np.concatenate ((y_train_pubqc, y_train_gen), axis=0)
print (y_train000.shape)
print (X_smiles_train00.shape)
# Out:
# (2984,)
# (2984, 40, 27, 1)

# %%
X_smiles_train0 = np.concatenate((X_smiles_train00, 
                                  X_smiles_train00[y_train000>10.2],
                                  X_smiles_train00[y_train000>10.2],
                                  X_smiles_train00[y_train000>10.2],
                                  X_smiles_train00[y_train000>10.5],), axis=0)
SMILES_train0 = np.concatenate((SMILES_train00, 
                                SMILES_train00[y_train000>10.2],
                                SMILES_train00[y_train000>10.2],
                                SMILES_train00[y_train000>10.2],
                                SMILES_train00[y_train000>10.5],), axis=0)

y_train00 = np.concatenate((y_train000, 
                                y_train000[y_train000>10.2],
                                y_train000[y_train000>10.2],
                                y_train000[y_train000>10.2],
                                y_train000[y_train000>10.5],), axis=0)

# %%
y_train0 = y_train00[y_train00<=13]
X_smiles_train = X_smiles_train0[y_train00<=13]
SMILES_train = SMILES_train0[y_train00<=13]
SMILES_train.shape
# Out:
# (3646,)

# %%
X_smiles_val00 = np.concatenate ((X_smiles_val_pubqc, X_smiles_val_gen), axis=0)
SMILES_val00 = np.concatenate ((SMILES_val_pubqc, SMILES_val_gen), axis=0)
y_val000 = np.concatenate ((y_val_pubqc, y_val_gen), axis=0)
print (y_val000.shape)
print (X_smiles_val00.shape)
# Out:
# (748,)
# (748, 40, 27, 1)

# %%
X_smiles_val0 = np.concatenate((X_smiles_val00, 
                                  X_smiles_val00[y_val000>10.2],
                                  X_smiles_val00[y_val000>10.2],
                                  X_smiles_val00[y_val000>10.2],
                                  X_smiles_val00[y_val000>10.5],), axis=0)
SMILES_val0 = np.concatenate((SMILES_val00, 
                                SMILES_val00[y_val000>10.2],
                                SMILES_val00[y_val000>10.2],
                                SMILES_val00[y_val000>10.2],
                                SMILES_val00[y_val000>10.5], ), axis=0)

y_val00 = np.concatenate((y_val000, 
                                y_val000[y_val000>10.2],
                                y_val000[y_val000>10.2],
                                y_val000[y_val000>10.2],
                                y_val000[y_val000>10.5],), axis=0)

# %%
y_val0 = y_val00[y_val00<=13]
X_smiles_val = X_smiles_val0[y_val00<=13]
SMILES_val = SMILES_val0[y_val00<=13]
SMILES_val.shape
# Out:
# (908,)

# %%
sns.histplot(y_train0)
# Out:
# <Axes: ylabel='Count'>

# %%
# Standardized between 0 and 11
gap_min = 0
gap_max = 15
y_val   = (y_val0 -   gap_min) / (gap_max - gap_min)
y_train = (y_train0 - gap_min) / (gap_max - gap_min)
y_gantrain = (y_gantrain0 - gap_min) / (gap_max - gap_min)

y_gantrain0

print (np.max(y_val))
print (np.max(y_train))

print (np.min(y_val))
print (np.min(y_train))

print (np.min(y_gantrain))
print (np.max(y_gantrain))
# Out:
# 0.8099926666666666
# 0.8381111333333333
# 0.6008820666666667
# 0.6011178666666667
# 0.6008820666666667
# 0.8381111333333333

# %%
np.argmax(y_gantrain0)
print (SMILES[1122])
# Out:
# CCCCCC(C)CC(C)CCCC(C)(C)C.

# %%
fig, ax = plt.subplots(figsize=(5, 4))

ax.tick_params(axis='both', length=4, width=2, colors='black', grid_alpha=0, labelsize=15)
[i.set_linewidth(2) for i in ax.spines.values()]
plt.xlabel('HOMO-LUMO gap (eV)', fontname='Arial', fontweight = 'bold', fontsize=15)
plt.ylabel('% of samples', fontname='Arial', fontweight = 'bold', fontsize=15)

sns.histplot (y_train0, color='red', label='train', stat='percent', kde=True, bins=50)
sns.histplot (y_val0, color='blue', label='test', stat='percent', kde=True, bins=50, alpha=0.5)
plt.legend()
plt.tight_layout()
plt.savefig('gap_val_train.jpeg', dpi=500)

# %%
""" models definition and extracting pretrained encoder and decoder """
encoder = load_model('./../data/nns/encoder_trans.h5')
decoder = load_model('./../data/nns/decoder_trans.h5')

class Config:
    
    def __init__(self):
        self.Filters = [256, 128, 64]
        self.genFilters = [128, 128, 128]
        self.upFilters = [(2, 2), (2, 2), (2, 2)]
        
config = Config()

## Generator 
z = Input(shape = (128, ))
y = Input(shape = (1, ))

h = Concatenate(axis = 1)([z, y])
h = Dense(1 * 1 * 128)(h)
R1 = Reshape([1, 1, 128])(h)
R2 = Reshape([1, 1, 128])(h)

for i in range(3):
    R1 = UpSampling2D(size = config.upFilters[i])(R1)
    C1 = Conv2D(filters = config.genFilters[i], 
               kernel_size = 2, 
               strides = 1, 
               padding = 'same')(R1)
    B1 = BatchNormalization()(C1)
    R1 = LeakyReLU(alpha=0.2)(B1)

for i in range(3):
    R2 = UpSampling2D(size = config.upFilters[i])(R2)
    C2 = Conv2D(filters = config.genFilters[i], 
               kernel_size = 2, 
               strides = 1, 
               padding = 'same')(R2)
    B2 = BatchNormalization()(C2)
    R2 = LeakyReLU(alpha=0.2)(B2)
    
R1 = Conv2D(1,
            kernel_size = 3,
            strides = 1,
            padding = 'valid',
            activation = 'tanh')(R1)
R2 = Conv2D(1,
            kernel_size = 3,
            strides = 1,
            padding = 'valid',
            activation = 'tanh')(R2)

generator0 = Model([z, y], [R1, R2])
print (generator0.summary())

## Discriminator 
inp1 = Input(shape = [6, 6, 1])
inp2 = Input(shape = [6, 6, 1])

X1 = Concatenate()([inp1, inp2])
X = Flatten()(X1)
y2 = Concatenate(axis = 1)([X, y])
for i in range(3):
		y2 = Dense(64, activation = 'relu')(y2)
		y2 = LeakyReLU(alpha = 0.2)(y2)
		y2 = Dropout(0.2)(y2)

O_dis = Dense(1, activation = 'sigmoid')(y2)


discriminator0 = Model([inp1, inp2, y], O_dis)
discriminator0.compile(loss = 'binary_crossentropy', optimizer = Adam(lr = 5e-5, beta_1 = 0.5))
print (discriminator0.summary()) 

## Regressor
inp1 = Input(shape = [6, 6, 1])
inp2 = Input(shape = [6, 6, 1])

yr = Concatenate()([inp1, inp2])

tower0 = Conv2D(64, 1, padding = 'same')(yr)
tower1 = Conv2D(64, 1, padding = 'same')(yr)
tower1 = Conv2D(64, 3, padding = 'same')(tower1)
tower2 = Conv2D(32, 1, padding = 'same')(yr)
tower2 = Conv2D(32, 5, padding = 'same')(tower2)
tower3 = MaxPooling2D(3, 1, padding = 'same')(yr)
tower3 = Conv2D(32, 1, padding = 'same')(tower3)
h = Concatenate()([tower0, tower1, tower2, tower3])
h = ReLU()(h)
h = MaxPooling2D(2, 1, padding = 'same')(h)

for i in range(6):
    tower0 = Conv2D(64, 1, padding = 'same')(h)
    tower1 = Conv2D(64, 1, padding = 'same')(h)
    tower1 = Conv2D(64, 3, padding = 'same')(tower1)
    tower2 = Conv2D(32, 1, padding = 'same')(h)
    tower2 = Conv2D(32, 5, padding = 'same')(tower2)
    tower3 = MaxPooling2D(3, 1, padding = 'same')(h)
    tower3 = Conv2D(32, 1, padding = 'same')(tower3)
    h = Concatenate()([tower0, tower1, tower2, tower3])
    h = ReLU()(h)
    if i % 2 == 0 and i != 0:
        h = MaxPooling2D(2, 1, padding = 'same')(h)
h = BatchNormalization()(h)

yr = Flatten()(h)
o = Dropout(0.2)(yr)
o = Dense(128)(o)

o_reg = Dropout(0.2)(o)
o_reg = Dense(1, activation = 'sigmoid')(o_reg)

regressor0 = Model([inp1, inp2], o_reg)
regressor_top0 = Model([inp1, inp2], o)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2023-05-31 08:09:32.978879: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 08:09:32.979040: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 08:09:32.979097: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 08:09:32.979304: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 08:09:32.979379: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 08:09:32.979431: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 08:09:32.979518: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 08:09:32.979571: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 08:09:32.979610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21818 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128)]        0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  concatenate (Concatenate)      (None, 129)          0           ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  dense (Dense)                  (None, 128)          16640       ['concatenate[0][0]']
#
#  reshape (Reshape)              (None, 1, 1, 128)    0           ['dense[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 1, 128)    0           ['dense[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 2, 2, 128)    0           ['reshape[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 2, 2, 128)   0           ['reshape_1[0][0]']
#
#  conv2d (Conv2D)                (None, 2, 2, 128)    65664       ['up_sampling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 2, 2, 128)    65664       ['up_sampling2d_3[0][0]']
#
#  batch_normalization (BatchNorm  (None, 2, 2, 128)   512         ['conv2d[0][0]']
#  alization)
#
#  batch_normalization_3 (BatchNo  (None, 2, 2, 128)   512         ['conv2d_3[0][0]']
#  rmalization)
#
#  leaky_re_lu (LeakyReLU)        (None, 2, 2, 128)    0           ['batch_normalization[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 2, 2, 128)    0           ['batch_normalization_3[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 4, 4, 128)   0           ['leaky_re_lu[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 4, 4, 128)   0           ['leaky_re_lu_3[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 4, 4, 128)    65664       ['up_sampling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 4, 4, 128)    65664       ['up_sampling2d_4[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 4, 4, 128)   512         ['conv2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 4, 4, 128)   512         ['conv2d_4[0][0]']
#  rmalization)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 4, 4, 128)    0           ['batch_normalization_1[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 4, 4, 128)    0           ['batch_normalization_4[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 8, 8, 128)   0           ['leaky_re_lu_1[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 8, 8, 128)   0           ['leaky_re_lu_4[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 8, 8, 128)    65664       ['up_sampling2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 8, 8, 128)    65664       ['up_sampling2d_5[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 8, 128)   512         ['conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 8, 8, 128)   512         ['conv2d_5[0][0]']
#  rmalization)
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 8, 8, 128)    0           ['batch_normalization_2[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 8, 8, 128)    0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 6, 6, 1)      1153        ['leaky_re_lu_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 6, 6, 1)      1153        ['leaky_re_lu_5[0][0]']
#
# ==================================================================================================
# Total params: 416,002
# Trainable params: 414,466
# Non-trainable params: 1,536
# __________________________________________________________________________________________________
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# None
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 6, 6, 1)]    0           []
#
#  input_4 (InputLayer)           [(None, 6, 6, 1)]    0           []
#
#  concatenate_1 (Concatenate)    (None, 6, 6, 2)      0           ['input_3[0][0]',
#                                                                   'input_4[0][0]']
#
#  flatten (Flatten)              (None, 72)           0           ['concatenate_1[0][0]']
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  concatenate_2 (Concatenate)    (None, 73)           0           ['flatten[0][0]',
#                                                                   'input_2[0][0]']
#
#  dense_1 (Dense)                (None, 64)           4736        ['concatenate_2[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 64)           0           ['dense_1[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['leaky_re_lu_6[0][0]']
#
#  dense_2 (Dense)                (None, 64)           4160        ['dropout[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 64)           0           ['dense_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['leaky_re_lu_7[0][0]']
#
#  dense_3 (Dense)                (None, 64)           4160        ['dropout_1[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 64)           0           ['dense_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 64)           0           ['leaky_re_lu_8[0][0]']
#
#  dense_4 (Dense)                (None, 1)            65          ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 13,121
# Trainable params: 13,121
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
discriminator0 = load_model('./../data/nns/keep/discriminator.h5')
generator0 = load_model('./../data/nns/keep/generator.h5')

discriminator0.trainable=True
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# Training the Regressor 
# latent vectors from trained Encoder, 
# last output of Encoder is concat. (O1, O2)
train_atoms_embedding, train_bonds_embedding, _ = encoder.predict([X_smiles_train], verbose=0)
atoms_embedding, bonds_embedding, _ = encoder.predict([X_smiles_train], verbose=0)
atoms_val, bonds_val, _ = encoder.predict([X_smiles_val], verbose=0)

# No training if the trained model is saved. 
try:
    regressor0 = load_model('./../data/nns/keep/regressor.h5')
    regressor_top0 = load_model('./../data/nns/keep/regressor_top.h5')
    regressor0.compile(loss = 'mse', optimizer = Adam(1e-8))
    print (".h5 was read")
except:
    print ("no .h5 available")
    regressor0.compile(loss = 'mse', optimizer = Adam(1e-8))
    pass
# Out:
# 2023-05-31 08:09:34.944382: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2023-05-31 08:09:35.502570: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# .h5 was read

# %%
discriminator0.summary(line_length=200)
# Out:
# Model: "model_1"
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#  Layer (type)                                                     Output Shape                                Param #                 Connected to
# ========================================================================================================================================================================================================
#  input_3 (InputLayer)                                             [(None, 6, 6, 1)]                           0                       []
#
#  input_4 (InputLayer)                                             [(None, 6, 6, 1)]                           0                       []
#
#  concatenate_1 (Concatenate)                                      (None, 6, 6, 2)                             0                       ['input_3[0][0]',
#                                                                                                                                        'input_4[0][0]']
#
#  flatten (Flatten)                                                (None, 72)                                  0                       ['concatenate_1[0][0]']
#
#  input_2 (InputLayer)                                             [(None, 1)]                                 0                       []
#
#  concatenate_2 (Concatenate)                                      (None, 73)                                  0                       ['flatten[0][0]',
#                                                                                                                                        'input_2[0][0]']
#
#  dense_1 (Dense)                                                  (None, 64)                                  4736                    ['concatenate_2[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)                                        (None, 64)                                  0                       ['dense_1[0][0]']
#
#  dropout (Dropout)                                                (None, 64)                                  0                       ['leaky_re_lu_6[0][0]']
#
#  dense_2 (Dense)                                                  (None, 64)                                  4160                    ['dropout[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)                                        (None, 64)                                  0                       ['dense_2[0][0]']
#
#  dropout_1 (Dropout)                                              (None, 64)                                  0                       ['leaky_re_lu_7[0][0]']
#
#  dense_3 (Dense)                                                  (None, 64)                                  4160                    ['dropout_1[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)                                        (None, 64)                                  0                       ['dense_3[0][0]']
#
#  dropout_2 (Dropout)                                              (None, 64)                                  0                       ['leaky_re_lu_8[0][0]']
#
#  dense_4 (Dense)                                                  (None, 1)                                   65                      ['dropout_2[0][0]']
#
# ========================================================================================================================================================================================================
# Total params: 13,121
# Trainable params: 13,121
# Non-trainable params: 0
# ________________________________________________________________________________________________________________________________________________________________________________________________________

# %%
discriminator0.trainable = False
generator0.trainable = False

# %%
discriminator0.summary(line_length=200)
# Out:
# Model: "model_1"
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#  Layer (type)                                                     Output Shape                                Param #                 Connected to
# ========================================================================================================================================================================================================
#  input_3 (InputLayer)                                             [(None, 6, 6, 1)]                           0                       []
#
#  input_4 (InputLayer)                                             [(None, 6, 6, 1)]                           0                       []
#
#  concatenate_1 (Concatenate)                                      (None, 6, 6, 2)                             0                       ['input_3[0][0]',
#                                                                                                                                        'input_4[0][0]']
#
#  flatten (Flatten)                                                (None, 72)                                  0                       ['concatenate_1[0][0]']
#
#  input_2 (InputLayer)                                             [(None, 1)]                                 0                       []
#
#  concatenate_2 (Concatenate)                                      (None, 73)                                  0                       ['flatten[0][0]',
#                                                                                                                                        'input_2[0][0]']
#
#  dense_1 (Dense)                                                  (None, 64)                                  4736                    ['concatenate_2[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)                                        (None, 64)                                  0                       ['dense_1[0][0]']
#
#  dropout (Dropout)                                                (None, 64)                                  0                       ['leaky_re_lu_6[0][0]']
#
#  dense_2 (Dense)                                                  (None, 64)                                  4160                    ['dropout[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)                                        (None, 64)                                  0                       ['dense_2[0][0]']
#
#  dropout_1 (Dropout)                                              (None, 64)                                  0                       ['leaky_re_lu_7[0][0]']
#
#  dense_3 (Dense)                                                  (None, 64)                                  4160                    ['dropout_1[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)                                        (None, 64)                                  0                       ['dense_3[0][0]']
#
#  dropout_2 (Dropout)                                              (None, 64)                                  0                       ['leaky_re_lu_8[0][0]']
#
#  dense_4 (Dense)                                                  (None, 1)                                   65                      ['dropout_2[0][0]']
#
# ========================================================================================================================================================================================================
# Total params: 13,121
# Trainable params: 0
# Non-trainable params: 13,121
# ________________________________________________________________________________________________________________________________________________________________________________________________________

# %%
generator0.summary(line_length=200)
# Out:
# Model: "model"
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#  Layer (type)                                                     Output Shape                                Param #                 Connected to
# ========================================================================================================================================================================================================
#  input_1 (InputLayer)                                             [(None, 128)]                               0                       []
#
#  input_2 (InputLayer)                                             [(None, 1)]                                 0                       []
#
#  concatenate (Concatenate)                                        (None, 129)                                 0                       ['input_1[0][0]',
#                                                                                                                                        'input_2[0][0]']
#
#  dense (Dense)                                                    (None, 128)                                 16640                   ['concatenate[0][0]']
#
#  reshape (Reshape)                                                (None, 1, 1, 128)                           0                       ['dense[0][0]']
#
#  reshape_1 (Reshape)                                              (None, 1, 1, 128)                           0                       ['dense[0][0]']
#
#  up_sampling2d (UpSampling2D)                                     (None, 2, 2, 128)                           0                       ['reshape[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)                                   (None, 2, 2, 128)                           0                       ['reshape_1[0][0]']
#
#  conv2d (Conv2D)                                                  (None, 2, 2, 128)                           65664                   ['up_sampling2d[0][0]']
#
#  conv2d_3 (Conv2D)                                                (None, 2, 2, 128)                           65664                   ['up_sampling2d_3[0][0]']
#
#  batch_normalization (BatchNormalization)                         (None, 2, 2, 128)                           512                     ['conv2d[0][0]']
#
#  batch_normalization_3 (BatchNormalization)                       (None, 2, 2, 128)                           512                     ['conv2d_3[0][0]']
#
#  leaky_re_lu (LeakyReLU)                                          (None, 2, 2, 128)                           0                       ['batch_normalization[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)                                        (None, 2, 2, 128)                           0                       ['batch_normalization_3[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)                                   (None, 4, 4, 128)                           0                       ['leaky_re_lu[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)                                   (None, 4, 4, 128)                           0                       ['leaky_re_lu_3[0][0]']
#
#  conv2d_1 (Conv2D)                                                (None, 4, 4, 128)                           65664                   ['up_sampling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)                                                (None, 4, 4, 128)                           65664                   ['up_sampling2d_4[0][0]']
#
#  batch_normalization_1 (BatchNormalization)                       (None, 4, 4, 128)                           512                     ['conv2d_1[0][0]']
#
#  batch_normalization_4 (BatchNormalization)                       (None, 4, 4, 128)                           512                     ['conv2d_4[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)                                        (None, 4, 4, 128)                           0                       ['batch_normalization_1[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)                                        (None, 4, 4, 128)                           0                       ['batch_normalization_4[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)                                   (None, 8, 8, 128)                           0                       ['leaky_re_lu_1[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)                                   (None, 8, 8, 128)                           0                       ['leaky_re_lu_4[0][0]']
#
#  conv2d_2 (Conv2D)                                                (None, 8, 8, 128)                           65664                   ['up_sampling2d_2[0][0]']
#
#  conv2d_5 (Conv2D)                                                (None, 8, 8, 128)                           65664                   ['up_sampling2d_5[0][0]']
#
#  batch_normalization_2 (BatchNormalization)                       (None, 8, 8, 128)                           512                     ['conv2d_2[0][0]']
#
#  batch_normalization_5 (BatchNormalization)                       (None, 8, 8, 128)                           512                     ['conv2d_5[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)                                        (None, 8, 8, 128)                           0                       ['batch_normalization_2[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)                                        (None, 8, 8, 128)                           0                       ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)                                                (None, 6, 6, 1)                             1153                    ['leaky_re_lu_2[0][0]']
#
#  conv2d_7 (Conv2D)                                                (None, 6, 6, 1)                             1153                    ['leaky_re_lu_5[0][0]']
#
# ========================================================================================================================================================================================================
# Total params: 416,002
# Trainable params: 0
# Non-trainable params: 416,002
# ________________________________________________________________________________________________________________________________________________________________________________________________________

# %%
regressor_top0.trainable = False
regressor0.trainable = False

# %%
generator0.layers.pop()
generator0.layers.pop()

discriminator0.layers.pop()
discriminator0.layers.pop()

# %%
regressor0.layers.pop()
regressor0.layers.pop()
regressor0.layers.pop()
regressor0.layers.pop()
regressor0.layers.pop()

# %%
regressor0.summary(line_length=200)
# Out:
# Model: "model_2"
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#  Layer (type)                                                     Output Shape                                Param #                 Connected to
# ========================================================================================================================================================================================================
#  input_5 (InputLayer)                                             [(None, 6, 6, 1)]                           0                       []
#
#  input_6 (InputLayer)                                             [(None, 6, 6, 1)]                           0                       []
#
#  concatenate_3 (Concatenate)                                      (None, 6, 6, 2)                             0                       ['input_5[0][0]',
#                                                                                                                                        'input_6[0][0]']
#
#  conv2d_9 (Conv2D)                                                (None, 6, 6, 64)                            192                     ['concatenate_3[0][0]']
#
#  conv2d_11 (Conv2D)                                               (None, 6, 6, 32)                            96                      ['concatenate_3[0][0]']
#
#  max_pooling2d (MaxPooling2D)                                     (None, 6, 6, 2)                             0                       ['concatenate_3[0][0]']
#
#  conv2d_8 (Conv2D)                                                (None, 6, 6, 64)                            192                     ['concatenate_3[0][0]']
#
#  conv2d_10 (Conv2D)                                               (None, 6, 6, 64)                            36928                   ['conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)                                               (None, 6, 6, 32)                            25632                   ['conv2d_11[0][0]']
#
#  conv2d_13 (Conv2D)                                               (None, 6, 6, 32)                            96                      ['max_pooling2d[0][0]']
#
#  concatenate_4 (Concatenate)                                      (None, 6, 6, 192)                           0                       ['conv2d_8[0][0]',
#                                                                                                                                        'conv2d_10[0][0]',
#                                                                                                                                        'conv2d_12[0][0]',
#                                                                                                                                        'conv2d_13[0][0]']
#
#  re_lu (ReLU)                                                     (None, 6, 6, 192)                           0                       ['concatenate_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)                                   (None, 6, 6, 192)                           0                       ['re_lu[0][0]']
#
#  conv2d_15 (Conv2D)                                               (None, 6, 6, 64)                            12352                   ['max_pooling2d_1[0][0]']
#
#  conv2d_17 (Conv2D)                                               (None, 6, 6, 32)                            6176                    ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)                                   (None, 6, 6, 192)                           0                       ['max_pooling2d_1[0][0]']
#
#  conv2d_14 (Conv2D)                                               (None, 6, 6, 64)                            12352                   ['max_pooling2d_1[0][0]']
#
#  conv2d_16 (Conv2D)                                               (None, 6, 6, 64)                            36928                   ['conv2d_15[0][0]']
#
#  conv2d_18 (Conv2D)                                               (None, 6, 6, 32)                            25632                   ['conv2d_17[0][0]']
#
#  conv2d_19 (Conv2D)                                               (None, 6, 6, 32)                            6176                    ['max_pooling2d_2[0][0]']
#
#  concatenate_5 (Concatenate)                                      (None, 6, 6, 192)                           0                       ['conv2d_14[0][0]',
#                                                                                                                                        'conv2d_16[0][0]',
#                                                                                                                                        'conv2d_18[0][0]',
#                                                                                                                                        'conv2d_19[0][0]']
#
#  re_lu_1 (ReLU)                                                   (None, 6, 6, 192)                           0                       ['concatenate_5[0][0]']
#
#  conv2d_21 (Conv2D)                                               (None, 6, 6, 64)                            12352                   ['re_lu_1[0][0]']
#
#  conv2d_23 (Conv2D)                                               (None, 6, 6, 32)                            6176                    ['re_lu_1[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)                                   (None, 6, 6, 192)                           0                       ['re_lu_1[0][0]']
#
#  conv2d_20 (Conv2D)                                               (None, 6, 6, 64)                            12352                   ['re_lu_1[0][0]']
#
#  conv2d_22 (Conv2D)                                               (None, 6, 6, 64)                            36928                   ['conv2d_21[0][0]']
#
#  conv2d_24 (Conv2D)                                               (None, 6, 6, 32)                            25632                   ['conv2d_23[0][0]']
#
#  conv2d_25 (Conv2D)                                               (None, 6, 6, 32)                            6176                    ['max_pooling2d_3[0][0]']
#
#  concatenate_6 (Concatenate)                                      (None, 6, 6, 192)                           0                       ['conv2d_20[0][0]',
#                                                                                                                                        'conv2d_22[0][0]',
#                                                                                                                                        'conv2d_24[0][0]',
#                                                                                                                                        'conv2d_25[0][0]']
#
#  re_lu_2 (ReLU)                                                   (None, 6, 6, 192)                           0                       ['concatenate_6[0][0]']
#
#  conv2d_27 (Conv2D)                                               (None, 6, 6, 64)                            12352                   ['re_lu_2[0][0]']
#
#  conv2d_29 (Conv2D)                                               (None, 6, 6, 32)                            6176                    ['re_lu_2[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)                                   (None, 6, 6, 192)                           0                       ['re_lu_2[0][0]']
#
#  conv2d_26 (Conv2D)                                               (None, 6, 6, 64)                            12352                   ['re_lu_2[0][0]']
#
#  conv2d_28 (Conv2D)                                               (None, 6, 6, 64)                            36928                   ['conv2d_27[0][0]']
#
#  conv2d_30 (Conv2D)                                               (None, 6, 6, 32)                            25632                   ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)                                               (None, 6, 6, 32)                            6176                    ['max_pooling2d_4[0][0]']
#
#  concatenate_7 (Concatenate)                                      (None, 6, 6, 192)                           0                       ['conv2d_26[0][0]',
#                                                                                                                                        'conv2d_28[0][0]',
#                                                                                                                                        'conv2d_30[0][0]',
#                                                                                                                                        'conv2d_31[0][0]']
#
#  re_lu_3 (ReLU)                                                   (None, 6, 6, 192)                           0                       ['concatenate_7[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)                                   (None, 6, 6, 192)                           0                       ['re_lu_3[0][0]']
#
#  conv2d_33 (Conv2D)                                               (None, 6, 6, 64)                            12352                   ['max_pooling2d_5[0][0]']
#
#  conv2d_35 (Conv2D)                                               (None, 6, 6, 32)                            6176                    ['max_pooling2d_5[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)                                   (None, 6, 6, 192)                           0                       ['max_pooling2d_5[0][0]']
#
#  conv2d_32 (Conv2D)                                               (None, 6, 6, 64)                            12352                   ['max_pooling2d_5[0][0]']
#
#  conv2d_34 (Conv2D)                                               (None, 6, 6, 64)                            36928                   ['conv2d_33[0][0]']
#
#  conv2d_36 (Conv2D)                                               (None, 6, 6, 32)                            25632                   ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)                                               (None, 6, 6, 32)                            6176                    ['max_pooling2d_6[0][0]']
#
#  concatenate_8 (Concatenate)                                      (None, 6, 6, 192)                           0                       ['conv2d_32[0][0]',
#                                                                                                                                        'conv2d_34[0][0]',
#                                                                                                                                        'conv2d_36[0][0]',
#                                                                                                                                        'conv2d_37[0][0]']
#
#  re_lu_4 (ReLU)                                                   (None, 6, 6, 192)                           0                       ['concatenate_8[0][0]']
#
#  conv2d_39 (Conv2D)                                               (None, 6, 6, 64)                            12352                   ['re_lu_4[0][0]']
#
#  conv2d_41 (Conv2D)                                               (None, 6, 6, 32)                            6176                    ['re_lu_4[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)                                   (None, 6, 6, 192)                           0                       ['re_lu_4[0][0]']
#
#  conv2d_38 (Conv2D)                                               (None, 6, 6, 64)                            12352                   ['re_lu_4[0][0]']
#
#  conv2d_40 (Conv2D)                                               (None, 6, 6, 64)                            36928                   ['conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)                                               (None, 6, 6, 32)                            25632                   ['conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)                                               (None, 6, 6, 32)                            6176                    ['max_pooling2d_7[0][0]']
#
#  concatenate_9 (Concatenate)                                      (None, 6, 6, 192)                           0                       ['conv2d_38[0][0]',
#                                                                                                                                        'conv2d_40[0][0]',
#                                                                                                                                        'conv2d_42[0][0]',
#                                                                                                                                        'conv2d_43[0][0]']
#
#  re_lu_5 (ReLU)                                                   (None, 6, 6, 192)                           0                       ['concatenate_9[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)                                   (None, 6, 6, 192)                           0                       ['re_lu_5[0][0]']
#
#  conv2d_45 (Conv2D)                                               (None, 6, 6, 64)                            12352                   ['max_pooling2d_8[0][0]']
#
#  conv2d_47 (Conv2D)                                               (None, 6, 6, 32)                            6176                    ['max_pooling2d_8[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)                                   (None, 6, 6, 192)                           0                       ['max_pooling2d_8[0][0]']
#
#  conv2d_44 (Conv2D)                                               (None, 6, 6, 64)                            12352                   ['max_pooling2d_8[0][0]']
#
#  conv2d_46 (Conv2D)                                               (None, 6, 6, 64)                            36928                   ['conv2d_45[0][0]']
#
#  conv2d_48 (Conv2D)                                               (None, 6, 6, 32)                            25632                   ['conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)                                               (None, 6, 6, 32)                            6176                    ['max_pooling2d_9[0][0]']
#
#  concatenate_10 (Concatenate)                                     (None, 6, 6, 192)                           0                       ['conv2d_44[0][0]',
#                                                                                                                                        'conv2d_46[0][0]',
#                                                                                                                                        'conv2d_48[0][0]',
#                                                                                                                                        'conv2d_49[0][0]']
#
#  re_lu_6 (ReLU)                                                   (None, 6, 6, 192)                           0                       ['concatenate_10[0][0]']
#
#  batch_normalization_6 (BatchNormalization)                       (None, 6, 6, 192)                           768                     ['re_lu_6[0][0]']
#
#  flatten_1 (Flatten)                                              (None, 6912)                                0                       ['batch_normalization_6[0][0]']
#
#  dropout_3 (Dropout)                                              (None, 6912)                                0                       ['flatten_1[0][0]']
#
#  dense_5 (Dense)                                                  (None, 128)                                 884864                  ['dropout_3[0][0]']
#
#  dropout_4 (Dropout)                                              (None, 128)                                 0                       ['dense_5[0][0]']
#
#  dense_6 (Dense)                                                  (None, 1)                                   129                     ['dropout_4[0][0]']
#
# ========================================================================================================================================================================================================
# Total params: 1,546,593
# Trainable params: 0
# Non-trainable params: 1,546,593
# ________________________________________________________________________________________________________________________________________________________________________________________________________

# %%
new_dense_generator1 = Conv2D(1,
            kernel_size = 3,
            strides = 1,
            padding = 'valid',
            activation = 'tanh', name='mydense1')(generator0.layers[-3].output)

new_dense_generator2 = Conv2D(1,
            kernel_size = 3,
            strides = 1,
            padding = 'valid',
            activation = 'tanh', name='mydense2')(generator0.layers[-4].output)

inp_gen = generator0.input
generator = Model([inp_gen[0], inp_gen[1]], [new_dense_generator1, new_dense_generator2])
print (generator.summary(line_length=150))
# Out:
# Model: "model_4"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                     Param #           Connected to
# ======================================================================================================================================================
#  input_1 (InputLayer)                            [(None, 128)]                    0                 []
#
#  input_2 (InputLayer)                            [(None, 1)]                      0                 []
#
#  concatenate (Concatenate)                       (None, 129)                      0                 ['input_1[0][0]',
#                                                                                                      'input_2[0][0]']
#
#  dense (Dense)                                   (None, 128)                      16640             ['concatenate[0][0]']
#
#  reshape_1 (Reshape)                             (None, 1, 1, 128)                0                 ['dense[0][0]']
#
#  reshape (Reshape)                               (None, 1, 1, 128)                0                 ['dense[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)                  (None, 2, 2, 128)                0                 ['reshape_1[0][0]']
#
#  up_sampling2d (UpSampling2D)                    (None, 2, 2, 128)                0                 ['reshape[0][0]']
#
#  conv2d_3 (Conv2D)                               (None, 2, 2, 128)                65664             ['up_sampling2d_3[0][0]']
#
#  conv2d (Conv2D)                                 (None, 2, 2, 128)                65664             ['up_sampling2d[0][0]']
#
#  batch_normalization_3 (BatchNormalization)      (None, 2, 2, 128)                512               ['conv2d_3[0][0]']
#
#  batch_normalization (BatchNormalization)        (None, 2, 2, 128)                512               ['conv2d[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)                       (None, 2, 2, 128)                0                 ['batch_normalization_3[0][0]']
#
#  leaky_re_lu (LeakyReLU)                         (None, 2, 2, 128)                0                 ['batch_normalization[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)                  (None, 4, 4, 128)                0                 ['leaky_re_lu_3[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)                  (None, 4, 4, 128)                0                 ['leaky_re_lu[0][0]']
#
#  conv2d_4 (Conv2D)                               (None, 4, 4, 128)                65664             ['up_sampling2d_4[0][0]']
#
#  conv2d_1 (Conv2D)                               (None, 4, 4, 128)                65664             ['up_sampling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNormalization)      (None, 4, 4, 128)                512               ['conv2d_4[0][0]']
#
#  batch_normalization_1 (BatchNormalization)      (None, 4, 4, 128)                512               ['conv2d_1[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)                       (None, 4, 4, 128)                0                 ['batch_normalization_4[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)                       (None, 4, 4, 128)                0                 ['batch_normalization_1[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)                  (None, 8, 8, 128)                0                 ['leaky_re_lu_4[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)                  (None, 8, 8, 128)                0                 ['leaky_re_lu_1[0][0]']
#
#  conv2d_5 (Conv2D)                               (None, 8, 8, 128)                65664             ['up_sampling2d_5[0][0]']
#
#  conv2d_2 (Conv2D)                               (None, 8, 8, 128)                65664             ['up_sampling2d_2[0][0]']
#
#  batch_normalization_5 (BatchNormalization)      (None, 8, 8, 128)                512               ['conv2d_5[0][0]']
#
#  batch_normalization_2 (BatchNormalization)      (None, 8, 8, 128)                512               ['conv2d_2[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)                       (None, 8, 8, 128)                0                 ['batch_normalization_5[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)                       (None, 8, 8, 128)                0                 ['batch_normalization_2[0][0]']
#
#  mydense1 (Conv2D)                               (None, 6, 6, 1)                  1153              ['leaky_re_lu_5[0][0]']
#
#  mydense2 (Conv2D)                               (None, 6, 6, 1)                  1153              ['leaky_re_lu_2[0][0]']
#
# ======================================================================================================================================================
# Total params: 416,002
# Trainable params: 2,306
# Non-trainable params: 413,696
# ______________________________________________________________________________________________________________________________________________________
# None

# %%
dis_dense = Dense(1, activation = 'sigmoid', name='mydense')(discriminator0.layers[-2].output)
inp_dist = discriminator0.input
discriminator = Model([inp_dist[0], inp_dist[1], inp_dist[2]], dis_dense, name='discriminator')
print (discriminator.summary())
# Out:
# Model: "discriminator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 6, 6, 1)]    0           []
#
#  input_4 (InputLayer)           [(None, 6, 6, 1)]    0           []
#
#  concatenate_1 (Concatenate)    (None, 6, 6, 2)      0           ['input_3[0][0]',
#                                                                   'input_4[0][0]']
#
#  flatten (Flatten)              (None, 72)           0           ['concatenate_1[0][0]']
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  concatenate_2 (Concatenate)    (None, 73)           0           ['flatten[0][0]',
#                                                                   'input_2[0][0]']
#
#  dense_1 (Dense)                (None, 64)           4736        ['concatenate_2[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 64)           0           ['dense_1[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['leaky_re_lu_6[0][0]']
#
#  dense_2 (Dense)                (None, 64)           4160        ['dropout[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 64)           0           ['dense_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['leaky_re_lu_7[0][0]']
#
#  dense_3 (Dense)                (None, 64)           4160        ['dropout_1[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 64)           0           ['dense_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 64)           0           ['leaky_re_lu_8[0][0]']
#
#  mydense (Dense)                (None, 1)            65          ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 13,121
# Trainable params: 65
# Non-trainable params: 13,056
# __________________________________________________________________________________________________
# None

# %%
new_layer1 = Dense(128, name='mydense1')(regressor0.layers[-4].output)
new_layer2 = Dropout(0.2, name='mydrop')(new_layer1)
new_layer3 = Dense(1, activation = 'sigmoid', name='mydense2')(new_layer2)
inp = regressor0.input
regressor = Model(inp, new_layer3, name='regressor')
regressor.summary(line_length=150)
# Out:
# Model: "regressor"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                     Param #           Connected to
# ======================================================================================================================================================
#  input_5 (InputLayer)                            [(None, 6, 6, 1)]                0                 []
#
#  input_6 (InputLayer)                            [(None, 6, 6, 1)]                0                 []
#
#  concatenate_3 (Concatenate)                     (None, 6, 6, 2)                  0                 ['input_5[0][0]',
#                                                                                                      'input_6[0][0]']
#
#  conv2d_9 (Conv2D)                               (None, 6, 6, 64)                 192               ['concatenate_3[0][0]']
#
#  conv2d_11 (Conv2D)                              (None, 6, 6, 32)                 96                ['concatenate_3[0][0]']
#
#  max_pooling2d (MaxPooling2D)                    (None, 6, 6, 2)                  0                 ['concatenate_3[0][0]']
#
#  conv2d_8 (Conv2D)                               (None, 6, 6, 64)                 192               ['concatenate_3[0][0]']
#
#  conv2d_10 (Conv2D)                              (None, 6, 6, 64)                 36928             ['conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)                              (None, 6, 6, 32)                 25632             ['conv2d_11[0][0]']
#
#  conv2d_13 (Conv2D)                              (None, 6, 6, 32)                 96                ['max_pooling2d[0][0]']
#
#  concatenate_4 (Concatenate)                     (None, 6, 6, 192)                0                 ['conv2d_8[0][0]',
#                                                                                                      'conv2d_10[0][0]',
#                                                                                                      'conv2d_12[0][0]',
#                                                                                                      'conv2d_13[0][0]']
#
#  re_lu (ReLU)                                    (None, 6, 6, 192)                0                 ['concatenate_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)                  (None, 6, 6, 192)                0                 ['re_lu[0][0]']
#
#  conv2d_15 (Conv2D)                              (None, 6, 6, 64)                 12352             ['max_pooling2d_1[0][0]']
#
#  conv2d_17 (Conv2D)                              (None, 6, 6, 32)                 6176              ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)                  (None, 6, 6, 192)                0                 ['max_pooling2d_1[0][0]']
#
#  conv2d_14 (Conv2D)                              (None, 6, 6, 64)                 12352             ['max_pooling2d_1[0][0]']
#
#  conv2d_16 (Conv2D)                              (None, 6, 6, 64)                 36928             ['conv2d_15[0][0]']
#
#  conv2d_18 (Conv2D)                              (None, 6, 6, 32)                 25632             ['conv2d_17[0][0]']
#
#  conv2d_19 (Conv2D)                              (None, 6, 6, 32)                 6176              ['max_pooling2d_2[0][0]']
#
#  concatenate_5 (Concatenate)                     (None, 6, 6, 192)                0                 ['conv2d_14[0][0]',
#                                                                                                      'conv2d_16[0][0]',
#                                                                                                      'conv2d_18[0][0]',
#                                                                                                      'conv2d_19[0][0]']
#
#  re_lu_1 (ReLU)                                  (None, 6, 6, 192)                0                 ['concatenate_5[0][0]']
#
#  conv2d_21 (Conv2D)                              (None, 6, 6, 64)                 12352             ['re_lu_1[0][0]']
#
#  conv2d_23 (Conv2D)                              (None, 6, 6, 32)                 6176              ['re_lu_1[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)                  (None, 6, 6, 192)                0                 ['re_lu_1[0][0]']
#
#  conv2d_20 (Conv2D)                              (None, 6, 6, 64)                 12352             ['re_lu_1[0][0]']
#
#  conv2d_22 (Conv2D)                              (None, 6, 6, 64)                 36928             ['conv2d_21[0][0]']
#
#  conv2d_24 (Conv2D)                              (None, 6, 6, 32)                 25632             ['conv2d_23[0][0]']
#
#  conv2d_25 (Conv2D)                              (None, 6, 6, 32)                 6176              ['max_pooling2d_3[0][0]']
#
#  concatenate_6 (Concatenate)                     (None, 6, 6, 192)                0                 ['conv2d_20[0][0]',
#                                                                                                      'conv2d_22[0][0]',
#                                                                                                      'conv2d_24[0][0]',
#                                                                                                      'conv2d_25[0][0]']
#
#  re_lu_2 (ReLU)                                  (None, 6, 6, 192)                0                 ['concatenate_6[0][0]']
#
#  conv2d_27 (Conv2D)                              (None, 6, 6, 64)                 12352             ['re_lu_2[0][0]']
#
#  conv2d_29 (Conv2D)                              (None, 6, 6, 32)                 6176              ['re_lu_2[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)                  (None, 6, 6, 192)                0                 ['re_lu_2[0][0]']
#
#  conv2d_26 (Conv2D)                              (None, 6, 6, 64)                 12352             ['re_lu_2[0][0]']
#
#  conv2d_28 (Conv2D)                              (None, 6, 6, 64)                 36928             ['conv2d_27[0][0]']
#
#  conv2d_30 (Conv2D)                              (None, 6, 6, 32)                 25632             ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)                              (None, 6, 6, 32)                 6176              ['max_pooling2d_4[0][0]']
#
#  concatenate_7 (Concatenate)                     (None, 6, 6, 192)                0                 ['conv2d_26[0][0]',
#                                                                                                      'conv2d_28[0][0]',
#                                                                                                      'conv2d_30[0][0]',
#                                                                                                      'conv2d_31[0][0]']
#
#  re_lu_3 (ReLU)                                  (None, 6, 6, 192)                0                 ['concatenate_7[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)                  (None, 6, 6, 192)                0                 ['re_lu_3[0][0]']
#
#  conv2d_33 (Conv2D)                              (None, 6, 6, 64)                 12352             ['max_pooling2d_5[0][0]']
#
#  conv2d_35 (Conv2D)                              (None, 6, 6, 32)                 6176              ['max_pooling2d_5[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)                  (None, 6, 6, 192)                0                 ['max_pooling2d_5[0][0]']
#
#  conv2d_32 (Conv2D)                              (None, 6, 6, 64)                 12352             ['max_pooling2d_5[0][0]']
#
#  conv2d_34 (Conv2D)                              (None, 6, 6, 64)                 36928             ['conv2d_33[0][0]']
#
#  conv2d_36 (Conv2D)                              (None, 6, 6, 32)                 25632             ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)                              (None, 6, 6, 32)                 6176              ['max_pooling2d_6[0][0]']
#
#  concatenate_8 (Concatenate)                     (None, 6, 6, 192)                0                 ['conv2d_32[0][0]',
#                                                                                                      'conv2d_34[0][0]',
#                                                                                                      'conv2d_36[0][0]',
#                                                                                                      'conv2d_37[0][0]']
#
#  re_lu_4 (ReLU)                                  (None, 6, 6, 192)                0                 ['concatenate_8[0][0]']
#
#  conv2d_39 (Conv2D)                              (None, 6, 6, 64)                 12352             ['re_lu_4[0][0]']
#
#  conv2d_41 (Conv2D)                              (None, 6, 6, 32)                 6176              ['re_lu_4[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)                  (None, 6, 6, 192)                0                 ['re_lu_4[0][0]']
#
#  conv2d_38 (Conv2D)                              (None, 6, 6, 64)                 12352             ['re_lu_4[0][0]']
#
#  conv2d_40 (Conv2D)                              (None, 6, 6, 64)                 36928             ['conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)                              (None, 6, 6, 32)                 25632             ['conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)                              (None, 6, 6, 32)                 6176              ['max_pooling2d_7[0][0]']
#
#  concatenate_9 (Concatenate)                     (None, 6, 6, 192)                0                 ['conv2d_38[0][0]',
#                                                                                                      'conv2d_40[0][0]',
#                                                                                                      'conv2d_42[0][0]',
#                                                                                                      'conv2d_43[0][0]']
#
#  re_lu_5 (ReLU)                                  (None, 6, 6, 192)                0                 ['concatenate_9[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)                  (None, 6, 6, 192)                0                 ['re_lu_5[0][0]']
#
#  conv2d_45 (Conv2D)                              (None, 6, 6, 64)                 12352             ['max_pooling2d_8[0][0]']
#
#  conv2d_47 (Conv2D)                              (None, 6, 6, 32)                 6176              ['max_pooling2d_8[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)                  (None, 6, 6, 192)                0                 ['max_pooling2d_8[0][0]']
#
#  conv2d_44 (Conv2D)                              (None, 6, 6, 64)                 12352             ['max_pooling2d_8[0][0]']
#
#  conv2d_46 (Conv2D)                              (None, 6, 6, 64)                 36928             ['conv2d_45[0][0]']
#
#  conv2d_48 (Conv2D)                              (None, 6, 6, 32)                 25632             ['conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)                              (None, 6, 6, 32)                 6176              ['max_pooling2d_9[0][0]']
#
#  concatenate_10 (Concatenate)                    (None, 6, 6, 192)                0                 ['conv2d_44[0][0]',
#                                                                                                      'conv2d_46[0][0]',
#                                                                                                      'conv2d_48[0][0]',
#                                                                                                      'conv2d_49[0][0]']
#
#  re_lu_6 (ReLU)                                  (None, 6, 6, 192)                0                 ['concatenate_10[0][0]']
#
#  batch_normalization_6 (BatchNormalization)      (None, 6, 6, 192)                768               ['re_lu_6[0][0]']
#
#  flatten_1 (Flatten)                             (None, 6912)                     0                 ['batch_normalization_6[0][0]']
#
#  dropout_3 (Dropout)                             (None, 6912)                     0                 ['flatten_1[0][0]']
#
#  mydense1 (Dense)                                (None, 128)                      884864            ['dropout_3[0][0]']
#
#  mydrop (Dropout)                                (None, 128)                      0                 ['mydense1[0][0]']
#
#  mydense2 (Dense)                                (None, 1)                        129               ['mydrop[0][0]']
#
# ======================================================================================================================================================
# Total params: 1,546,593
# Trainable params: 884,993
# Non-trainable params: 661,600
# ______________________________________________________________________________________________________________________________________________________

# %%
np.max(y_train0)
# Out:
# 12.571667

# %%
regressor = load_model('./../data/nns/keep/regressor_trans.h5')
regressor.compile(loss = 'mse', optimizer = Adam(5e-6))


history = regressor.fit([atoms_embedding, bonds_embedding], 
              y_train,
              validation_data = ([atoms_val,
                                  bonds_val],
                                 y_val),
              batch_size=8,
              epochs=1,
              verbose=1)
    
# Validating the regressor
# Train
pred_train = regressor.predict([atoms_embedding, bonds_embedding])
pred_train0 = pred_train*(gap_max-gap_min)+gap_min
print('Current R2 on Regressor for train data: {}'.format(r2_score(y_train0, pred_train0.reshape([-1]))))
mse_train = mean_squared_error(y_train0, pred_train0.reshape([-1]))
mae_train = mean_absolute_error(y_train0, pred_train0.reshape([-1]))

#print ('prediction on train: ', pred_train)
#print ('True train: ', y_train)

# Test
pred = regressor.predict([atoms_val, bonds_val])
pred0 = pred*(gap_max-gap_min) + gap_min
print('Current R2 on Regressor for test data: {}'.format(r2_score(y_val0, pred0.reshape([-1]))))
mse_val = mean_squared_error (y_val0, pred0.reshape([-1]))
mae_val = mean_absolute_error (y_val0, pred0.reshape([-1]))

#print ("prediction on test: ", pred )
#print ("True test values: ", y_val)

print ('Train MSE: {}, RMSE: {}, MAE: {}'.format (round(mse_train, 5), 
                                                  round(mse_train**0.5, 5), 
                                                  round(mae_train, 5)))
print ('Test MSE: {}, RMSE: {}, MAE: {}'.format (round(mse_val, 5), 
                                                  round(mse_val**0.5, 5), 
                                                  round(mae_val, 5)))
# Saving the currently trained models
regressor.save('./../data/nns/regressor_trans.h5')
#regressor_top.save('./../data/nns/regressor_top_trans.h5')

# save the losses 
with open ('regressor_loss_0_150.csv', 'w') as f:
    for key in history.history.keys():
        f.write("%s,%s\n"%(key,history.history[key]))
# Out:
# 2023-05-31 08:09:39.794204: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-05-31 08:09:39.805090: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x1f516760 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-31 08:09:39.805109: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-05-31 08:09:39.814228: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-31 08:09:39.896968: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-05-31 08:09:39.920024: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 456/456 [==============================] - 9s 7ms/step - loss: 1.6860e-04 - val_loss: 2.8585e-04
# 114/114 [==============================] - 0s 2ms/step
# Current R2 on Regressor for train data: 0.9090716763635052
# 29/29 [==============================] - 0s 3ms/step
# Current R2 on Regressor for test data: 0.6054167404484763
# Train MSE: 0.01473, RMSE: 0.12139, MAE: 0.09457
# Test MSE: 0.06432, RMSE: 0.25361, MAE: 0.15952

# %%
#regressor = load_model('./../data/nns/keep/regressor.h5')
with open('./../data/trainingsets/image.pickle', 'rb') as f:
    X_smiles_original, _, y_original0 = pickle.load(f) 
# Training the Regressor 
# latent vectors from trained Encoder, 
# last output of Encoder is concat. (O1, O2)

train_atoms_embedding_try, train_bonds_embedding_try, _ = encoder.predict([X_smiles_original], verbose=0)
pred_original = regressor.predict([train_atoms_embedding_try, train_bonds_embedding_try])
pred_original0 = pred_original*(gap_max-gap_min) + gap_min

print('pearsonr on original data: {}'.format(r2_score(y_original0, pred_original0.reshape([-1]))))
print('MAE on original data: {}'.format(mean_absolute_error(y_original0, pred_original0.reshape([-1]))))
# Out:
# 4145/4145 [==============================] - 7s 2ms/step
# pearsonr on original data: 0.9294572159183871
# MAE on original data: 0.41706003312348805

# %%
from scipy.stats import pearsonr
print('pearsonr on original data: {}'.format(pearsonr(y_original0, pred_original0.reshape([-1]))))
# Out:
# pearsonr on original data: PearsonRResult(statistic=0.9822632020591812, pvalue=0.0)

# %%
plt.scatter (y_original0, pred_original0.reshape([-1]), s=0.1)

# %%
print('Current R2 on Regressor for test data: {}'.format(r2_score(y_val0, pred0.reshape([-1]))))
# Out:
# Current R2 on Regressor for test data: 0.6054167404484763

# %%
pred0
# Out:
# array([[10.496817 ],
#        [ 9.640673 ],
#        [10.095796 ],
#        [10.27132  ],
#        [10.02875  ],
#        [10.060736 ],
#        [10.151731 ],
#        [10.149194 ],
#        [10.133202 ],
#        [10.120872 ],
#        [ 9.985506 ],
#        [10.195408 ],
#        [ 9.931021 ],
#        [10.348962 ],
#        [ 9.97534  ],
#        [10.287975 ],
#        [10.080206 ],
#        [ 9.947589 ],
#        [ 9.968964 ],
#        [10.058429 ],
#        [10.228235 ],
#        [ 9.915833 ],
#        [ 9.90403  ],
#        [10.439241 ],
#        [10.269145 ],
#        [10.272379 ],
#        [10.361667 ],
#        [ 9.8587055],
#        [10.162291 ],
#        [ 9.8643   ],
#        [10.065988 ],
#        [ 9.937963 ],
#        [10.213082 ],
#        [10.271099 ],
#        [10.178345 ],
#        [10.338114 ],
#        [10.028264 ],
#        [ 9.8949175],
#        [10.013289 ],
#        [10.165202 ],
#        [10.220556 ],
#        [ 9.976372 ],
#        [10.326915 ],
#        [ 9.773775 ],
#        [ 9.851425 ],
#        [10.031322 ],
#        [10.003758 ],
#        [10.185601 ],
#        [10.07955  ],
#        [ 9.879296 ],
#        [ 9.684866 ],
#        [10.038121 ],
#        [10.034231 ],
#        [ 9.944769 ],
#        [10.021976 ],
#        [10.133438 ],
#        [10.133939 ],
#        [10.129832 ],
#        [10.157136 ],
#        [ 9.982435 ],
#        [10.032454 ],
#        [10.112735 ],
#        [ 9.876459 ],
#        [10.004753 ],
#        [ 9.794704 ],
#        [10.395748 ],
#        [10.01031  ],
#        [ 9.983882 ],
#        [ 9.69479  ],
#        [ 9.8997555],
#        [ 9.958009 ],
#        [10.038717 ],
#        [ 9.966147 ],
#        [10.025073 ],
#        [10.051774 ],
#        [ 9.853451 ],
#        [ 9.98098  ],
#        [ 9.928793 ],
#        [10.098127 ],
#        [10.00346  ],
#        [ 9.673014 ],
#        [ 9.9319105],
#        [ 9.755766 ],
#        [10.084627 ],
#        [ 9.860048 ],
#        [ 9.9433775],
#        [ 9.874386 ],
#        [ 9.807718 ],
#        [ 9.888432 ],
#        [ 9.894034 ],
#        [ 9.965751 ],
#        [ 9.920105 ],
#        [ 9.789156 ],
#        [ 9.698816 ],
#        [ 9.764233 ],
#        [10.067902 ],
#        [ 9.929532 ],
#        [10.068107 ],
#        [10.219837 ],
#        [10.236291 ],
#        [ 9.925675 ],
#        [ 9.913631 ],
#        [ 9.708977 ],
#        [10.0773   ],
#        [ 9.881528 ],
#        [10.041827 ],
#        [ 9.880477 ],
#        [10.010368 ],
#        [ 9.972892 ],
#        [ 9.954062 ],
#        [ 9.864977 ],
#        [10.02612  ],
#        [ 9.826669 ],
#        [ 9.9812   ],
#        [ 9.886066 ],
#        [10.06694  ],
#        [ 9.733215 ],
#        [10.1342   ],
#        [ 9.98223  ],
#        [ 9.891357 ],
#        [10.001536 ],
#        [ 9.693906 ],
#        [ 9.919033 ],
#        [ 9.658707 ],
#        [ 9.807161 ],
#        [ 9.848446 ],
#        [ 9.940751 ],
#        [10.019826 ],
#        [ 9.744178 ],
#        [ 9.917143 ],
#        [ 9.947834 ],
#        [ 9.915573 ],
#        [ 9.8603   ],
#        [ 9.8711605],
#        [ 9.880098 ],
#        [ 9.86128  ],
#        [10.004088 ],
#        [ 9.969013 ],
#        [ 9.90257  ],
#        [ 9.609927 ],
#        [ 9.860091 ],
#        [ 9.858854 ],
#        [ 9.953813 ],
#        [ 9.914158 ],
#        [10.050424 ],
#        [ 9.818856 ],
#        [ 9.775024 ],
#        [ 9.91525  ],
#        [ 9.974427 ],
#        [10.005262 ],
#        [ 9.758622 ],
#        [ 9.746941 ],
#        [ 9.702976 ],
#        [ 9.859932 ],
#        [ 9.788846 ],
#        [ 9.681491 ],
#        [10.04378  ],
#        [ 9.913316 ],
#        [ 9.83104  ],
#        [ 9.825237 ],
#        [ 9.83652  ],
#        [ 9.76648  ],
#        [ 9.832842 ],
#        [ 9.605884 ],
#        [ 9.540053 ],
#        [ 9.717688 ],
#        [ 9.711864 ],
#        [ 9.993698 ],
#        [10.15837  ],
#        [ 9.972945 ],
#        [ 9.870558 ],
#        [ 9.857624 ],
#        [ 9.806009 ],
#        [ 9.812039 ],
#        [ 9.414009 ],
#        [ 9.368539 ],
#        [ 9.676465 ],
#        [ 9.182853 ],
#        [ 9.340133 ],
#        [ 9.568037 ],
#        [ 9.589949 ],
#        [ 9.317252 ],
#        [ 9.422017 ],
#        [ 9.605833 ],
#        [ 9.452724 ],
#        [ 9.418611 ],
#        [ 9.667428 ],
#        [ 9.408697 ],
#        [ 9.765564 ],
#        [ 9.753054 ],
#        [ 9.429352 ],
#        [ 9.621743 ],
#        [ 9.471995 ],
#        [ 9.388457 ],
#        [ 9.454126 ],
#        [ 9.55282  ],
#        [ 9.651279 ],
#        [ 9.575189 ],
#        [ 9.645823 ],
#        [ 9.704087 ],
#        [ 9.304493 ],
#        [ 9.277461 ],
#        [ 9.487563 ],
#        [ 9.890138 ],
#        [ 9.884667 ],
#        [ 9.433307 ],
#        [ 9.605663 ],
#        [ 9.6900625],
#        [ 9.366409 ],
#        [ 9.397196 ],
#        [ 9.571159 ],
#        [ 9.627535 ],
#        [ 9.589972 ],
#        [ 9.370119 ],
#        [ 9.735197 ],
#        [ 9.448784 ],
#        [ 9.415225 ],
#        [ 9.611746 ],
#        [ 9.614707 ],
#        [ 9.485676 ],
#        [ 9.750816 ],
#        [ 9.634722 ],
#        [ 8.913652 ],
#        [ 9.711682 ],
#        [ 9.5617485],
#        [ 9.702795 ],
#        [ 9.760802 ],
#        [ 9.643894 ],
#        [ 9.469177 ],
#        [ 9.7230015],
#        [ 9.58591  ],
#        [ 9.392179 ],
#        [ 9.619437 ],
#        [ 9.785037 ],
#        [ 9.627928 ],
#        [ 9.824318 ],
#        [ 9.472467 ],
#        [ 9.614843 ],
#        [ 9.724297 ],
#        [ 9.651324 ],
#        [ 9.737218 ],
#        [ 9.681385 ],
#        [ 9.843457 ],
#        [ 9.6966715],
#        [10.01146  ],
#        [ 9.650649 ],
#        [ 9.796073 ],
#        [ 9.761911 ],
#        [ 9.738554 ],
#        [ 9.5665245],
#        [ 9.697323 ],
#        [ 9.700577 ],
#        [ 9.835446 ],
#        [10.111677 ],
#        [ 9.505839 ],
#        [ 9.786466 ],
#        [ 9.80948  ],
#        [10.013599 ],
#        [ 9.654608 ],
#        [ 9.6555   ],
#        [ 9.672474 ],
#        [ 9.838044 ],
#        [ 9.961925 ],
#        [ 9.877059 ],
#        [ 9.688497 ],
#        [ 9.746856 ],
#        [ 9.767497 ],
#        [ 9.802767 ],
#        [ 9.684871 ],
#        [ 9.654506 ],
#        [ 9.858566 ],
#        [ 9.637915 ],
#        [ 9.771561 ],
#        [ 9.534847 ],
#        [ 9.956892 ],
#        [ 9.830922 ],
#        [ 9.818145 ],
#        [ 9.574655 ],
#        [ 9.693964 ],
#        [ 9.988261 ],
#        [ 9.812814 ],
#        [ 9.751714 ],
#        [ 9.75746  ],
#        [ 9.655305 ],
#        [ 9.757413 ],
#        [ 9.729056 ],
#        [ 9.933155 ],
#        [ 9.817924 ],
#        [ 9.903414 ],
#        [ 9.878541 ],
#        [ 9.8227005],
#        [ 9.807584 ],
#        [ 9.774893 ],
#        [ 9.738937 ],
#        [ 9.750225 ],
#        [ 9.828297 ],
#        [ 9.882206 ],
#        [ 9.683823 ],
#        [ 9.687641 ],
#        [ 9.847377 ],
#        [ 9.66146  ],
#        [ 9.877959 ],
#        [ 9.676735 ],
#        [ 9.892506 ],
#        [ 9.660576 ],
#        [ 9.70898  ],
#        [ 9.772074 ],
#        [ 9.643369 ],
#        [ 9.744686 ],
#        [ 9.934923 ],
#        [ 9.749326 ],
#        [ 9.865572 ],
#        [ 9.833414 ],
#        [ 9.844003 ],
#        [ 9.901799 ],
#        [ 9.95848  ],
#        [ 9.838269 ],
#        [ 9.736012 ],
#        [10.007663 ],
#        [ 9.837198 ],
#        [ 9.747969 ],
#        [ 9.961807 ],
#        [ 9.665846 ],
#        [ 9.71134  ],
#        [ 9.858012 ],
#        [10.031645 ],
#        [ 9.904755 ],
#        [ 9.826733 ],
#        [ 9.895018 ],
#        [ 9.807564 ],
#        [ 9.825179 ],
#        [ 9.96793  ],
#        [ 9.950721 ],
#        [ 9.730631 ],
#        [ 9.869129 ],
#        [ 9.838528 ],
#        [ 9.891309 ],
#        [ 9.980503 ],
#        [10.031468 ],
#        [10.012875 ],
#        [ 9.905185 ],
#        [ 9.933844 ],
#        [ 9.635083 ],
#        [ 9.980414 ],
#        [ 9.912563 ],
#        [10.035464 ],
#        [ 9.825251 ],
#        [ 9.9016   ],
#        [10.153131 ],
#        [ 9.617183 ],
#        [10.16958  ],
#        [ 9.83679  ],
#        [ 9.684333 ],
#        [ 9.908209 ],
#        [ 9.814873 ],
#        [10.165166 ],
#        [10.125151 ],
#        [10.316915 ],
#        [10.0679455],
#        [ 9.904574 ],
#        [ 9.631515 ],
#        [ 9.428092 ],
#        [ 9.707507 ],
#        [ 9.743721 ],
#        [ 9.624327 ],
#        [ 9.591567 ],
#        [ 9.598787 ],
#        [ 9.749787 ],
#        [ 9.575607 ],
#        [ 9.516952 ],
#        [ 9.560942 ],
#        [ 9.563235 ],
#        [ 9.565691 ],
#        [ 9.815291 ],
#        [ 9.786891 ],
#        [ 9.731066 ],
#        [ 9.650112 ],
#        [ 9.68879  ],
#        [ 9.878627 ],
#        [ 9.601874 ],
#        [ 9.493766 ],
#        [ 9.637657 ],
#        [ 9.77924  ],
#        [ 9.639884 ],
#        [ 9.651786 ],
#        [ 9.635484 ],
#        [ 9.556007 ],
#        [ 9.842543 ],
#        [ 9.828843 ],
#        [10.070004 ],
#        [ 9.434804 ],
#        [ 9.856035 ],
#        [ 9.596761 ],
#        [ 9.729849 ],
#        [ 9.807353 ],
#        [ 9.637878 ],
#        [ 9.615401 ],
#        [ 9.650137 ],
#        [ 9.44525  ],
#        [ 9.680831 ],
#        [ 9.75914  ],
#        [ 9.657938 ],
#        [ 9.881334 ],
#        [ 9.57814  ],
#        [ 9.683774 ],
#        [ 9.462222 ],
#        [ 9.582552 ],
#        [ 9.6774   ],
#        [ 9.905974 ],
#        [ 9.770448 ],
#        [10.108057 ],
#        [ 9.916636 ],
#        [ 9.726685 ],
#        [ 9.699032 ],
#        [10.141979 ],
#        [ 9.618709 ],
#        [ 9.770664 ],
#        [ 9.7367325],
#        [ 9.836382 ],
#        [ 9.456709 ],
#        [ 9.900864 ],
#        [ 9.740678 ],
#        [ 9.663776 ],
#        [ 9.95921  ],
#        [ 9.787442 ],
#        [ 9.737084 ],
#        [ 9.859884 ],
#        [ 9.732846 ],
#        [ 9.933804 ],
#        [ 9.46997  ],
#        [ 9.469022 ],
#        [ 9.8166065],
#        [ 9.791537 ],
#        [10.029339 ],
#        [10.06791  ],
#        [ 9.3710575],
#        [ 9.960055 ],
#        [ 9.767381 ],
#        [ 9.556477 ],
#        [ 9.7064   ],
#        [ 9.94239  ],
#        [ 9.958269 ],
#        [ 9.796795 ],
#        [ 9.577302 ],
#        [ 9.909547 ],
#        [ 9.721592 ],
#        [10.395748 ],
#        [ 9.791127 ],
#        [10.048468 ],
#        [ 9.73023  ],
#        [ 9.89493  ],
#        [ 9.9298115],
#        [ 9.771623 ],
#        [ 9.751855 ],
#        [ 9.588452 ],
#        [ 9.769487 ],
#        [ 9.671837 ],
#        [ 9.995235 ],
#        [ 9.83477  ],
#        [ 9.543041 ],
#        [ 9.67612  ],
#        [ 9.747824 ],
#        [ 9.452044 ],
#        [ 9.918439 ],
#        [ 9.944769 ],
#        [ 9.788162 ],
#        [ 9.875697 ],
#        [ 9.752821 ],
#        [ 9.955395 ],
#        [ 9.988106 ],
#        [ 9.703924 ],
#        [ 9.876464 ],
#        [ 9.593885 ],
#        [ 9.84297  ],
#        [ 9.66646  ],
#        [ 9.851423 ],
#        [ 9.774499 ],
#        [ 9.8371525],
#        [ 8.803759 ],
#        [ 9.620457 ],
#        [ 9.632794 ],
#        [ 9.8863735],
#        [10.000023 ],
#        [ 9.781429 ],
#        [ 9.911633 ],
#        [ 9.930849 ],
#        [ 9.926354 ],
#        [10.105919 ],
#        [ 9.74334  ],
#        [ 9.8916645],
#        [ 9.774827 ],
#        [ 9.840671 ],
#        [ 9.898872 ],
#        [ 9.981628 ],
#        [ 9.828418 ],
#        [ 9.81881  ],
#        [ 9.97476  ],
#        [10.354664 ],
#        [ 9.843036 ],
#        [ 9.869513 ],
#        [ 9.836083 ],
#        [ 9.715418 ],
#        [ 9.918179 ],
#        [10.048116 ],
#        [ 9.673014 ],
#        [ 9.983882 ],
#        [ 9.923047 ],
#        [ 9.917172 ],
#        [10.028155 ],
#        [ 9.954062 ],
#        [10.156705 ],
#        [ 9.9297905],
#        [ 9.850618 ],
#        [10.005969 ],
#        [10.113094 ],
#        [10.001317 ],
#        [ 9.725556 ],
#        [10.185601 ],
#        [ 9.928332 ],
#        [ 9.939472 ],
#        [10.008289 ],
#        [10.049927 ],
#        [10.08128  ],
#        [ 9.969586 ],
#        [ 9.763878 ],
#        [10.188397 ],
#        [ 9.770137 ],
#        [ 9.932449 ],
#        [ 9.916654 ],
#        [ 8.048902 ],
#        [ 9.895592 ],
#        [10.013149 ],
#        [10.470267 ],
#        [ 9.901221 ],
#        [10.372874 ],
#        [10.338114 ],
#        [10.103254 ],
#        [10.19433  ],
#        [10.384397 ],
#        [10.396376 ],
#        [10.135234 ],
#        [10.477326 ],
#        [10.272379 ],
#        [10.232394 ],
#        [10.267476 ],
#        [ 9.976372 ],
#        [ 9.975884 ],
#        [10.273125 ],
#        [10.271099 ],
#        [10.585325 ],
#        [10.056392 ],
#        [10.507261 ],
#        [10.698105 ],
#        [10.611728 ],
#        [ 9.640673 ],
#        [10.825536 ],
#        [11.227848 ],
#        [11.154376 ],
#        [11.344423 ],
#        [10.668596 ],
#        [ 9.239879 ],
#        [ 9.478006 ],
#        [ 9.416968 ],
#        [ 9.322036 ],
#        [ 9.63747  ],
#        [ 9.239523 ],
#        [ 9.2175   ],
#        [ 9.266806 ],
#        [ 9.382738 ],
#        [ 9.544758 ],
#        [ 9.478393 ],
#        [ 9.438988 ],
#        [ 9.419233 ],
#        [ 9.348222 ],
#        [ 9.526017 ],
#        [ 9.677899 ],
#        [ 9.405899 ],
#        [ 9.43304  ],
#        [ 9.351133 ],
#        [ 9.6440735],
#        [ 9.415632 ],
#        [ 9.486286 ],
#        [ 9.557235 ],
#        [ 9.073359 ],
#        [ 9.706288 ],
#        [ 9.5547495],
#        [ 9.536557 ],
#        [ 9.25758  ],
#        [ 9.432505 ],
#        [ 9.29987  ],
#        [ 9.528581 ],
#        [ 9.452478 ],
#        [ 9.580439 ],
#        [ 9.562957 ],
#        [ 9.647446 ],
#        [ 9.625899 ],
#        [ 9.610347 ],
#        [ 9.470381 ],
#        [ 9.456244 ],
#        [ 9.6053095],
#        [ 9.586406 ],
#        [ 9.519883 ],
#        [ 9.554831 ],
#        [ 9.730823 ],
#        [ 9.697846 ],
#        [ 9.86227  ],
#        [ 9.4885   ],
#        [ 9.732656 ],
#        [ 9.471812 ],
#        [ 9.574431 ],
#        [ 9.633712 ],
#        [ 9.540389 ],
#        [ 9.620039 ],
#        [ 9.498385 ],
#        [ 9.525189 ],
#        [ 9.419296 ],
#        [ 9.665447 ],
#        [ 9.780931 ],
#        [ 9.484424 ],
#        [ 9.721159 ],
#        [ 9.686534 ],
#        [ 9.750892 ],
#        [ 9.766536 ],
#        [ 9.634585 ],
#        [ 9.484345 ],
#        [ 9.66265  ],
#        [ 9.479611 ],
#        [ 9.507675 ],
#        [ 9.412765 ],
#        [ 9.742279 ],
#        [ 9.662564 ],
#        [ 9.670752 ],
#        [ 9.618754 ],
#        [ 9.595325 ],
#        [ 9.643495 ],
#        [ 9.689174 ],
#        [ 9.60461  ],
#        [ 9.778753 ],
#        [ 9.4784565],
#        [ 9.494658 ],
#        [ 9.621526 ],
#        [ 9.624822 ],
#        [ 9.660937 ],
#        [ 9.555708 ],
#        [ 9.696772 ],
#        [ 9.692709 ],
#        [ 9.719288 ],
#        [ 9.43634  ],
#        [ 9.731199 ],
#        [ 9.578132 ],
#        [ 9.804582 ],
#        [ 9.666759 ],
#        [ 9.7716   ],
#        [ 9.747718 ],
#        [ 9.69037  ],
#        [ 9.691126 ],
#        [ 9.486469 ],
#        [ 9.603616 ],
#        [ 9.826871 ],
#        [ 9.658243 ],
#        [ 9.571429 ],
#        [ 9.625945 ],
#        [ 9.810417 ],
#        [ 9.542471 ],
#        [ 9.69105  ],
#        [ 9.722802 ],
#        [ 9.604923 ],
#        [ 9.643212 ],
#        [ 9.7594795],
#        [ 9.589882 ],
#        [ 9.724369 ],
#        [ 9.768803 ],
#        [ 9.5756855],
#        [ 9.806086 ],
#        [ 9.687673 ],
#        [ 9.665395 ],
#        [ 9.710912 ],
#        [ 9.602169 ],
#        [ 9.671841 ],
#        [ 9.788016 ],
#        [ 9.710431 ],
#        [ 9.635841 ],
#        [ 9.699608 ],
#        [ 9.543995 ],
#        [ 9.762174 ],
#        [ 9.793383 ],
#        [ 9.901932 ],
#        [ 9.800413 ],
#        [ 9.67251  ],
#        [ 9.632282 ],
#        [ 9.645182 ],
#        [ 9.804846 ],
#        [ 9.769928 ],
#        [ 9.877182 ],
#        [ 9.884451 ],
#        [ 9.694541 ],
#        [ 9.695687 ],
#        [ 9.791866 ],
#        [ 9.74609  ],
#        [ 9.733604 ],
#        [ 9.769225 ],
#        [ 9.714801 ],
#        [ 9.805692 ],
#        [ 9.7092905],
#        [ 9.852605 ],
#        [ 9.732005 ],
#        [ 9.801184 ],
#        [ 9.729459 ],
#        [ 9.75559  ],
#        [ 9.816446 ],
#        [ 9.706557 ],
#        [ 9.836427 ],
#        [ 9.78265  ],
#        [ 9.77849  ],
#        [ 9.78695  ],
#        [ 9.835441 ],
#        [ 9.491704 ],
#        [ 9.622168 ],
#        [ 9.890373 ],
#        [ 9.960475 ],
#        [ 9.919512 ],
#        [ 9.778196 ],
#        [ 9.812531 ],
#        [ 9.889635 ],
#        [ 9.910775 ],
#        [ 9.879311 ],
#        [ 9.9165325],
#        [ 9.877408 ],
#        [ 9.713695 ],
#        [ 9.837429 ],
#        [ 9.945308 ],
#        [ 9.903034 ],
#        [10.10818  ],
#        [ 9.943539 ],
#        [ 9.790699 ],
#        [ 9.969323 ],
#        [ 9.893293 ],
#        [10.062012 ],
#        [ 9.945037 ],
#        [ 9.946163 ],
#        [ 9.754019 ],
#        [10.155919 ],
#        [ 9.977321 ],
#        [10.156526 ],
#        [10.066221 ],
#        [10.085173 ],
#        [ 9.648802 ],
#        [10.496817 ],
#        [ 9.640673 ],
#        [10.439241 ],
#        [10.269145 ],
#        [10.272379 ],
#        [10.361667 ],
#        [ 9.8587055],
#        [10.162291 ],
#        [ 9.8643   ],
#        [10.213082 ],
#        [10.271099 ],
#        [10.178345 ],
#        [10.338114 ],
#        [10.028264 ],
#        [ 9.8949175],
#        [10.013289 ],
#        [10.165202 ],
#        [10.220556 ],
#        [ 9.976372 ],
#        [10.326915 ],
#        [ 9.773775 ],
#        [ 9.901221 ],
#        [10.372874 ],
#        [10.338114 ],
#        [10.103254 ],
#        [10.19433  ],
#        [10.384397 ],
#        [10.396365 ],
#        [10.135234 ],
#        [10.477326 ],
#        [10.272379 ],
#        [10.232395 ],
#        [10.267476 ],
#        [ 9.976372 ],
#        [ 9.975879 ],
#        [10.273111 ],
#        [10.271099 ],
#        [10.585324 ],
#        [10.056389 ],
#        [10.507259 ],
#        [10.698104 ],
#        [10.611727 ],
#        [ 9.640673 ],
#        [10.825536 ],
#        [11.227838 ],
#        [11.154367 ],
#        [11.344423 ],
#        [10.668595 ],
#        [ 9.648802 ],
#        [10.496817 ],
#        [ 9.640673 ],
#        [10.439239 ],
#        [10.269147 ],
#        [10.272379 ],
#        [10.361671 ],
#        [ 9.8587055],
#        [10.162289 ],
#        [ 9.8643   ],
#        [10.213082 ],
#        [10.271099 ],
#        [10.178345 ],
#        [10.338114 ],
#        [10.028264 ],
#        [ 9.8949175],
#        [10.013289 ],
#        [10.165202 ],
#        [10.220556 ],
#        [ 9.976372 ],
#        [10.326915 ],
#        [ 9.773776 ],
#        [ 9.901221 ],
#        [10.372874 ],
#        [10.338114 ],
#        [10.103254 ],
#        [10.19433  ],
#        [10.384397 ],
#        [10.396376 ],
#        [10.135234 ],
#        [10.477326 ],
#        [10.272379 ],
#        [10.232394 ],
#        [10.267476 ],
#        [ 9.976372 ],
#        [ 9.975884 ],
#        [10.273125 ],
#        [10.271099 ],
#        [10.585325 ],
#        [10.056392 ],
#        [10.507261 ],
#        [10.698105 ],
#        [10.611728 ],
#        [ 9.640673 ],
#        [10.825536 ],
#        [11.227848 ],
#        [11.154376 ],
#        [11.344423 ],
#        [10.668596 ],
#        [ 9.648802 ],
#        [10.496817 ],
#        [ 9.640673 ],
#        [10.439241 ],
#        [10.269145 ],
#        [10.272379 ],
#        [10.361667 ],
#        [ 9.8587055],
#        [10.162291 ],
#        [ 9.8643   ],
#        [10.213082 ],
#        [10.271099 ],
#        [10.178345 ],
#        [10.338114 ],
#        [10.028264 ],
#        [ 9.8949175],
#        [10.013289 ],
#        [10.165202 ],
#        [10.220556 ],
#        [ 9.976372 ],
#        [10.326915 ],
#        [ 9.773775 ],
#        [ 9.901221 ],
#        [10.372874 ],
#        [10.338114 ],
#        [10.103254 ],
#        [10.19433  ],
#        [10.384397 ],
#        [10.396365 ],
#        [10.135234 ],
#        [10.477326 ],
#        [10.272379 ],
#        [10.232395 ],
#        [10.267476 ],
#        [ 9.976372 ],
#        [ 9.975879 ],
#        [10.273111 ],
#        [10.271099 ],
#        [10.585324 ],
#        [10.056389 ],
#        [10.507259 ],
#        [10.698104 ],
#        [10.611727 ],
#        [ 9.640673 ],
#        [10.825536 ],
#        [11.227838 ],
#        [11.154367 ],
#        [11.344423 ],
#        [10.668595 ],
#        [ 9.648802 ],
#        [10.496817 ],
#        [ 9.640673 ],
#        [10.327019 ],
#        [10.585526 ],
#        [10.056497 ],
#        [10.507565 ],
#        [10.698392 ],
#        [10.611993 ],
#        [ 9.641022 ],
#        [10.825894 ],
#        [11.2280035],
#        [11.154443 ],
#        [11.344707 ],
#        [10.668508 ]], dtype=float32)

# %%
print (np.max(y_train0))
print (np.max(pred_train0))
print (np.max(y_val0))
print (np.max(pred0))
# Out:
# 12.571667
# 12.3320465
# 12.14989
# 11.344707

# %%
MAE_pred_des = np.round (mean_absolute_error(pred0, y_val0), 4)
print ("MAE_pred_des", MAE_pred_des)
# Fractioned MAE, more normalized
Fractioned_MAE_pred_des = 0
for pred, true in zip(pred0, y_val0):
        Fractioned_MAE_pred_des = Fractioned_MAE_pred_des +  abs(pred-true)/true
Fractioned_MAE_pred_des = Fractioned_MAE_pred_des/(pred0.shape[0])
print ("MAEF_pred_des", Fractioned_MAE_pred_des)
# Out:
# MAE_pred_des 0.1595
# MAEF_pred_des [0.01581343]

# %%
fig, ax = plt.subplots(figsize=(5, 4))
plt.plot(list(range(len(history.history['loss']))), 
         history.history['loss'], label='Training loss', linewidth=3,) 
plt.plot(list(range(len(history.history['val_loss']))), 
         history.history['val_loss'], label='Validation loss', linewidth=3,) 

ax.set_xlabel('Epochs', fontsize='20', fontname='Arial', fontweight='bold', labelpad=5)
ax.set_ylabel('Loss', fontsize='20', fontname='Arial', fontweight='bold', labelpad=5)

ax.tick_params(direction='out', length=5, width=3, colors='black', grid_alpha=1, labelsize='18')

[i.set_linewidth(2) for i in ax.spines.values()]


#plt.title ('per {}, rand {}'.format(per, rand))

#plt.ylim(0, 12)
#plt.xticks((1, 3, 5, 7, 9,  11));
#plt.yticks((1, 3, 5, 7, 9,  11));
plt.title('Regressor loss', fontsize=15, fontname='Arial', fontweight='bold', pad=10)
plt.legend(fontsize=15) 
plt.tight_layout()
plt.savefig("R_loss_0_100.png", dpi=300)

# %%
fig, ax = plt.subplots(figsize=(5, 4))
plt.rcParams["legend.markerscale"] = 1

plt.scatter (y_train0, pred_train0, color='red', label='Train', alpha=0.6, s=10)
plt.scatter ( y_val0, pred0, color='blue', label='Test', alpha=0.6, s=10)

plt.legend()

ax.set_xlabel('DFT gap (eV)', fontsize='20', fontname='Arial', fontweight='bold', labelpad=5)
ax.set_ylabel('Pred. gap (eV)', fontsize='20', fontname='Arial', fontweight='bold', labelpad=5)

ax.tick_params(direction='out', length=5, width=3, colors='black', 
               grid_alpha=1, labelsize='18')

[i.set_linewidth(3) for i in ax.spines.values()]
leg = plt.legend(title='Train: R$^2$={}, MAE={} \nTest: R$^2$={}, MAE={}'.\
           format(round(r2_score(y_train0, pred_train0.reshape([-1])), 2), 
                  round (mae_train, 2),
                  round (r2_score(y_val0, pred0.reshape([-1])), 2), 
                  round (mae_val, 2), ), framealpha=0, title_fontsize=10)
leg._legend_box.align = "left"

#plt.title ('per {}, rand {}'.format(per, rand))
plt.xlim(8, 13)
plt.ylim(8, 13)
#plt.xticks((1, 3, 5, 7, 9,  11));
#plt.yticks((1, 3, 5, 7, 9,  11));
plt.plot([0, 12], [0, 12], '--k', )#color='black')
plt.tight_layout()
plt.savefig('regressor_train_val.jpeg', dpi=300)
plt.rcParams["legend.markerscale"] = 1

# %%
np.max(pred_train0)
# Out:
# 12.3320465

# %%
K.clear_session()

# %%
## Combined model 
discriminator.compile(loss = 'binary_crossentropy', optimizer = Adam(lr = 5e-5, beta_1 = 0.5))
def build_combined(z, y,
                   regressor,
                   discriminator,
                   encoder,
                   decoder):
    discriminator0.trainable = False
    regressor.trainable = False
    encoder.trainable = False
    decoder.trainable = False
    
    atoms_emb, bonds_emb = generator([z, y])
    dec_embedding = Concatenate()([atoms_emb, bonds_emb])
    
    softmax_smiles, _ = decoder([dec_embedding])
    argmax_smiles = argmax (softmax_smiles, axis=2)
    argmax_smiles = Reshape([40])(argmax_smiles)
    smiles = one_hot(argmax_smiles, depth=27)
    smiles = Reshape([40, 27, 1])(smiles)
    latent_encoder_atom, latent_encoder_bond, _ = encoder ([smiles])
    
    y_pred = regressor([latent_encoder_atom, latent_encoder_bond])
    valid = discriminator([atoms_emb, bonds_emb, y])
    #print ('valid from comb', valid)

    combined = Model([z, y], [valid, y_pred])

    combined.compile(loss = ['binary_crossentropy',
                             'mse'], 
                     loss_weights = [0.01, 25.0], 
                     optimizer = Adam(5e-6, beta_1 = 0.5))
    
    return combined

combined = build_combined(z, y,
                          regressor,
                          discriminator,
                          encoder,
                          decoder)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
discriminator.summary(line_length=200)
# Out:
# Model: "discriminator"
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#  Layer (type)                                                     Output Shape                                Param #                 Connected to
# ========================================================================================================================================================================================================
#  input_3 (InputLayer)                                             [(None, 6, 6, 1)]                           0                       []
#
#  input_4 (InputLayer)                                             [(None, 6, 6, 1)]                           0                       []
#
#  concatenate_1 (Concatenate)                                      (None, 6, 6, 2)                             0                       ['input_3[0][0]',
#                                                                                                                                        'input_4[0][0]']
#
#  flatten (Flatten)                                                (None, 72)                                  0                       ['concatenate_1[0][0]']
#
#  input_2 (InputLayer)                                             [(None, 1)]                                 0                       []
#
#  concatenate_2 (Concatenate)                                      (None, 73)                                  0                       ['flatten[0][0]',
#                                                                                                                                        'input_2[0][0]']
#
#  dense_1 (Dense)                                                  (None, 64)                                  4736                    ['concatenate_2[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)                                        (None, 64)                                  0                       ['dense_1[0][0]']
#
#  dropout (Dropout)                                                (None, 64)                                  0                       ['leaky_re_lu_6[0][0]']
#
#  dense_2 (Dense)                                                  (None, 64)                                  4160                    ['dropout[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)                                        (None, 64)                                  0                       ['dense_2[0][0]']
#
#  dropout_1 (Dropout)                                              (None, 64)                                  0                       ['leaky_re_lu_7[0][0]']
#
#  dense_3 (Dense)                                                  (None, 64)                                  4160                    ['dropout_1[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)                                        (None, 64)                                  0                       ['dense_3[0][0]']
#
#  dropout_2 (Dropout)                                              (None, 64)                                  0                       ['leaky_re_lu_8[0][0]']
#
#  mydense (Dense)                                                  (None, 1)                                   65                      ['dropout_2[0][0]']
#
# ========================================================================================================================================================================================================
# Total params: 13,121
# Trainable params: 65
# Non-trainable params: 13,056
# ________________________________________________________________________________________________________________________________________________________________________________________________________

# %%
# Train GAN on desired range 9-12
p= multiprocessing.Process()
""" Training RCGAN """
# loading pretrained models
#regressor = load_model    ('./../data/nns/regressor_trans.h5')
#regressor_top = load_model('./../data/nns/regressor_top.h5')

# unfrozen layers of G and D were already read.
#generator = load_model    ('./../data/nns/keep/generator.h5')
#discriminator = load_model ('./../data/nns/keep/discriminator.h5')
#combined = load_model ('./../data/nns/combined.h5')

regressor.trainable = False

# SMILES related information
max_gen_atoms = 9
bond_max = 9
MAX_NB_WORDS = 27
MAX_SEQUENCE_LENGTH = 40


epochs = 20
batch_size = 4
batches = y_train0.shape[0] // batch_size
threshold = 0.2 # defining accurate samples
reinforce_n = 50 # 5*reinforce_n = fake sampling
reinforce_sample = 1000 # how many samples generated for Reinforcement

# variable for storing generated data
G_Losses = []
D_Losses = []
R_Losses = []
D_Losses_real = []
D_Losses_fake = []

for e in range(epochs):
    start = time.time()
    D_loss = []
    G_loss = []
    R_loss = []
    D_loss_real = []
    D_loss_fake = []
    
    for b in range(batches):
        

        regressor.trainable = False

        idx = np.arange(b * batch_size, (b + 1) * batch_size)
        # rearrange the samples 
        idx = np.random.choice(idx, batch_size, replace = False)
        
        x_smiles_train = X_smiles_train[idx] 
        batch_y = y_gantrain[idx]
        
        batch_z = np.random.normal(0, 1, size = (batch_size, 128))
        
        atoms_embedding, bonds_embedding, _ = encoder.predict([x_smiles_train], verbose=0)
        dec_embedding = np.concatenate([atoms_embedding, bonds_embedding], axis = -1)
        
        gen_atoms_embedding, gen_bonds_embedding = generator.predict([batch_z, batch_y], verbose=0)
        
        gen_dec_embedding = np.concatenate([gen_atoms_embedding, gen_bonds_embedding], axis = -1)
        softmax_smiles = decoder.predict(gen_dec_embedding, verbose=0)[0]
        
        argmax_smiles = np.argmax(softmax_smiles, axis = 2)
        smiles = to_categorical(argmax_smiles, num_classes=27)
        SHAPE = list(smiles.shape) + [1]
        smiles = smiles.reshape(SHAPE)
        latent_encoder_atom, latent_encoder_bond, _ = encoder.predict([smiles], verbose=0)
        gen_pred = regressor.predict([latent_encoder_atom, latent_encoder_bond], verbose=0).reshape([-1])
        
        regressor.trainable = True
        r_loss = regressor.train_on_batch([atoms_embedding, bonds_embedding], batch_y)
        R_loss.append(r_loss)
        regressor.trainable = False

        discriminator.trainable = True
        discriminator0.trainable = False
        # original was 3!
        d = 3
        #if b<100:
        #    d=1
        for _ in range(d):
            d_loss_real = discriminator.train_on_batch([atoms_embedding, bonds_embedding, batch_y],
                                                       [0.9 * np.ones((batch_size, 1))])
            d_loss_fake = discriminator.train_on_batch([gen_atoms_embedding, gen_bonds_embedding, batch_y],
                                                       [np.zeros((batch_size, 1))]) 

        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
        D_loss.append(d_loss)
        D_loss_real.append (d_loss_real)
        D_loss_fake.append (d_loss_fake)
        discriminator.trainable = False
        

        regressor.trainable = False

        #for _ in range(d):
        g_loss = combined.train_on_batch([batch_z, batch_y], [0.9 * np.ones((batch_size, 1)), batch_y])
        
        G_loss.append(g_loss[0])
    
    D_Losses.append(np.mean(D_loss))
    D_Losses_real.append(np.mean(D_loss_real))
    D_Losses_fake.append(np.mean(D_loss_fake))
    G_Losses.append(np.mean(G_loss))
    R_Losses.append(np.mean(R_loss))
    
    print('====')
    print('Current epoch: {}/{}'.format((e + 1), epochs))
    print ('D Loss Real: {}'.format(np.mean(D_loss_real)))
    print ('D Loss Fake: {}'.format(np.mean(D_loss_fake)))
    print('D Loss: {}'.format(np.mean(D_loss)))
    print('G Loss: {}'.format(np.mean(G_loss)))
    print('R Loss: {}'.format(np.mean(R_loss)))
    print('====')
    print()

    
    # Reinforcement
    gen_error = []
    gen_smiles = []
    gen_valid_smiles = []
    gen_X_atoms = []
    gen_X_bonds = []
    predcv_AE_latent = []
    embeddings = []
    sample_ys = []
    valid_smiles_index = []
    for _ in range(reinforce_sample):
        # train only on data between 9 and 12
        sample_y = np.random.uniform(9, 13, size = [1, ])
        sample_y = np.round(sample_y, 4)
        sample_y = (sample_y - gap_min) / (gap_max - gap_min)
        sample_ys.append(sample_y)

        sample_z = np.random.normal(0, 1, size = (1, 128))

        sample_atoms_embedding, sample_bonds_embedding = generator.predict([sample_z, sample_y], verbose=0)
        embeddings.append((sample_atoms_embedding, sample_bonds_embedding))
        
        dec_embedding = np.concatenate([sample_atoms_embedding, sample_bonds_embedding], axis = -1)
        softmax_smiles = decoder.predict(dec_embedding, verbose=0)[0]
        argmax_smiles = np.argmax(softmax_smiles, axis = 2).reshape([-1])
        smiles = to_categorical(argmax_smiles, num_classes=27)
        SHAPE = [1] + list(smiles.shape) + [1]
        smiles = smiles.reshape(SHAPE)
        c_smiles = ''
        for s in argmax_smiles:
            c_smiles += tokenizer[s]
        c_smiles = c_smiles.rstrip()
        
        gen_smiles.append(c_smiles)
        latent_encoder_atom, latent_encoder_bond, _ = encoder.predict([smiles], verbose=0)
        reg_pred = regressor.predict([latent_encoder_atom, latent_encoder_bond], verbose=0)
        
        pred, desire = reg_pred[0][0], sample_y[0]
        gen_error.append(round (np.abs((pred - desire) / desire), 5)) #!!!!!!!!!!!!! chenge it to desire

        
    gen_error = np.asarray(gen_error).reshape(-1, 1)
    # two validity defined: 

    # without sanitizing: valid 0    
    valid = 0
    valid0 = 0
    idx_ = []
    idx0_ = []
    preds_can = []
    for iter_, smiles in enumerate(gen_smiles):
        if ' ' in smiles[:-1]:
            continue
        m  = Chem.MolFromSmiles(smiles[:-1], sanitize=True)
        m0 = Chem.MolFromSmiles(smiles[:-1], sanitize=False)
        if m0 is not None:
            valid0 += 1
            idx0_.append(iter_)
        if m is not None:
            #if len(construct_atomic_number_array(m)) <= 60:
            valid += 1
            idx_.append(iter_)
            #try:
            gen_smiles [iter_] = Chem.MolToSmiles(m, canonical=True)
            smiles_can = Chem.MolToSmiles(m, canonical=True)
            smiles_can_dot = smiles_can + '.'
            X_smiles0 = tokenizer_.texts_to_sequences([smiles_can_dot])
            X_smiles1 = pad_sequences(X_smiles0, maxlen = 40, padding = 'post')
            X_smiles2 = to_categorical(X_smiles1, num_classes=27)
            latent_encoder_atom, latent_encoder_bond, _ = encoder.predict(X_smiles2, verbose=0)
            pred_can = regressor.predict([latent_encoder_atom, latent_encoder_bond], verbose=0).reshape([-1])
            #pred_can = pred_can*15
            preds_can.append(pred_can[0])
            print (Chem.MolToSmiles(m, canonical=True))
            print ("gap_des", sample_ys[iter_])
            print ("error", gen_error[iter_])
            #except:
                #pass
    idx_ = np.asarray(idx_)

    idx0_ = np.asarray(idx0_)
    preds_can = np.array (preds_can).reshape(-1, 1)
    #print('gen error before correction:', gen_error [idx_])
    sample_ys_ = np.array (sample_ys)
    gen_error [idx_] = [(abs(i-j)/j) for i,j in zip(preds_can, sample_ys_[idx_])] 
    #print('gen error after correction:', gen_error [idx_])
    validity = [gen_smiles[jj] for jj in idx0_ ]
    validity = pd.DataFrame(validity)
    validity = validity.drop_duplicates()

    validity_sanitize = [gen_smiles[jj] for jj in idx_ ]
    validity_sanitize = pd.DataFrame(validity_sanitize)
    validity_sanitize = validity_sanitize.drop_duplicates()

    if (e + 1) % 100 == 0:
        reinforce_n += 10

    # invalid smiles:
    fake_indices1 = np.setdiff1d(np.arange(reinforce_sample), np.asarray(idx_))
    fake_indices2 = np.intersect1d(np.where(gen_error > threshold)[0], idx_)
    fake_indices = np.concatenate ((fake_indices1, fake_indices2))
    fake_indices = np.random.choice(fake_indices, reinforce_n * 5, replace = False)

    real_indices_ = np.intersect1d(np.where(gen_error <= threshold)[0], idx_)
    sample_size =  len(real_indices_)
    real_indices = np.random.choice(real_indices_, sample_size, replace = False)
    
    # Activating Reinforcement 
    if e >= 5:
        discriminator.trainable = True
        discriminator0.trainable = False

        regressor.trainable = False
        for real_index in real_indices:
            #real_latent = regressor_top.predict([embeddings[real_index][0], embeddings[real_index][1]])
            _ = discriminator.train_on_batch([embeddings[real_index][0], 
                                              embeddings[real_index][1], 
                                              sample_ys[real_index]],
                                             [1 * np.ones((1, 1))])

        for fake_index in fake_indices:
            #fake_latent = regressor_top.predict([embeddings[fake_index][0], embeddings[fake_index][1]])
            _ = discriminator.train_on_batch([embeddings[fake_index][0], 
                                              embeddings[fake_index][1] , 
                                              sample_ys[fake_index]],
                                             [np.zeros((1, 1))])
        discriminator.trainable = False

    # ==== #
    try:
        print('Currently valid SMILES (No chemical_beauty and sanitize off): {}'.format(valid0))
        print('Currently valid SMILES Unique (No chemical_beauty and sanitize off): {}'.format(len(validity)))
        print('Currently valid SMILES Sanitized: {}'.format(valid))
        print('Currently valid Unique SMILES Sanitized: {}'.format(len(validity_sanitize)))
        print('Currently satisfying SMILES: {}'.format(len(real_indices_)))
        print('Currently unique satisfying generation: {}'.format(len(np.unique(np.array(gen_smiles)[real_indices_]))))
        #print('Gen Sample is: {}, for {}'.format(c_smiles, sample_y))
        #print('Predicted val: {}'.format(reg_pred))
        print('====')
        print()
    except:
        pass
    
    if (e + 1) % 5 == 0:
        plt.close()
        fig, ax = plt.subplots(figsize = (12, 10))
        ax.tick_params(axis='both', which='major', labelsize=30)
        plt.plot(G_Losses, color='blue')
        plt.plot(D_Losses, color='red')
        plt.xlabel('epochs', fontsize=35)
        plt.ylabel('loss', fontsize=35)
        mpl.rcParams['axes.linewidth'] = 2.5
        #plt.plot(R_Losses)
        plt.legend(['G Loss', 'D Loss'], fontsize=30)
        plt.savefig("G_D_losses{}.png".format (e+1))
    

    n_unique = len(np.unique(np.array(gen_smiles)[real_indices_]))
    n_valid = valid
    if valid > 450 and n_unique > 350:
        print('Criteria has satisified, training has ended')
        break

    end = time.time()
    print ("time for current epoch: ", (end - start))

    tf.compat.v1.keras.backend.clear_session()
with open('GAN_loss.pickle', 'wb') as f:
    pickle.dump((G_Losses, D_Losses, R_Losses), f)

# Saving the currently trained models
#regressor.save('regressor.h5')
#regressor_top.save('regressor_top.h5')
generator.save('./../data/nns/generator_trans.h5')
discriminator.save('./../data/nns/discriminator_trans.h5')
combined.save('./../data/nns/combined_trans.h5')

p.start()
pred_can
p.join()
print ('Done')
# Out:
# ====
# Current epoch: 1/20
# D Loss Real: 0.5278059515026607
# D Loss Fake: 0.1427163488090179
# D Loss: 0.33526115015583935
# G Loss: 2.2448512356315304
# R Loss: 0.0004405167187846743
# ====
#
# CCCOOOCCC[SH]1CCCCCCSC1
# gap_des [0.68694]
# error [0.31516]
# CCCCN1CCCC=CC=NC=NN=CC=N1
# gap_des [0.73752]
# error [0.51333]
# Currently valid SMILES (No chemical_beauty and sanitize off): 6
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 6
# Currently valid SMILES Sanitized: 2
# Currently valid Unique SMILES Sanitized: 2
# Currently satisfying SMILES: 0
# Currently unique satisfying generation: 0
# ====
#
# time for current epoch:  267.29415822029114
# ====
# Current epoch: 2/20
# D Loss Real: 0.43997286775371247
# D Loss Fake: 0.14580988190435237
# D Loss: 0.29289137482903244
# G Loss: 1.772569134913213
# R Loss: 0.00038746456315749136
# ====
#
# C=CCc1nnccncccc1OCC
# gap_des [0.84858667]
# error [0.62348]
# NNCC1=CC=CCNNC1N
# gap_des [0.84679333]
# error [0.52172]
# NNCC12CNC1C(CO)O2
# gap_des [0.60023333]
# error [0.11909]
# COCCOOOC
# gap_des [0.69527333]
# error [0.40702]
# COCC1COC1CCC(O)OO[O]
# gap_des [0.80796667]
# error [0.31823]
# CCCOOOSCOC
# gap_des [0.78728]
# error [0.42602]
# NNC1=CC=NC=CCCCNCNCCC1
# gap_des [0.75995333]
# error [0.47265]
# Currently valid SMILES (No chemical_beauty and sanitize off): 11
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 11
# Currently valid SMILES Sanitized: 7
# Currently valid Unique SMILES Sanitized: 7
# Currently satisfying SMILES: 1
# Currently unique satisfying generation: 1
# ====
#
# time for current epoch:  271.4037871360779
# ====
# Current epoch: 3/20
# D Loss Real: 0.4668636430631485
# D Loss Fake: 0.1602899325093474
# D Loss: 0.3135767877862479
# G Loss: 1.5701472049356162
# R Loss: 0.00036864081030151875
# ====
#
# CCC12CCCCCCCCCC1CCC2
# gap_des [0.69658667]
# error [0.0901]
# O=NCO
# gap_des [0.61073333]
# error [0.39953]
# CCCOOCC
# gap_des [0.79552]
# error [0.4078]
# CCCCO
# gap_des [0.75406]
# error [0.1534]
# CCCCOCCCCCCC1CCCCCCS1
# gap_des [0.85879333]
# error [0.36543]
# CCCC1CC1CCSC1COC1OCC
# gap_des [0.72926667]
# error [0.26734]
# CC1[C]C(C)COCCCCSCC1
# gap_des [0.63692]
# error [0.25858]
# CCCCOOCC1CCCCCCCCCCC1
# gap_des [0.69423333]
# error [0.10144]
# CCCCO
# gap_des [0.61788667]
# error [0.2742]
# C1CCC2NCCCC2OC1
# gap_des [0.62654]
# error [0.24606]
# NNCNO
# gap_des [0.70357333]
# error [0.17468]
# [C]CC(C)CCCCC1CCCCC1CCC
# gap_des [0.79801333]
# error [0.29796]
# NNONNO
# gap_des [0.74203333]
# error [0.15969]
# Currently valid SMILES (No chemical_beauty and sanitize off): 16
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 15
# Currently valid SMILES Sanitized: 13
# Currently valid Unique SMILES Sanitized: 12
# Currently satisfying SMILES: 7
# Currently unique satisfying generation: 6
# ====
#
# time for current epoch:  271.2867844104767
# ====
# Current epoch: 4/20
# D Loss Real: 0.4923571551670489
# D Loss Fake: 0.19013430602496728
# D Loss: 0.3412457305960081
# G Loss: 1.394208050258335
# R Loss: 0.0003507582048167105
# ====
#
# CCCCCCC.CCCCCCCCCCCC
# gap_des [0.79132]
# error [0.1953]
# CCSC
# gap_des [0.76955333]
# error [0.27881]
# CSCCC1CC2CC2CCCCOC1C
# gap_des [0.85101333]
# error [0.38646]
# CCCOOCCC1OCC(CC)OC1C
# gap_des [0.60911333]
# error [0.03761]
# ON1CC12C=CC=CC2
# gap_des [0.78452]
# error [0.45803]
# CCCCCCCC
# gap_des [0.73245333]
# error [0.22735]
# CCCCOCCCC
# gap_des [0.61766]
# error [0.02815]
# CCCCO
# gap_des [0.68170667]
# error [0.05967]
# CCOOC
# gap_des [0.78868667]
# error [0.22444]
# C#CCNCCC
# gap_des [0.81926667]
# error [0.37902]
# CCNC1CC1
# gap_des [0.61450667]
# error [0.13571]
# CCNOC
# gap_des [0.82981333]
# error [0.29756]
# [C]CCCCC1CCCCC2CCCC12CC
# gap_des [0.80289333]
# error [0.33201]
# CSCON
# gap_des [0.7022]
# error [0.28044]
# CCCCCCC
# gap_des [0.63819333]
# error [0.10659]
# C.C#CCC
# gap_des [0.64741333]
# error [0.08705]
# [2H]SC(C)CCCCCCC1CC1
# gap_des [0.70454667]
# error [0.23734]
# CCCCCCC.CCCCCCCCCCCC
# gap_des [0.70206]
# error [0.09299]
# Currently valid SMILES (No chemical_beauty and sanitize off): 22
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 21
# Currently valid SMILES Sanitized: 18
# Currently valid Unique SMILES Sanitized: 17
# Currently satisfying SMILES: 9
# Currently unique satisfying generation: 8
# ====
#
# time for current epoch:  282.0009319782257
# ====
# Current epoch: 5/20
# D Loss Real: 0.5051796396071773
# D Loss Fake: 0.21190824156446111
# D Loss: 0.3585439405858192
# G Loss: 1.2770995372082348
# R Loss: 0.0003322414600827737
# ====
#
# CC.CCCCS
# gap_des [0.69858]
# error [0.2409]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.83804667]
# error [0.21938]
# CCCCCCCCCCCCCCCCCOCC
# gap_des [0.70716]
# error [0.09187]
# COOC
# gap_des [0.74052667]
# error [0.36912]
# CCCCCCCCCCCCCCCCOCCC
# gap_des [0.84253333]
# error [0.23834]
# C1CC1
# gap_des [0.61156]
# error [0.08139]
# CCNN
# gap_des [0.69309333]
# error [0.17911]
# COOC
# gap_des [0.80916667]
# error [0.295]
# C#CCCCCCCCCC
# gap_des [0.62032]
# error [0.15465]
# CCCCCCCCCCCC1CCCCCC1
# gap_des [0.69412667]
# error [0.07437]
# CCC1CCCC1CSCCCCCCCSC
# gap_des [0.79953333]
# error [0.41576]
# CCCCCCSCCCCCCS.CCCCO
# gap_des [0.82791333]
# error [0.35428]
# CCC(CC(C)CPOC)C(C)O
# gap_des [0.63718]
# error [0.11487]
# C#CCCCC
# gap_des [0.68209333]
# error [0.23079]
# CCCCO
# gap_des [0.84856667]
# error [0.47216]
# CCOOC
# gap_des [0.73048]
# error [0.16331]
# C.C#CC
# gap_des [0.682]
# error [0.14563]
# CC.CCCC
# gap_des [0.86509333]
# error [0.25323]
# C#CCCCCCCCCCCCCCCCCC
# gap_des [0.79036]
# error [0.20048]
# CCCCCCCCC#CCCCCCCCCC
# gap_des [0.67576667]
# error [0.08195]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.78196667]
# error [0.16339]
# Currently valid SMILES (No chemical_beauty and sanitize off): 25
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 23
# Currently valid SMILES Sanitized: 21
# Currently valid Unique SMILES Sanitized: 19
# Currently satisfying SMILES: 10
# Currently unique satisfying generation: 10
# ====
#
# time for current epoch:  290.30603766441345
# ====
# Current epoch: 6/20
# D Loss Real: 0.5227380865033712
# D Loss Fake: 0.2304417882247549
# D Loss: 0.37658993736406304
# G Loss: 1.2198738461292864
# R Loss: 0.00032360762033891745
# ====
#
# CCCOOOCCCC1C2CCC(C)C12
# gap_des [0.79753333]
# error [0.21094]
# C[C][C]C1CCCCCCC1C#N
# gap_des [0.67232667]
# error [0.41732]
# CCCCC1CC1CCCCCCCSCOC
# gap_des [0.84666667]
# error [0.36075]
# C#CC1CCCCCCC2CC(C2)N1
# gap_des [0.67446667]
# error [0.13675]
# CCCCCCC.CCCCCCCCCCCC
# gap_des [0.85421333]
# error [0.25152]
# CNOC
# gap_des [0.63814]
# error [0.05212]
# [CH]C(CO)CCCCCCCCCCC
# gap_des [0.73982667]
# error [0.2185]
# C#CC12CC1CCCCCC2OC
# gap_des [0.79589333]
# error [0.372]
# C#CC.CC
# gap_des [0.81466667]
# error [0.28985]
# CCCCOCCCCCCCCCCCCCCS
# gap_des [0.807]
# error [0.28313]
# C.C=CCC
# gap_des [0.60082667]
# error [0.09929]
# CCC=CCCCCCCCCCCOCCCC
# gap_des [0.79874]
# error [0.30211]
# C#CCC[C]C1(CCC)SCCS1
# gap_des [0.76974667]
# error [0.47203]
# C#CCCCCCCC[C]CCCCCCl
# gap_des [0.80562667]
# error [0.39538]
# CCCCCCCCCCCCCCCCOCCC
# gap_des [0.71370667]
# error [0.10124]
# CC#CCCCCCCCCCCCCC[S]
# gap_des [0.83232]
# error [0.52305]
# CCCCC=CCCSCC#CCCCCCC
# gap_des [0.77984667]
# error [0.45888]
# [CH]CCC1CCCCCCCC1CCN
# gap_des [0.61336667]
# error [0.13823]
# CCCCCCCCCCCCCCCOCCCC
# gap_des [0.7696]
# error [0.17146]
# C#CCCCCC
# gap_des [0.79157333]
# error [0.34682]
# CCCCCCCCC1CCCCCCCCC1
# gap_des [0.67822667]
# error [0.056]
# CC.CCCCN
# gap_des [0.62386667]
# error [0.02016]
# CCCCC1CCCCCCC2CC2CC1
# gap_des [0.75541333]
# error [0.17439]
# C.CCCCCCCCC1CCCCCCCCC1
# gap_des [0.71563333]
# error [0.10888]
# Currently valid SMILES (No chemical_beauty and sanitize off): 27
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 27
# Currently valid SMILES Sanitized: 24
# Currently valid Unique SMILES Sanitized: 24
# Currently satisfying SMILES: 9
# Currently unique satisfying generation: 9
# ====
#
# time for current epoch:  290.80955171585083
# ====
# Current epoch: 7/20
# D Loss Real: 0.5376724161117713
# D Loss Fake: 0.22976206999443854
# D Loss: 0.3837172430531049
# G Loss: 1.136235313406204
# R Loss: 0.00031346948097518744
# ====
#
# CCCOS
# gap_des [0.74477333]
# error [0.3655]
# [N][N]C1CCCCCC12CC2
# gap_des [0.73836]
# error [0.31896]
# C#CCCCCCC#CCCCCCCCCC
# gap_des [0.85629333]
# error [0.29591]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.81591333]
# error [0.19912]
# CCOCC1CCC2CC1C1CCC21
# gap_des [0.682]
# error [0.10298]
# CCCCCCC[C]CCCCCCCCSC
# gap_des [0.777]
# error [0.40922]
# CCCCCCCCCCCC1CCCCCC1
# gap_des [0.73380667]
# error [0.14013]
# CNC
# gap_des [0.82484]
# error [0.25034]
# CCCCC
# gap_des [0.74367333]
# error [0.10226]
# OCCCC=CCCSCC1CCCCCC1
# gap_des [0.78986]
# error [0.52427]
# CCCC=CCC1CCCCCC[C]1N
# gap_des [0.67678667]
# error [0.38185]
# CCCCCCCCCSCC1CCCCCC1
# gap_des [0.77814667]
# error [0.30646]
# CCCC1CCCC1CC1CCCCCC1
# gap_des [0.60384]
# error [0.03383]
# CC1CCCCC1CCCCCCSCCCO
# gap_des [0.67696]
# error [0.16068]
# CC.CCCC
# gap_des [0.70184667]
# error [0.07245]
# CCCCOCCCCCCCCCCCCCCS
# gap_des [0.6981]
# error [0.16027]
# CCCCCCCCCCCC1CCCCCC1
# gap_des [0.81762]
# error [0.21148]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.81276667]
# error [0.19602]
# CCCC#CCCCCCCCCCSC
# gap_des [0.85956667]
# error [0.47329]
# C#CCSCCCCSCCCCCCCC#[SH]
# gap_des [0.60725333]
# error [0.27135]
# C#CCCCCCC1CCC1C
# gap_des [0.77775333]
# error [0.39636]
# CCCCCCC.CCCCCCCSOCCC
# gap_des [0.60062667]
# error [0.09422]
# Currently valid SMILES (No chemical_beauty and sanitize off): 29
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 27
# Currently valid SMILES Sanitized: 22
# Currently valid Unique SMILES Sanitized: 20
# Currently satisfying SMILES: 10
# Currently unique satisfying generation: 9
# ====
#
# time for current epoch:  291.8822383880615
# ====
# Current epoch: 8/20
# D Loss Real: 0.5421400209224315
# D Loss Fake: 0.24655275041688313
# D Loss: 0.39434638566965735
# G Loss: 1.1065476576252773
# R Loss: 0.00030311275636746873
# ====
#
# CCNNC
# gap_des [0.65963333]
# error [0.1474]
# CCCCC
# gap_des [0.84452667]
# error [0.2168]
# COCCO
# gap_des [0.85442]
# error [0.26027]
# CCCCC1CCCCCC1C1CCCCC1
# gap_des [0.81958]
# error [0.27877]
# C=CCCCCC
# gap_des [0.72066]
# error [0.30722]
# COCCO
# gap_des [0.63212667]
# error [0.00014]
# COCCO
# gap_des [0.69212]
# error [0.08681]
# CCCCCCCCC
# gap_des [0.60268667]
# error [0.03208]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.65944667]
# error [0.00901]
# CCC1CCCCC1CC1CCC(C)CC1
# gap_des [0.76810667]
# error [0.1824]
# CCCCCCCC1CCCCCC1COCC
# gap_des [0.79512]
# error [0.20884]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.86451333]
# error [0.24408]
# CCCCCCCC
# gap_des [0.79694]
# error [0.2804]
# C#CC1CCCCCCC1P[P][O]
# gap_des [0.8376]
# error [0.53791]
# CCCCOCCC
# gap_des [0.64823333]
# error [0.16649]
# CCCCCCCCCCCCCCCCCCSC
# gap_des [0.7178]
# error [0.17905]
# [C]CCCCCCCCC#CC
# gap_des [0.63227333]
# error [0.44694]
# CCC#CCCCCCCCCCCCCCCC
# gap_des [0.79381333]
# error [0.22959]
# [C][C]C[C]CC1CCC1C#C
# gap_des [0.64379333]
# error [0.49805]
# C#COC.CCCC1CCCCCCCCC1
# gap_des [0.85827333]
# error [0.30935]
# C[C][CH]CCCCCCCCCCCC
# gap_des [0.76158667]
# error [0.3749]
# CCOC
# gap_des [0.63872]
# error [0.14707]
# CC#CCCCCCCCC1CCSC1CCCC
# gap_des [0.81924667]
# error [0.41646]
# C#CCCCCCCCCCCCC.CCCO
# gap_des [0.73399333]
# error [0.13806]
# CCOC
# gap_des [0.72915333]
# error [0.15239]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.64442]
# error [0.0141]
# Currently valid SMILES (No chemical_beauty and sanitize off): 30
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 25
# Currently valid SMILES Sanitized: 26
# Currently valid Unique SMILES Sanitized: 21
# Currently satisfying SMILES: 11
# Currently unique satisfying generation: 8
# ====
#
# time for current epoch:  292.6339416503906
# ====
# Current epoch: 9/20
# D Loss Real: 0.5447104690692558
# D Loss Fake: 0.2460891602690711
# D Loss: 0.39539981466916346
# G Loss: 1.0641691264717887
# R Loss: 0.00029539820826616326
# ====
#
# C#CCCCCCCCCCCCCCCCCC
# gap_des [0.85342]
# error [0.26411]
# CC(C)CCCC1[C][CH]CC1
# gap_des [0.69452]
# error [0.3814]
# COCC1CCCCCCCSC1S[NH]
# gap_des [0.77684667]
# error [0.34627]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.73673333]
# error [0.11316]
# CCOCCCCC1CCC(CCC(C)C)C1
# gap_des [0.80808]
# error [0.21083]
# CCCCCCCC
# gap_des [0.65998]
# error [0.1286]
# CCCCCCC
# gap_des [0.68241333]
# error [0.15879]
# CCCCCCCCCCCCCCCCOCCC
# gap_des [0.84218]
# error [0.23178]
# CCCCSCCC
# gap_des [0.73869333]
# error [0.29922]
# CC#CCCCCC1CCCCCC1CC
# gap_des [0.72088667]
# error [0.17491]
# CCCC1CCC1SCCCC1CCC1C
# gap_des [0.66935333]
# error [0.17667]
# CCOO
# gap_des [0.79099333]
# error [0.25607]
# CCCCCCCCC1CCCCCCCC1N
# gap_des [0.80499333]
# error [0.23746]
# CCCCO
# gap_des [0.69500667]
# error [0.06608]
# C1CCC2CCC3CCCCC3C(CC1)C2
# gap_des [0.63904667]
# error [0.01789]
# COOC
# gap_des [0.68540667]
# error [0.16403]
# Currently valid SMILES (No chemical_beauty and sanitize off): 19
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 19
# Currently valid SMILES Sanitized: 16
# Currently valid Unique SMILES Sanitized: 16
# Currently satisfying SMILES: 7
# Currently unique satisfying generation: 7
# ====
#
# time for current epoch:  291.8436076641083
# ====
# Current epoch: 10/20
# D Loss Real: 0.5457775106676062
# D Loss Fake: 0.255656106930132
# D Loss: 0.4007168087988691
# G Loss: 1.0972317013926354
# R Loss: 0.0002849570889643788
# ====
#
# CCCCCCO.CCCOSCCCCCCN
# gap_des [0.68354]
# error [0.22147]
# CCCCC1CC2CC12CC=COCC
# gap_des [0.73716667]
# error [0.26008]
# CC.CCCCS
# gap_des [0.81247333]
# error [0.33206]
# CCCCCCC#CC#CCCCCCCCC
# gap_des [0.62167333]
# error [0.13024]
# CCCCC1CCCCCC1C1CCC1C
# gap_des [0.76638]
# error [0.18857]
# C#COCCCCC1[C][CH]CC1
# gap_des [0.72747333]
# error [0.4272]
# CCOC
# gap_des [0.83321333]
# error [0.25946]
# C#CCCCCCC1CC2CCCCC12
# gap_des [0.6292]
# error [0.00809]
# CCOC
# gap_des [0.72792]
# error [0.15234]
# CCCCCCCC
# gap_des [0.60192]
# error [0.06143]
# CCCCCCCCCCCC1CCCCCCC1
# gap_des [0.86514667]
# error [0.3282]
# CCCCP
# gap_des [0.81644]
# error [0.26182]
# CCCC1CCCC2CC1CCCCCC2OC
# gap_des [0.72928]
# error [0.13602]
# CCOCOCCC1OC12CCCCCC2
# gap_des [0.63675333]
# error [0.00073]
# COCCSCCCC1CC[CH]CCC1
# gap_des [0.84308]
# error [0.45308]
# Currently valid SMILES (No chemical_beauty and sanitize off): 17
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 16
# Currently valid SMILES Sanitized: 15
# Currently valid Unique SMILES Sanitized: 14
# Currently satisfying SMILES: 8
# Currently unique satisfying generation: 8
# ====
#
# time for current epoch:  292.9891314506531
# ====
# Current epoch: 11/20
# D Loss Real: 0.5610500223419407
# D Loss Fake: 0.2555245173559345
# D Loss: 0.4082872698489376
# G Loss: 1.0368007748386732
# R Loss: 0.0002701897092814517
# ====
#
# CCOCC
# gap_des [0.67798]
# error [0.04896]
# CCCC1CCCC1CC1CCCCCC1
# gap_des [0.66214667]
# error [0.04783]
# CCCCCCCCCSCC1CCCCCC1
# gap_des [0.70206667]
# error [0.22981]
# C#CC1[C]SCCC2CC2CCC1
# gap_des [0.77855333]
# error [0.41609]
# CCCCC
# gap_des [0.85431333]
# error [0.21931]
# CC(C)CCCCCCC1CCCCCCC1C
# gap_des [0.80456667]
# error [0.19998]
# CCCCCCCCCSCC1CCCCCCC1C
# gap_des [0.69768667]
# error [0.21281]
# CCOC
# gap_des [0.85806]
# error [0.37026]
# CC=CCCCC
# gap_des [0.81085333]
# error [0.41574]
# CCCCCCOC
# gap_des [0.81083333]
# error [0.30983]
# CCCC1CCCCCCC2CC2CCC1
# gap_des [0.79628]
# error [0.19964]
# CCCC1CCCCCCCC1
# gap_des [0.74634667]
# error [0.23895]
# Currently valid SMILES (No chemical_beauty and sanitize off): 16
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 16
# Currently valid SMILES Sanitized: 12
# Currently valid Unique SMILES Sanitized: 12
# Currently satisfying SMILES: 5
# Currently unique satisfying generation: 5
# ====
#
# time for current epoch:  291.99235129356384
# ====
# Current epoch: 12/20
# D Loss Real: 0.5624844483565028
# D Loss Fake: 0.25894198734027
# D Loss: 0.41071321784838644
# G Loss: 1.0340154090186766
# R Loss: 0.0002593180459472901
# ====
#
# CCC.C[C]CCCCCCCCCCCC
# gap_des [0.66453333]
# error [0.1985]
# CCCCCCCCC1CC1CCCCCCC
# gap_des [0.69665333]
# error [0.09342]
# C#CCCCCCC1CC1CC1CCC1
# gap_des [0.64807333]
# error [0.03979]
# C[C][CH]CCCCCCCCOCCC
# gap_des [0.79688667]
# error [0.43]
# CCCCCC#N
# gap_des [0.65230667]
# error [0.09746]
# CCCCCCCCC1CC1CCCCCCC
# gap_des [0.79022667]
# error [0.20077]
# CCCCCCCCCCCC1CCCCCC1
# gap_des [0.77698667]
# error [0.16614]
# CNCCCOCCCSCC1CCCCCC1
# gap_des [0.68265333]
# error [0.23447]
# COCCSCCCCC[CH]CCCCCl
# gap_des [0.61231333]
# error [0.22604]
# C1CCSCCC2CSCCCCC2CC1
# gap_des [0.85098667]
# error [0.4163]
# Currently valid SMILES (No chemical_beauty and sanitize off): 13
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 12
# Currently valid SMILES Sanitized: 10
# Currently valid Unique SMILES Sanitized: 9
# Currently satisfying SMILES: 7
# Currently unique satisfying generation: 6
# ====
#
# time for current epoch:  289.01104640960693
# ====
# Current epoch: 13/20
# D Loss Real: 0.5687608254008183
# D Loss Fake: 0.2577271901405111
# D Loss: 0.4132440077706647
# G Loss: 0.9881538123374909
# R Loss: 0.0002533995003556005
# ====
#
# CCCCCCCCC#CCCCCCCCCC
# gap_des [0.79058667]
# error [0.20609]
# CCCCCCCCCCCCCCCCCCCS
# gap_des [0.7768]
# error [0.24074]
# CCCCCCCCC1CC1CCCCCCC
# gap_des [0.72154]
# error [0.12449]
# CCCCCCCCC1CCCCCCCCC1
# gap_des [0.82822667]
# error [0.2313]
# [CH]1OC2CCCCC(C2)CC2CC12
# gap_des [0.62332]
# error [0.0703]
# CCCCCCC.CCCCCCCCCCCC
# gap_des [0.60383333]
# error [0.06758]
# N#CC1[C][CH]CCSCCCC1
# gap_des [0.69558667]
# error [0.43393]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.63051333]
# error [0.03638]
# C[C]SCCCCCCCCCCCCCCC
# gap_des [0.74074]
# error [0.357]
# CCCCSCCCCSCC1CCCCCC1
# gap_des [0.85265333]
# error [0.41752]
# C#CCSCCCC1[C][CH]CC1
# gap_des [0.78053333]
# error [0.50708]
# Currently valid SMILES (No chemical_beauty and sanitize off): 12
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 12
# Currently valid SMILES Sanitized: 11
# Currently valid Unique SMILES Sanitized: 11
# Currently satisfying SMILES: 4
# Currently unique satisfying generation: 4
# ====
#
# time for current epoch:  287.8285629749298
# ====
# Current epoch: 14/20
# D Loss Real: 0.5746978913913312
# D Loss Fake: 0.26395544294588896
# D Loss: 0.4193266671686101
# G Loss: 1.0210483556635817
# R Loss: 0.000247352265639867
# ====
#
# C[C][CH]CC#CCCCCCCCC
# gap_des [0.79828]
# error [0.46062]
# OCCC1=CCCC1C1OC(CO)CP1
# gap_des [0.75080667]
# error [0.30996]
# CCCCCCCCC#CCCCCC(C)C
# gap_des [0.7501]
# error [0.16742]
# CCC12CCC1CCCCC[C]1CC12
# gap_des [0.68465333]
# error [0.24711]
# CC#CCCC
# gap_des [0.78456667]
# error [0.3721]
# CCCC
# gap_des [0.76259333]
# error [0.22742]
# CCCCOCCCC1[C]CCCCCC1
# gap_des [0.82312]
# error [0.33317]
# CC#CCCCCCCC1CCCCCC1C
# gap_des [0.79265333]
# error [0.19456]
# C#CC
# gap_des [0.65003333]
# error [0.11873]
# CCCCCCCCC1CC2CCCCC12
# gap_des [0.78626667]
# error [0.18624]
# CCCCCCCCC#CCCCCCCCCC
# gap_des [0.64924667]
# error [0.03746]
# C#CCCCCCCC[C]CCCSCCC
# gap_des [0.75394]
# error [0.45463]
# CCCC#CCCC1C=C1C(C)CCCCF
# gap_des [0.86266667]
# error [0.3034]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.73738]
# error [0.11465]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.67865333]
# error [0.03804]
# CCCCCCCCC1[C]CCCCCC1
# gap_des [0.82983333]
# error [0.40028]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.71838]
# error [0.09124]
# Currently valid SMILES (No chemical_beauty and sanitize off): 19
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 17
# Currently valid SMILES Sanitized: 17
# Currently valid Unique SMILES Sanitized: 15
# Currently satisfying SMILES: 8
# Currently unique satisfying generation: 6
# ====
#
# time for current epoch:  290.1592466831207
# ====
# Current epoch: 15/20
# D Loss Real: 0.5780955399953965
# D Loss Fake: 0.2731428964004231
# D Loss: 0.4256192181979099
# G Loss: 1.0107141753983746
# R Loss: 0.00023901900463028057
# ====
#
# CCCCCCCCCSCC1CCCCCC1
# gap_des [0.73837333]
# error [0.26271]
# [CH]1CCCCNCCCC2CC12
# gap_des [0.60839333]
# error [0.18554]
# CCCCCCCCC#CCCCCCCCCC
# gap_des [0.76853333]
# error [0.18475]
# CCC#CCCCC1CC2CCCCC12
# gap_des [0.7901]
# error [0.2215]
# C=CCS#CCCC[CH]CC(C)CCC
# gap_des [0.75566]
# error [0.51866]
# C1CC1
# gap_des [0.80285333]
# error [0.17749]
# CCC.CCCC
# gap_des [0.73867333]
# error [0.12497]
# C1CC1
# gap_des [0.69644667]
# error [0.20999]
# CCCCCC(C)C#CCCCCCOCC
# gap_des [0.67906667]
# error [0.0964]
# CCCCCCC.CCCCCCCCCCCC
# gap_des [0.75629333]
# error [0.14543]
# CCCCNCCCCCCC1CCCCCCC1
# gap_des [0.82662667]
# error [0.25107]
# CCCCCCCCCSCC
# gap_des [0.78030667]
# error [0.37803]
# COCC1CCCCCCCCCCCCCC1
# gap_des [0.77328]
# error [0.15834]
# Currently valid SMILES (No chemical_beauty and sanitize off): 15
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 14
# Currently valid SMILES Sanitized: 13
# Currently valid Unique SMILES Sanitized: 12
# Currently satisfying SMILES: 7
# Currently unique satisfying generation: 6
# ====
#
# time for current epoch:  292.1109986305237
# ====
# Current epoch: 16/20
# D Loss Real: 0.5871670878155957
# D Loss Fake: 0.28415416266488547
# D Loss: 0.4356606252402406
# G Loss: 0.9598957883474202
# R Loss: 0.00022601258868988416
# ====
#
# CCCCCCCCC1CC1CCCCCCC
# gap_des [0.72842667]
# error [0.13223]
# C#CCCCCCC#CC1CCC1CCC
# gap_des [0.62534]
# error [0.09351]
# C#CCCCCCC
# gap_des [0.64449333]
# error [0.18861]
# COCCO
# gap_des [0.69370667]
# error [0.08015]
# [CH][SH]CCCCCCCNCC=O
# gap_des [0.74356667]
# error [0.45441]
# CCCC1CCCCCCC2CC2CCC1
# gap_des [0.71434]
# error [0.10715]
# C.CCCCCCCCC1CC1CCCCCCC
# gap_des [0.81472667]
# error [0.20569]
# CCCCCCCNC
# gap_des [0.64992]
# error [0.17565]
# C1CC12CC1SC12
# gap_des [0.60726667]
# error [0.16415]
# CCC12CCCC1CC1CCCCC12
# gap_des [0.68302667]
# error [0.07678]
# CCCCOOCCCSCP1CCCCC1C
# gap_des [0.6663]
# error [0.20609]
# CCC.CCCNC
# gap_des [0.68596667]
# error [0.13099]
# CCCC=CCCCCCCCCCCCCS
# gap_des [0.78292667]
# error [0.39308]
# CCCC
# gap_des [0.72832667]
# error [0.09313]
# CCCCCCCCC1CC2CCCCC12
# gap_des [0.76910667]
# error [0.16295]
# CCCCOCCCCCCCC[C](C)C
# gap_des [0.64716667]
# error [0.08892]
# CCCC1CCCCCCC2CSC2CC1
# gap_des [0.63773333]
# error [0.15626]
# Currently valid SMILES (No chemical_beauty and sanitize off): 17
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 17
# Currently valid SMILES Sanitized: 17
# Currently valid Unique SMILES Sanitized: 17
# Currently satisfying SMILES: 13
# Currently unique satisfying generation: 13
# ====
#
# time for current epoch:  295.7614440917969
# ====
# Current epoch: 17/20
# D Loss Real: 0.5767636268709415
# D Loss Fake: 0.2748816878827234
# D Loss: 0.42582265737683245
# G Loss: 1.0029254931420841
# R Loss: 0.00022668300154270375
# ====
#
# C#CC.CC
# gap_des [0.60830667]
# error [0.02762]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.60789333]
# error [0.0771]
# CCCCCCCC1CC1CCCCOCCC
# gap_des [0.83517333]
# error [0.24167]
# CCCCCC1CCC2CCCCCCC12
# gap_des [0.85213333]
# error [0.24808]
# CC#CCCCCC1CC2CCCCC12
# gap_des [0.67994]
# error [0.06455]
# CCCCCCCCC
# gap_des [0.71616]
# error [0.08487]
# CCCCCCCCC1CC1CCCCCCC
# gap_des [0.76730667]
# error [0.17762]
# CCCCOCCCC1CC2CC12COCOO
# gap_des [0.82486]
# error [0.24752]
# CCCCCCCCC1CC2CCCCCC12
# gap_des [0.81684667]
# error [0.24703]
# CCCC1CCCCCCC2CC2CCC1
# gap_des [0.63285333]
# error [0.0075]
# CCCCCCCCC#CCCCCCCCCC
# gap_des [0.73048]
# error [0.13877]
# CCCCCCCCC1CC1CCCCCCC
# gap_des [0.61746667]
# error [0.02195]
# CCCC1C[C][CH]CCCCCCC1
# gap_des [0.7915]
# error [0.4553]
# CCNC
# gap_des [0.72119333]
# error [0.22024]
# CCCC1CCCCCCC2CC2CCC1
# gap_des [0.78168667]
# error [0.33211]
# CCCCCCCCC1CC1CC1CCC1O
# gap_des [0.78322]
# error [0.25891]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.83775333]
# error [0.21843]
# CCCCCCCCCC[C]CCCCCCS
# gap_des [0.7822]
# error [0.44179]
# C1CCCC2SC2CC2(CCC1)CC2
# gap_des [0.76734667]
# error [0.27537]
# CCCCCCCCCSCC1CCCCCC1
# gap_des [0.82969333]
# error [0.34836]
# CCCCCCCCC1CC1CCCCCCC
# gap_des [0.67142]
# error [0.06017]
# Currently valid SMILES (No chemical_beauty and sanitize off): 21
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 17
# Currently valid SMILES Sanitized: 21
# Currently valid Unique SMILES Sanitized: 17
# Currently satisfying SMILES: 12
# Currently unique satisfying generation: 9
# ====
#
# time for current epoch:  290.3740577697754
# ====
# Current epoch: 18/20
# D Loss Real: 0.5863868163001
# D Loss Fake: 0.2743861164001116
# D Loss: 0.43038646635010586
# G Loss: 0.9736887673253416
# R Loss: 0.00021719425384268928
# ====
#
# CCCCCCCCCSCC1CCCCCC1
# gap_des [0.63214667]
# error [0.13818]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.80544]
# error [0.18985]
# C#CCCCCCCSCC1CCCCCC1
# gap_des [0.85228667]
# error [0.36521]
# CCCCCCCC1CC1CCCCOCCC
# gap_des [0.84596]
# error [0.24897]
# CCCCCCCC
# gap_des [0.81833333]
# error [0.2975]
# CCCCCCCC
# gap_des [0.74790667]
# error [0.23135]
# CCOC1CCCCSCC2CCCCC21
# gap_des [0.73936]
# error [0.31289]
# CCCCCCCCC1CC1CCCCCCC
# gap_des [0.80348667]
# error [0.215]
# Currently valid SMILES (No chemical_beauty and sanitize off): 8
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 7
# Currently valid SMILES Sanitized: 8
# Currently valid Unique SMILES Sanitized: 7
# Currently satisfying SMILES: 4
# Currently unique satisfying generation: 3
# ====
#
# time for current epoch:  280.0836431980133
# ====
# Current epoch: 19/20
# D Loss Real: 0.5865202654402552
# D Loss Fake: 0.2876757681650916
# D Loss: 0.4370980168026734
# G Loss: 0.9036294145532091
# R Loss: 0.0002096459563206049
# ====
#
# CCCCCCCCC#CC1CCCCCC1
# gap_des [0.68778667]
# error [0.08976]
# C#CC1[C][C]C2CC2CCC1
# gap_des [0.61832]
# error [0.29409]
# CCCC1CCCCCCC2CCSCC12
# gap_des [0.82364]
# error [0.30711]
# C[C]S
# gap_des [0.64566]
# error [0.36323]
# CCCC
# gap_des [0.83061333]
# error [0.20981]
# CCC#CCCCC#CC1CCCCCC1
# gap_des [0.60264]
# error [0.01654]
# CC1CCCCCC2CC2CC2CC12C
# gap_des [0.66864]
# error [0.10356]
# CCCCCCCCC1CC2CCCCC12OC
# gap_des [0.69933333]
# error [0.08846]
# CCCCCCCCCCCCCCCCCCCC
# gap_des [0.68224667]
# error [0.04586]
# CCCCCCCCCSCC1CCCCCC1
# gap_des [0.65938]
# error [0.17459]
# COCCC1CCCSCC12CCCCCC2
# gap_des [0.6065]
# error [0.16906]
# CCCCCCCCCCCCCCCC(C)C
# gap_des [0.74873333]
# error [0.13445]
# CCCC1CCC12CCCC1CC1C2
# gap_des [0.65823333]
# error [0.03243]
# NCCC1[C]CCCC2CC2CCC1
# gap_des [0.64306]
# error [0.1657]
# CCCCCC#N
# gap_des [0.85898]
# error [0.32194]
# C#CCC=CCC#CC1CCCCCC1
# gap_des [0.64108]
# error [0.29796]
# CCCCCCCCC1CC2CCCCC12
# gap_des [0.79583333]
# error [0.19804]
# CCCCCCCCC#CCCCCCCCCC
# gap_des [0.76761333]
# error [0.17825]
# CCCCCCCCC1CC2CCCCCC12C
# gap_des [0.78754]
# error [0.21628]
# CCCCCCCCC#CC1CCCCCC1
# gap_des [0.71296667]
# error [0.12191]
# Currently valid SMILES (No chemical_beauty and sanitize off): 21
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 20
# Currently valid SMILES Sanitized: 20
# Currently valid Unique SMILES Sanitized: 19
# Currently satisfying SMILES: 12
# Currently unique satisfying generation: 11
# ====
#
# time for current epoch:  285.54623675346375
# ====
# Current epoch: 20/20
# D Loss Real: 0.5856117764825224
# D Loss Fake: 0.2839449297505892
# D Loss: 0.4347783531165558
# G Loss: 0.949524287187569
# R Loss: 0.000200903484167728
# ====
#
# C[C][CH]CCCCCCCCCOCC
# gap_des [0.61884]
# error [0.24298]
# CCCCCCCC
# gap_des [0.85598]
# error [0.3134]
# C#CCCCCCCSCC
# gap_des [0.64689333]
# error [0.23973]
# C#CCCCCCCCCC1[C]C1CC
# gap_des [0.68453333]
# error [0.24867]
# C#CC1CCCC1CC1[CH]CC1
# gap_des [0.63622667]
# error [0.16529]
# C=CCCCC
# gap_des [0.68082]
# error [0.24349]
# CCCCCCCCC1CC1CCCCCCC
# gap_des [0.60342667]
# error [0.04465]
# CC#CCCCCCSCC1CCCCCC1
# gap_des [0.84731333]
# error [0.40365]
# CCCCCCCCCCSCCCCCCCCC
# gap_des [0.76400667]
# error [0.23215]
# CCCCCCCC
# gap_des [0.75453333]
# error [0.23637]
# CCCCCCCCC#CCCCCCCCCC
# gap_des [0.70389333]
# error [0.10526]
# CCCCC[C]CCCCCCCCCCCC
# gap_des [0.65683333]
# error [0.21836]
# CCCCCCCCCCCCCCCCCCOC
# gap_des [0.81026]
# error [0.19787]
# CNCC1OCC1CCC#N
# gap_des [0.82388667]
# error [0.27634]
# CCCCCCCCC1CC1C1CCCC1
# gap_des [0.66767333]
# error [0.07605]
# CCCCCCCCC1[C]CCCCCC1
# gap_des [0.81359333]
# error [0.35833]
# C#CCCCCC
# gap_des [0.65028667]
# error [0.19761]
# CCCC1CCCCCCC2CC2CCC1
# gap_des [0.67418]
# error [0.05968]
# Currently valid SMILES (No chemical_beauty and sanitize off): 20
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 19
# Currently valid SMILES Sanitized: 18
# Currently valid Unique SMILES Sanitized: 17
# Currently satisfying SMILES: 9
# Currently unique satisfying generation: 9
# ====
#
# time for current epoch:  282.1533622741699
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done

# %%
tf.compat.v1.keras.backend.clear_session()

# %%
encoder = load_model('./../data/nns/encoder_trans.h5')
decoder = load_model('./../data/nns/decoder_trans.h5')
#model = load_model('./../data/nns/ae_model_trans.h5')

#regressor = load_model    ('./../data/nns/keep/regressor.h5')
#regressor_top = load_model('./../data/nns/keep/regressor_top.h5')
#generator = load_model    ('./../data/nns/keep/generator_trans.h5')
#discriminator= load_model ('./../data/nns/keep/discriminator_trans.h5')

pbar = ProgressBar()
max = 0.3

randS = []
rsquaredS = []
MAE_S = []
less20RE_perS = []
output_lenS = []
mean_RE_S = []
np.random.seed(420)
sample_yss = np.random.uniform(8, 15, size=500)

for rand in pbar(range(0, 10)):  
    N = 1000
    n_sample = 100
    gen_error = []
    gen_smiles = []
    sample_ys = []
    preds = []
  
    predss_can = []
    gen_atoms_embedding = []
    gen_bonds_embedding = []

    regressor.trainable = False
    generator.trainable = False
    discriminator.trainable = False

    np.random.seed(rand)

    pbar = ProgressBar()
    for hc in (pbar(sample_yss)):
        try:
            # get it back to original of s_min to s_max
            #sample_y = np.random.uniform(0, 15, size=[1,])
            sample_y = hc
            #print (sample_y)
            sample_y = np.round(sample_y, 4)
            sample_y = sample_y * np.ones([N, ])
            sample_y_ = (sample_y - gap_min) / (gap_max - gap_min)
            
            sample_z = np.random.normal(0, 1, size = (N, 128))
            
            regressor.trainable = False
            encoder.trainable = False
            decoder.trainable = False

            sample_atoms_embedding, sample_bonds_embedding = generator.predict([sample_z, sample_y_], verbose=0)
            dec_embedding = np.concatenate([sample_atoms_embedding, sample_bonds_embedding], axis = -1)

            softmax_smiles = decoder.predict(dec_embedding, verbose=0)[0]
            argmax_smiles = np.argmax(softmax_smiles, axis = 2)
            #print (argmax_smiles)

            #print ('shape argmax_smiles', argmax_smiles.shape)
            smiles = to_categorical(argmax_smiles, num_classes=27)
            
            SHAPE = list(smiles.shape) + [1] 
            
            #print ('shape line 767', SHAPE) 
            smiles = smiles.reshape(SHAPE)

            latent_encoder_atom, latent_encoder_bond, _ = encoder.predict([smiles], verbose=0)
            pred = regressor.predict([latent_encoder_atom, latent_encoder_bond], verbose=0).reshape([-1])
            pred = pred * (gap_max - gap_min) + gap_min

            gen_errors = np.abs((pred - sample_y) / sample_y).reshape([-1])


            smiles = decoder.predict(dec_embedding, verbose=0)[0]
            #print(smiles)
            smiles = np.argmax(smiles, axis = 2).reshape(smiles.shape[0], 40)
            

            generated_smiles = []
            
            for S in smiles:
                c_smiles = ''
                for s in S:
                    c_smiles += tokenizer[s]
                c_smiles = c_smiles.rstrip()
                #print (c_smiles)
                generated_smiles.append(c_smiles)
            generated_smiles = np.array(generated_smiles)
            #generated_smiles = generated_smiles [accurate]
            all_gen_smiles = []
            idx = []
            preds_can = []
            for i, smiles in enumerate(generated_smiles):
                all_gen_smiles.append(smiles[:-1])

                if ' ' in smiles[:-1]:
                    continue
                #m = Chem.MolFromSmiles(smiles[:-1], sanitize=False)
                m = Chem.MolFromSmiles(smiles[:-1], sanitize=True)
                if m is not None:
                    
                    smiles_can = Chem.MolToSmiles(m, canonical=True)
                    smiles_can_dot = smiles_can + '.'
                    X_smiles0 = tokenizer_.texts_to_sequences([smiles_can_dot])
                    X_smiles1 = pad_sequences(X_smiles0, maxlen = 40, padding = 'post')
                    X_smiles2 = to_categorical(X_smiles1, num_classes=27)
                    latent_encoder_atom, latent_encoder_bond, _ = encoder.predict(X_smiles2, verbose=0)
                    pred_can = regressor.predict([latent_encoder_atom, latent_encoder_bond], verbose=0).reshape([-1])
                    pred_can = pred_can*15
                    # focus on samples with high gap
                    if pred_can >10:
                        print(pred_can[0])
                        preds_can.append(pred_can[0])
                        idx.append(i)


            idx = np.array(idx)
            all_gen_smiles = np.array(all_gen_smiles)
            #print ('all gen smiels shape', all_gen_smiles.shape)
            #print ('gen_errors shape', gen_errors.shape)
            #print (idx)
            gen_smiles.extend(list(all_gen_smiles[idx]))
            gen_error.extend(list(gen_errors[idx]))
            sample_ys.extend(list(sample_y[idx]))
            gen_atoms_embedding.extend(sample_atoms_embedding[idx])
            gen_bonds_embedding.extend(sample_bonds_embedding[idx])
            preds.extend(list(pred[idx]))
            predss_can.extend(list(preds_can))
        except:
            #print('Did not discover SMILES for HC: {}'.format(sample_y))
            pass    

    try:
        output = {}

        for i, s in enumerate (gen_smiles):
            ss = Chem.MolToSmiles(Chem.MolFromSmiles(s, sanitize=True), canonical=True)
            gen_smiles[i] = ss

        output['SMILES'] = gen_smiles
        output['des_gap'] = sample_ys
        # More accurate for regressor to predict gap from canonical SMILES
        output['pred_gap'] = predss_can
        #output['Err_pred_des'] = gen_error
        output['Err_pred_des'] = [abs(i- j)/i for i, j in zip(output['des_gap'], output['pred_gap'])]
        output = pd.DataFrame(output)
        output.reset_index(drop = True, inplace = True)
        #if (sum (output['Err_pred_des']<= 0.2))/output.shape[0] > 0.0:
        output.to_csv ('./../experiments/transfer1/trans1_training{}.csv'.format(rand), index=False)
        #print ((sum (output['Err_pred_des']<= 0.2))/output.shape[0] )

        ## Statistics  (# pred=True value, Des=prediction)
        # total # of samples
        N = len(predss_can)
        print ('random seed', rand)

        # Explained Variance R2 from sklearn.metrics.explained_variance_score
        explained_variance_R2_pred_des = explained_variance_score(output['des_gap'], output['pred_gap'])
        print ("explained_varice_R2_pred_des", explained_variance_R2_pred_des)
        rsquared = np.round (r2_score (output['des_gap'], output['pred_gap']), 4)
        print ("r squared r**2", rsquared)

        # mean absolute error 
        MAE_pred_des = np.round (mean_absolute_error(output['pred_gap'], output['des_gap']), 4)
        print ("MAE_pred_des", MAE_pred_des)
        # Fractioned MAE, more normalized
        Fractioned_MAE_pred_des = 0
        for pred, des in zip(output['pred_gap'], output['des_gap']):
            Fractioned_MAE_pred_des = Fractioned_MAE_pred_des +  abs(des-pred)/des
        Fractioned_MAE_pred_des = Fractioned_MAE_pred_des/N
        #print ("Fractioned MAE_pred_des", Fractioned_MAE_pred_des)

        # root mean squared error (RMSE), sqrt(sklearn ouputs MSE)
        RMSE_pred_des = mean_squared_error(output['pred_gap'], output['des_gap'])**0.5
        #print ("RMSE_pred_des", RMSE_pred_des)

        Fractioned_RMSE_pred_des = 0
        for pred, des in zip(output['pred_gap'], output['des_gap']):
            Fractioned_RMSE_pred_des = Fractioned_RMSE_pred_des + ((des-pred)/des)**2
        Fractioned_RMSE_pred_des = (Fractioned_RMSE_pred_des/N)**0.5
        #print ("Fractioned_RMSE_pred_des", Fractioned_RMSE_pred_des)

        # do not drop duplicate
        output2 = output.drop_duplicates(['SMILES'])
        output2.reset_index(drop = True, inplace = True)
        #output2.to_csv('./../experiments/regular/Initial_training_nodub.csv', index = False)
        """with open('gen_pickles.pickle', 'wb') as f:
            pickle.dump(gen_unique_pickles, f)
        """
        #print ('% < 20 RE NODUP', sum (output2['Err_pred_des'] < 0.2) / output2['Err_pred_des'].shape[0])
        less20RE_per = np.round ((sum(output['Err_pred_des'] <= 0.2) / output['Err_pred_des'].shape[0]), 4)
        print ('% < 20 RE', less20RE_per)
        output_len = len(output)
        explained_variance_R2_pred_des = explained_variance_score(output['des_gap'], output['pred_gap'])
        #print ("explained_varice_R2_pred_des", explained_variance_R2_pred_des)
        mean_RE = np.round (np.mean (output['Err_pred_des']), 4)
        print ('RE mean', mean_RE)

        randS.append(rand)
        rsquaredS.append(rsquared)
        MAE_S.append(MAE_pred_des)
        less20RE_perS.append(less20RE_per)
        mean_RE_S.append(mean_RE)
        output_lenS.append(output_len)

        if rsquared>max:
            good_rand = rand
            max = rsquared
            best_r2 = rsquared
            print ('best r2', best_r2)
            print ('best random seed', good_rand)
        
        tf.compat.v1.keras.backend.clear_session()
    except:
        pass
    tf.compat.v1.keras.backend.clear_session()

params = {}
params ['rand'] = randS
params ['r2'] = rsquaredS
params ['MAE'] = MAE_S
params ['less20RE_per'] = less20RE_perS
params ['Average_RE'] = mean_RE_S
params ['total_valid'] = output_lenS
params = pd.DataFrame(params)
params.reset_index(drop = True, inplace = True)
params.to_csv ('./gen_params.csv', index=False)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 100% |########################################################################|
# random seed 0
#   8% |#####                                                                   |
# 10.088832
#  90% |################################################################        |
# 10.073549
# 100% |########################################################################|
# random seed 1
# explained_varice_R2_pred_des 0.009751675459148679
# r squared r**2 -1.3709
# MAE_pred_des 1.837
# % < 20 RE 0.5
# RE mean 0.1394
#  89% |################################################################        |
# 10.086004
# 100% |########################################################################|
# random seed 2
# explained_varice_R2_pred_des 1.0
# r squared r**2 nan
# MAE_pred_des 2.3238
# % < 20 RE 1.0
# RE mean 0.1873
# 100% |########################################################################|
#  40% |############################                                            |
# random seed 3
#  51% |####################################                                    |
# 10.033694
#  86% |#############################################################           |
# 10.10105
# 100% |########################################################################|
# random seed 4
# explained_varice_R2_pred_des -0.14740702877770806
# r squared r**2 -37.3473
# MAE_pred_des 2.8861
# % < 20 RE 0.5
# RE mean 0.2217
#  10% |#######                                                                 |
# 10.036505
#  59% |##########################################                              |
# 10.08038
# 100% |########################################################################|
# random seed 5
# explained_varice_R2_pred_des -0.02940807925923239
# r squared r**2 -0.0554
# MAE_pred_des 1.5248
# % < 20 RE 1.0
# RE mean 0.1477
# 100% |########################################################################|
#  70% |##################################################                      |
# random seed 6
# 100% |########################################################################|
# random seed 7
# 100% |########################################################################|
#  90% |################################################################        |
# random seed 8
# 100% |########################################################################|
# 100% |########################################################################|
# random seed 9

# %%
output
# Out:
# Empty DataFrame
# Columns: [SMILES, des_gap, pred_gap, Err_pred_des]
# Index: []

# %%
output.to_csv ('./../experiments/regular/regularVStransfer_gapdist/transfer1.csv')

# %%
with open('./../data/trainingsets/image.pickle', 'rb') as f:
    _, SMILES_original, y_original = pickle.load(f) 

initial_train = pd.read_csv ('./../experiments/regular/regularVStransfer_gapdist/Initial_training.csv')

# %%
fig, ax = plt.subplots(figsize=(6, 5))

bw_adjust = 3
sns.kdeplot(y_original, bw_adjust=bw_adjust, color='blue', 
            fill=True, label='PubChemQC', linewidth=0, alpha=0.5)
sns.kdeplot(initial_train['pred_gap'], color='red', fill=True,
            bw_adjust=bw_adjust, label='Initial Gen.', linewidth=0, alpha=0.5)
sns.kdeplot(output['pred_gap'], color='green', fill=True, 
            bw_adjust=bw_adjust, label='TL Iter. 1', linewidth=0, alpha=0.5)

plt.xlabel('d', fontsize=20,fontweight='bold', fontname='Arial')
plt.xlim(0, 12)
plt.legend(fontsize=8, framealpha=1)
plt.xlim(1, 15)
plt.xlabel(r'$E_{gap}$ (eV)', fontsize=25, 
           fontname='Arial', fontweight="bold", labelpad=0)
plt.ylabel('Rel. Abundance', fontsize=25, 
           fontname='Arial', fontweight="bold", labelpad=10)
ax.tick_params(axis='both', which='major', labelsize=20, width=3, length=4)
[i.set_linewidth(3) for i in ax.spines.values()]
plt.tight_layout()
plt.savefig('genVSpubqc_dist.jpeg', dpi=500)

# %%
fig, ax = plt.subplots(figsize=(6, 5))

bw_adjust = 3

kwargs1 = dict(kde_kws={'bw_adjust':1})
kwargs2 = dict(kde_kws={'bw_adjust':1})
kwargs3 = dict(kde_kws={'bw_adjust':0.2})

sns.histplot(y_original, color='blue', fill=True, label='PubChemQC', stat='percent', **kwargs1,
             kde=True, bins=25, alpha=0.4, linewidth=0.1)
sns.histplot(initial_train['pred_gap'], color='red', fill=True,  label='Initial Gen.', **kwargs2,
             kde=True, stat='percent', bins=25, linewidth=0.1)
sns.histplot(output['pred_gap'], color='green', fill=True, label='TL Iter. 1', stat='percent', **kwargs3,
             kde=True, bins=15, linewidth=0.1)

plt.xlabel('d', fontsize=20,fontweight='bold', fontname='Arial')
plt.xlim(0, 12)
plt.legend(fontsize=8, framealpha=1)
plt.xlim(1, 15)
plt.xlabel(r'$E_{gap}$ (eV)', fontsize=25, 
           fontname='Arial', fontweight="bold", labelpad=0)
plt.ylabel('Percentage', fontsize=25, 
           fontname='Arial', fontweight="bold", labelpad=10)
ax.tick_params(axis='both', which='major', labelsize=20, width=3, length=4)
[i.set_linewidth(3) for i in ax.spines.values()]
plt.tight_layout()
#plt.savefig('genVSpubqc_dist.jpeg', dpi=500)

# %%
output.loc [output['pred_gap']<3]
# Out:
#                               SMILES  des_gap  pred_gap  Err_pred_des
# 46           Cc1cccccccccnc2connc1-2   3.2616  2.982346      0.085619
# 91      CNC1=CC=CC=CC=CC=CC=NC=CC=N1   1.6809  2.429755      0.445508
# 166           CC[SH]=CC=[SH]CCC(C)CC   8.7628  2.237473      0.744662
# 193          OC1C=CC=CC=C2C=C1SC=CC2   3.9097  2.769147      0.291724
# 337  O=c1ccc2cc(c1)C1=C=CC=CC=C1N=C2   0.7034  2.197857      2.124619

# %%
SMILES_original[y_original<1.5]
# Out:
# array(['C1=CCc2c3c(ccc2=C1)=c1ccccc1=C3.',
#        'COc1cc(O)c2c(c1)[C](O)C(=O)C(=O)[C]2O.',
#        'C1=CCc2cc3c(cc2=C1)C=c1ccccc1=3.',
#        'O=c1ccc(=O)c2[nH]c3ccccc3[nH]c1=2.',
#        'NNC1=C2C=CCC3=C2C2=C1CC=CC2=NC3=O.',
#        'O=C1C=CC2=c3ccccc3=C(NO)C2=C1.', 'O=C1C(=O)C(=O)C1=O.',
#        'NC1=CC=CN(O)[C]1c1c(N)c[c]c[n+]1[O-].',
#        'N[C](CC(=O)c1ccccc1O)c1cc[c]cc1.',
#        'O=C(C[C](O)c1cc[c]cc1)c1ccco1.',
#        'C=CC[N]C(=S)C(=C(C)O)N1C=CCC=C1.',
#        'O=C(C[C](O)c1cc[c]cc1)c1ccccc1O.',
#        '[O]N(Cc1cccc(O)c1)c1cc[c]cc1.', 'O=C1C=Cc2c[c]ccc2[C]1CNC1CC1.',
#        'O=C1C=CC(=CCC2=C[C]C=CN2)C=C1.', 'O=C1C=CC=CC1=NC(=O)C1=CNC=CN1.',
#        'N#CC[C](c1cc[c]cc1)N1CCCC1.', 'N#CC[C](c1cc[c]cc1)N1CCCCC1.',
#        'C1=C[C](c2cscc2[C]2C=CC=C2)C=C1.',
#        'N#CC(C#N)=C1C(O)=c2ccccc2=C1O.', 'O=c1ccc(=O)c2[nH]cc[nH]c1=2.',
#        'N#Cc1ccc2c(c1)[C](O)C(=O)C(=O)[C]2O.',
#        '[N][N]c1ccc2cccc(S([O])([O])[O])c2c1.', 'C1=C[C]2C=C[C]1C2.',
#        'N=C(O)C[CH]c1cnc2c[c]ccc2c1.',
#        'O=C1[CH]c2cc3c(O)ccc(O)c3cc2[CH]C1=O.',
#        'O=c1ccc2[nH]c3ccccc3[nH]c=2c1=O.', 'O=C1C=C2C=c3ccccc3=C2C=C1O.',
#        'N#CC1[C]2[CH][CH][C]1C=C2.', 'C1=CCC2=c3cc4ccccc4cc3=CC2=C1.',
#        'O=C1[CH]c2cc3ccccc3cc2[CH]C1=O.', 'OCC[C](c1cc[c]cc1)c1cccs1.',
#        'Cc1ccc2c(c1)[C](O)C(=O)C(=O)[C]2O.',
#        'O=C1[C](O)c2ccc(O)cc2[C](O)C1=O.',
#        'O=C1[CH]C=CN=C1[N]C(=O)C1=CNC=CN1.',
#        '[CH]1[CH][C]2C[C]1c1cncnc12.', 'O=c1ccc2[nH]cc[nH]c=2c1=O.',
#        'O=C1C=CC2=c3ccc(O)c(O)c3=CC2=C1.', '[CH]1C[CH]C1.',
#        'O=C1N=C(O)C=C1C(=O)On1c(O)ccc1O.', 'S=C1C=CC=C(C2=NNNN2)C1=S.',
#        'CC1=C[C](c2c(C)ccc3c2[N]NN3)C(=O)C=C1.',
#        'O=C1c2ccccc2[C]2[C]3C=CC=CC3SC21.',
#        'C1=C2C=c3cc4ccccc4c4ccc(c2c34)=CC1.',
#        'C1=c2ccccc2=Cc2[nH]c3ccccc3c2O1.', '[CH]1[CH][C]2C[C]1c1ccccc12.',
#        'Cc1c(O)c(O)c2c(c1O)[CH]C(=O)C(=O)[C]2O.',
#        'O=C1C=CC(=O)C(C2=CC=CC(=CO)N2)=C1.', '[CH2]CCCC[CH2].',
#        'N#CC[C](c1cc[c]cc1)N1CCNCC1.', 'O=C(O)C[C]1NCc2c[c]ccc21.',
#        'N=C(O)C[C](N)c1ccc2c[c]ccc2c1.',
#        'Cc1ccc(C)c2c1[C](O)C(=O)C(=O)[C]2O.',
#        'CCc1ccc2c(c1)[C](O)C(=O)C(=O)[C]2O.', 'N#CC1=Cc2cc(N)ccc21.',
#        'CCc1cccc2c1[C](O)C(=O)C(=O)[C]2O.',
#        '[N][N]c1cc(C([O])=O)c2ccccc2c1O.', 'C1=C[C]2C[C]1c1cc3c(cc12)O3.',
#        'O=C1OC(=O)c2c1ccc1c2[C]2[CH][CH][C]1C2.',
#        'Cc1cccc2c1[C](O)C(=O)C(=O)[C]2O.',
#        'O=C(C[C](O)c1cc[c]cc1)C1=N[CH]N[N]1.'], dtype=object)

# %%
print (np.max (output['pred_gap']))
print (np.mean (output['pred_gap']))
# Out:
# 10.274595
# 8.818021
